# %% [markdown]
# Beta maṣāḥǝft
# ===
#
# The Beta maṣāḥǝft implementation is a specific implementation built by Pietro Liuzzo
#
# ## Configuration
#
# The following cell are used to avoid rewriting to much cells if the address of the DTS API were to change.

# %%
import requests
import requests_cache

API_URI = "http://betamasaheft.eu"
URI = "http://betamasaheft.eu/api/dts"

# %% [markdown]
# ## Getting the available endpoints
#
# DTS entry point is a listing of the available endpoints and their URL. This means that for each implementation of DTS, this single URL will give you all the information you need to perform arbitrary queries, if you were to do so. The Beta maṣāḥǝft implementation provide the three endpoints :

# %%
entry_request = requests.get(URI)
ENDPOINTS = entry_request.json()
ENDPOINTS
# Out:
# {'@context': '/dts/api/contexts/EntryPoint.jsonld',
#  '@id': '/api/dts/',
#  '@type': 'EntryPoint',
#  'collections': '/api/dts/collections',
#  'documents': '/api/dts/document',
#  'navigation': '/api/dts/navigation'}

# %% [markdown]
# As you can see, all three endpoints have been given URIs. Because we do not know the text we want to see, we'll browse from here :

# %% [markdown]
# ## Browsing the root of the catalog
#
# The root of the data catalog is the result of the basic GET request on the `collections` endpoint :

# %%
ROOT_COLLECTION  = requests.get(API_URI+ENDPOINTS["collections"]).json()
ROOT_COLLECTION
# Out:
# {'@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#   'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#   'dc': 'http://purl.org/dc/terms/',
#   'dts': 'https://w3id.org/dts/api#',
#   'ecrm': 'http://erlangen-crm.org/current/',
#   'saws': 'http://purl.org/saws/ontology#',
#   'tei': 'http://www.tei-c.org/ns/1.0'},
#  '@id': 'urn:dts',
#  '@type': 'Collection',
#  'description': "The project Beta maṣāḥǝft: Manuscripts of Ethiopia and Eritrea (Schriftkultur des christlichen Äthiopiens: eine multimediale Forschungsumgebung) is a long-term project funded within the framework of the Academies' Programme (coordinated by the Union of the German Academies of Sciences and Humanities) under survey of the Akademie der Wissenschaften in Hamburg. The funding will be provided for 25 years, from 2016–2040. The project is hosted by the Hiob Ludolf Centre for Ethiopian Studies at the University of Hamburg. It aims at creating a virtual research environment that shall manage complex data related to predominantly Christian manuscript tradition of the Ethiopian and Eritrean Highlands.",
#  'dts:dublincore': {'dc:description': [{'@lang': 'en',
#     '@value': "The project Beta maṣāḥǝft: Manuscripts of Ethiopia and Eritrea (Schriftkultur des christlichen Äthiopiens: eine multimediale Forschungsumgebung) is a long-term project funded within the framework of the Academies' Programme (coordinated by the Union of the German Academies of Sciences and Humanities) under survey of the Akademie der Wissenschaften in Hamburg. The funding will be provided for 25 years, from 2016–2040. The project is hosted by the Hiob Ludolf Centre for Ethiopian Studies at the University of Hamburg. It aims at creating a virtual research environment that shall manage complex data related to predominantly Christian manuscript tradition of the Ethiopian and Eritrean Highlands."}],
#   'dc:publisher': ['Akademie der Wissenschaften in Hamburg',
#    'Hiob-Ludolf-Zentrum für Äthiopistik']},
#  'member': [{'@id': 'urn:dts:betmas',
#    '@type': 'Collection',
#    'description': 'Collection of textual units of the Ethiopic tradition',
#    'title': 'Beta maṣāḥǝft Textual Units',
#    'totalItems': 1174},
#   {'@id': 'urn:dts:betmasMS',
#    '@type': 'Collection',
#    'description': 'Collection of Ethiopic Manuscript trasncriptions',
#    'title': 'Beta maṣāḥǝft Manuscripts',
#    'totalItems': 125}],
#  'title': 'Beta maṣāḥǝft',
#  'totalItems': 2}

# %% [markdown]
# The root collection has 2 items : let's go see the one made of manuscripts !

# %% [markdown]
# ## Requesting a specific collection
#
# Requesting a specific collection is simple : you go to the Collections endpoint, add the parameter `id` with the `@id` property of your item.
#
# ### Manuscripts Collections
#
# We first want to get the Manuscripts collection : it will be at the URI http://betamasaheft.eu/api/dts/collections?id=urn:dts:betmasMS

# %%
Manuscript_Collection  = requests.get(API_URI+ENDPOINTS["collections"]+"?id=urn:dts:betmasMS").json()
print(API_URI+ENDPOINTS["collections"]+"?id=urn:dts:betmasMS")
print(Manuscript_Collection)
#Let's check page X where we have BLorient718
# Out:
# http://betamasaheft.eu/api/dts/collections?id=urn:dts:betmasMS
# {'title': 'Beta maṣāḥǝft Manuscripts', 'view': {'next': '/api/dts/collections?id=urn:dts:betmasMS&page=2', 'previous': None, '@type': 'PartialCollectionView', 'first': '/api/dts/collections?id=urn:dts:betmasMS&page=1', 'last': '/api/dts/collections?id=urn:dts:betmasMS&page=13', '@id': '/api/dts/collections?id=urn:dts:betmasMS&page=1'}, 'totalItems': 125, '@type': 'Collection', '@id': 'urn:dts:betmasMS', '@context': {'saws': 'http://purl.org/saws/ontology#', 'crm': 'http://www.cidoc-crm.org/cidoc-crm/', '@vocab': 'https://www.w3.org/ns/hydra/core#', 'dts': 'https://w3id.org/dts/api#', 'tei': 'http://www.tei-c.org/ns/1.0', 'dc': 'http://purl.org/dc/terms/', 'ecrm': 'http://erlangen-crm.org/current/'}, 'member': [{'title': 'Egypt, Dayr as-Suryān, DS Ethiop. 12', 'dts:references': '/api/dts/navigation?id=urn:dts:betmasMS:DSEthiop12', 'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeType': 'column'}], 'dts:citeType': 'page'}], 'dts:citeType': 'folio'}], 'totalItems': 0, 'dts:passage': '/api/dts/document?id=urn:dts:betmasMS:DSEthiop12', 'dts:citeDepth': 3, 'dts:download': 'http://betamasaheft.eu/tei/DSEthiop12.xml', 'description': 'The transcription of manuscript Egypt, Dayr as-Suryān, DS Ethiop. 12 in Beta maṣāḥǝft ', '@id': 'urn:dts:betmasMS:DSEthiop12', 'dts:dublincore': {'dc:title': None, 'dc:creator': ['Beta maṣāḥǝft Team'], 'dc:type': ['http://chs.harvard.edu/xmlns/cts#edition', 'dc:Text'], 'dc:language': ['en', 'ar', 'gez', 'ti'], 'dc:contributor': ['Alessandro Bausi', 'Dorothea Reule', 'Denis Nosnitsin']}, '@type': 'Resource'}, {'title': 'Egypt, Dayr as-Suryān, DS Ethiop. 3', 'dts:references': '/api/dts/navigation?id=urn:dts:betmasMS:DSEthiop3', 'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeType': 'column'}], 'dts:citeType': 'page'}], 'dts:citeType': 'folio'}], 'totalItems': 0, 'dts:passage': '/api/dts/document?id=urn:dts:betmasMS:DSEthiop3', 'dts:citeDepth': 3, 'dts:download': 'http://betamasaheft.eu/tei/DSEthiop3.xml', 'description': 'The transcription of manuscript Egypt, Dayr as-Suryān, DS Ethiop. 3 in Beta maṣāḥǝft ', '@id': 'urn:dts:betmasMS:DSEthiop3', 'dts:dublincore': {'dc:title': None, 'dc:creator': ['Beta maṣāḥǝft Team'], 'dc:type': ['http://chs.harvard.edu/xmlns/cts#edition', 'dc:Text'], 'dc:language': ['en', 'ar', 'gez', 'am'], 'dc:contributor': ['Alessandro Bausi', 'Dorothea Reule', 'Denis Nosnitsin']}, '@type': 'Resource'}, {'title': 'Egypt, Dayr as-Suryān, DS Ethiop. 8', 'dts:references': '/api/dts/navigation?id=urn:dts:betmasMS:DSEthiop8', 'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeType': 'column'}], 'dts:citeType': 'page'}], 'dts:citeType': 'folio'}], 'totalItems': 0, 'dts:passage': '/api/dts/document?id=urn:dts:betmasMS:DSEthiop8', 'dts:citeDepth': 3, 'dts:download': 'http://betamasaheft.eu/tei/DSEthiop8.xml', 'description': 'The transcription of manuscript Egypt, Dayr as-Suryān, DS Ethiop. 8 in Beta maṣāḥǝft ', '@id': 'urn:dts:betmasMS:DSEthiop8', 'dts:dublincore': {'dc:title': None, 'dc:creator': ['Beta maṣāḥǝft Team'], 'dc:type': ['http://chs.harvard.edu/xmlns/cts#edition', 'dc:Text'], 'dc:language': ['en', 'ar', 'gez', 'ti'], 'dc:contributor': ['Alessandro Bausi', 'Dorothea Reule', 'Denis Nosnitsin']}, '@type': 'Resource'}, {'title': 'Egypt, Dayr as-Suryān, DS Ethiop. 9', 'dts:references': '/api/dts/navigation?id=urn:dts:betmasMS:DSEthiop9', 'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeType': 'column'}], 'dts:citeType': 'page'}], 'dts:citeType': 'folio'}], 'totalItems': 0, 'dts:passage': '/api/dts/document?id=urn:dts:betmasMS:DSEthiop9', 'dts:citeDepth': 3, 'dts:download': 'http://betamasaheft.eu/tei/DSEthiop9.xml', 'description': 'The transcription of manuscript Egypt, Dayr as-Suryān, DS Ethiop. 9 in Beta maṣāḥǝft ', '@id': 'urn:dts:betmasMS:DSEthiop9', 'dts:dublincore': {'dc:title': None, 'dc:creator': ['Beta maṣāḥǝft Team'], 'dc:type': ['http://chs.harvard.edu/xmlns/cts#ed ...

# %% [markdown]
# ### London, British Library, BL Oriental 718
#
# There is a lot of collections, let check this one in details : urn:dts:betmasMS:BLorient718 (It's available in one of the pages and is an interesting, fully working collection)

# %%
BLorient718  = requests.get(API_URI+ENDPOINTS["collections"]+"?id=urn:dts:betmasMS:BLorient718").json()
pprint(BLorient718)
# Out:
# {'@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#               'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#               'dc': 'http://purl.org/dc/terms/',
#               'dts': 'https://w3id.org/dts/api#',
#               'ecrm': 'http://erlangen-crm.org/current/',
#               'saws': 'http://purl.org/saws/ontology#',
#               'tei': 'http://www.tei-c.org/ns/1.0'},
#  '@id': 'urn:dts:betmasMS:BLorient718',
#  '@type': 'Resource',
#  'description': 'The transcription of manuscript London, British Library, BL '
#                 'Oriental 718 in Beta maṣāḥǝft ',
#  'dts:citeDepth': 3,
#  'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeStructure': [{'dts:citeType': 'column'}],
#                                                'dts:citeType': 'page'}],
#                         'dts:citeType': 'folio'}],
#  'dts:download': 'http://betamasaheft.eu/tei/BLorient718.xml',
#  'dts:dublincore': {'dc:contributor': ['Alessandro Bausi',
#                                        'Nafisa Valieva',
#                                        'Pietro Maria Liuzzo'],
#                     'dc:creator': [['Alessandro Bausi', 'Nafisa Valieva']],
#                     'dc:language': ['en', 'gez', 'am'],
#                     'dc:title': None,
#                     'dc:type': ['http://chs.harvard.edu/xmlns/cts#edition',
#                                 'dc:Text']},
#  'dts:passage': '/api/dts/document?id=urn:dts:betmasMS:BLorient718',
#  'dts:references': '/api/dts/navigation?id=urn:dts:betmasMS:BLorient718',
#  'title': 'London, British Library, BL Oriental 718',
#  'totalItems': 0}

# %% [markdown]
# So, there is few things we can see:
#
# - The `dts:dublincore` is quite well filled :
#     - There is multiple language in the text
#     - The creator of the edition are Alessandro Bausia and Nafisa Valieva
#     - Contributor are named.
# - The data provider has given a direct link for download, in case this seems more interesting for the user, through `dts:download`
# - You see the `dts:citeDepth` ? The texts has up to 3 levels !
#     1. The first level has the name `folio`. This level has a second level:
#         1. The second of the level inside folio has the name `page`
#             1. The third of the level inside page has the name `column`
#
# Now, we have two really interesting links, let's go see what's in there !

# %% [markdown]
# ## What folio do you have ?
#
# To reply to this long but quite clear title, there is only one thing to do : go to the `dts:references` URI we see here.
#
# But wait, see the URI ? It's actually a simple construction :
#
# - We use `navigation` from `ENDPOINTS`.
# - We add the `@id` of the Resource we are interested in !
#
# ### All the *folio*s !

# %%
Folios = requests.get(API_URI+BLorient718["dts:references"]).json()
Folios
# Out:
# {'@base': '/dts/api/document/',
#  '@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#   'dc': 'http://purl.org/dc/terms/',
#   'dts': 'https://w3id.org/dts/api#'},
#  '@id': '/api/dts/navigation?id=urn:dts:betmasMS:BLorient718',
#  'dts:citeDepth': 3,
#  'dts:citeType': 'folio',
#  'dts:level': 1,
#  'dts:passage': 'dts/api/document?id=urn:dts:betmasMS:BLorient718{&ref}{&start}{&end}',
#  'member': [{'ref': '1'},
#   {'ref': '2'},
#   {'ref': '3'},
#   {'ref': '4'},
#   {'ref': '5'},
#   {'ref': '6'},
#   {'ref': '7'},
#   {'ref': '8'},
#   {'ref': '9'},
#   {'ref': '10'},
#   {'ref': '11'},
#   {'ref': '12'},
#   {'ref': '13'},
#   {'ref': '14'},
#   {'ref': '15'},
#   {'ref': '16'},
#   {'ref': '17'},
#   {'ref': '18'},
#   {'ref': '19'},
#   {'ref': '20'},
#   {'ref': '21'},
#   {'ref': '22'},
#   {'ref': '23'},
#   {'ref': '24'},
#   {'ref': '25'},
#   {'ref': '26'},
#   {'ref': '27'},
#   {'ref': '28'},
#   {'ref': '29'},
#   {'ref': '30'},
#   {'ref': '31'},
#   {'ref': '32'},
#   {'ref': '33'},
#   {'ref': '34'},
#   {'ref': '35'},
#   {'ref': '36'},
#   {'ref': '37'},
#   {'ref': '38'},
#   {'ref': '39'},
#   {'ref': '40'},
#   {'ref': '41'},
#   {'ref': '42'},
#   {'ref': '43'},
#   {'ref': '44'},
#   {'ref': '45'},
#   {'ref': '46'},
#   {'ref': '47'},
#   {'ref': '48'},
#   {'ref': '49'},
#   {'ref': '50'},
#   {'ref': '51'},
#   {'ref': '52'},
#   {'ref': '53'},
#   {'ref': '54'},
#   {'ref': '55'},
#   {'ref': '56'},
#   {'ref': '57'},
#   {'ref': '58'},
#   {'ref': '59'},
#   {'ref': '60'},
#   {'ref': '61'},
#   {'ref': '62'},
#   {'ref': '63'},
#   {'ref': '64'},
#   {'ref': '65'},
#   {'ref': '66'},
#   {'ref': '67'},
#   {'ref': '68'},
#   {'ref': '69'},
#   {'ref': '70'},
#   {'ref': '71'},
#   {'ref': '72'},
#   {'ref': '73'},
#   {'ref': '74'},
#   {'ref': '75'},
#   {'ref': '76'},
#   {'ref': '77'},
#   {'ref': '78'},
#   {'ref': '79'},
#   {'ref': '80'},
#   {'ref': '81'},
#   {'ref': '82'},
#   {'ref': '83'},
#   {'ref': '84'},
#   {'ref': '85'},
#   {'ref': '86'},
#   {'ref': '87'},
#   {'ref': '88'},
#   {'ref': '89'},
#   {'ref': '90'},
#   {'ref': '91'},
#   {'ref': '92'},
#   {'ref': '93'},
#   {'ref': '94'},
#   {'ref': '95'},
#   {'ref': '96'},
#   {'ref': '97'},
#   {'ref': '98'},
#   {'ref': '99'},
#   {'ref': '100'},
#   {'ref': '101'},
#   {'ref': '102'},
#   {'ref': '103'},
#   {'ref': '104'},
#   {'ref': '105'},
#   {'ref': '106'},
#   {'ref': '107'},
#   {'ref': '108'},
#   {'ref': '109'},
#   {'ref': '110'},
#   {'ref': '111'},
#   {'ref': '112'},
#   {'ref': '113'},
#   {'ref': '114'},
#   {'ref': '115'},
#   {'ref': '116'},
#   {'ref': '117'},
#   {'ref': '118'},
#   {'ref': '119'},
#   {'ref': '120'},
#   {'ref': '121'},
#   {'ref': '122'},
#   {'ref': '123'},
#   {'ref': '124'},
#   {'ref': '125'},
#   {'ref': '126'},
#   {'ref': '127'},
#   {'ref': '128'},
#   {'ref': '129'},
#   {'ref': '130'}]}

# %% [markdown]
# ### Give me all the columns !

# %%
Columns = requests.get(API_URI+BLorient718["dts:references"] + "&level=3").json()
Columns
# Out:
# {'@base': '/dts/api/document/',
#  '@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#   'dc': 'http://purl.org/dc/terms/',
#   'dts': 'https://w3id.org/dts/api#'},
#  '@id': '/api/dts/navigation?id=urn:dts:betmasMS:BLorient718',
#  'dts:citeDepth': 3,
#  'dts:citeType': 'column',
#  'dts:level': 3,
#  'dts:passage': 'dts/api/document?id=urn:dts:betmasMS:BLorient718{&ref}{&start}{&end}',
#  'member': [{'ref': '1ra'},
#   {'ref': '1rb'},
#   {'ref': '1va'},
#   {'ref': '1vb'},
#   {'ref': '2ra'},
#   {'ref': '2rb'},
#   {'ref': '2va'},
#   {'ref': '2vb'},
#   {'ref': '3ra'},
#   {'ref': '3rb'},
#   {'ref': '3va'},
#   {'ref': '3vb'},
#   {'ref': '4ra'},
#   {'ref': '4rb'},
#   {'ref': '4va'},
#   {'ref': '4vb'},
#   {'ref': '5ra'},
#   {'ref': '5rb'},
#   {'ref': '5va'},
#   {'ref': '5vb'},
#   {'ref': '6ra'},
#   {'ref': '6rb'},
#   {'ref': '6va'},
#   {'ref': '6vb'},
#   {'ref': '7ra'},
#   {'ref': '7rb'},
#   {'ref': '7va'},
#   {'ref': '7vb'},
#   {'ref': '8ra'},
#   {'ref': '8rb'},
#   {'ref': '8va'},
#   {'ref': '8vb'},
#   {'ref': '9ra'},
#   {'ref': '9rb'},
#   {'ref': '9va'},
#   {'ref': '9vb'},
#   {'ref': '10ra'},
#   {'ref': '10rb'},
#   {'ref': '11va'},
#   {'ref': '11vb'},
#   {'ref': '11ra'},
#   {'ref': '11rb'},
#   {'ref': '11va'},
#   {'ref': '11vb'},
#   {'ref': '12ra'},
#   {'ref': '12rb'},
#   {'ref': '12va'},
#   {'ref': '12vb'},
#   {'ref': '13ra'},
#   {'ref': '13rb'},
#   {'ref': '13va'},
#   {'ref': '13vb'},
#   {'ref': '14ra'},
#   {'ref': '14rb'},
#   {'ref': '14va'},
#   {'ref': '14vb'},
#   {'ref': '15ra'},
#   {'ref': '15rb'},
#   {'ref': '15va'},
#   {'ref': '15vb'},
#   {'ref': '16ra'},
#   {'ref': '16rb'},
#   {'ref': '16va'},
#   {'ref': '16vb'},
#   {'ref': '17ra'},
#   {'ref': '17rb'},
#   {'ref': '17va'},
#   {'ref': '17vb'},
#   {'ref': '18ra'},
#   {'ref': '18rb'},
#   {'ref': '18va'},
#   {'ref': '18vb'},
#   {'ref': '19ra'},
#   {'ref': '19rb'},
#   {'ref': '19va'},
#   {'ref': '19vb'},
#   {'ref': '20ra'},
#   {'ref': '20rb'},
#   {'ref': '20va'},
#   {'ref': '20vb'},
#   {'ref': '21ra'},
#   {'ref': '21rb'},
#   {'ref': '21va'},
#   {'ref': '21vb'},
#   {'ref': '22ra'},
#   {'ref': '22rb'},
#   {'ref': '22va'},
#   {'ref': '22vb'},
#   {'ref': '23ra'},
#   {'ref': '23rb'},
#   {'ref': '23va'},
#   {'ref': '23vb'},
#   {'ref': '24ra'},
#   {'ref': '24rb'},
#   {'ref': '24va'},
#   {'ref': '24vb'},
#   {'ref': '25ra'},
#   {'ref': '25rb'},
#   {'ref': '25va'},
#   {'ref': '25vb'},
#   {'ref': '26ra'},
#   {'ref': '26rb'},
#   {'ref': '26va'},
#   {'ref': '26vb'},
#   {'ref': '27ra'},
#   {'ref': '27rb'},
#   {'ref': '27va'},
#   {'ref': '27vb'},
#   {'ref': '28ra'},
#   {'ref': '28rb'},
#   {'ref': '28va'},
#   {'ref': '28vb'},
#   {'ref': '29ra'},
#   {'ref': '29rb'},
#   {'ref': '29va'},
#   {'ref': '29vb'},
#   {'ref': '30ra'},
#   {'ref': '30rb'},
#   {'ref': '30va'},
#   {'ref': '30vb'},
#   {'ref': '31ra'},
#   {'ref': '31rb'},
#   {'ref': '31va'},
#   {'ref': '31vb'},
#   {'ref': '32ra'},
#   {'ref': '32rb'},
#   {'ref': '32va'},
#   {'ref': '32vb'},
#   {'ref': '33ra'},
#   {'ref': '33rb'},
#   {'ref': '33va'},
#   {'ref': '33vb'},
#   {'ref': '34ra'},
#   {'ref': '34rb'},
#   {'ref': '34va'},
#   {'ref': '34vb'},
#   {'ref': '35ra'},
#   {'ref': '35rb'},
#   {'ref': '35va'},
#   {'ref': '35vb'},
#   {'ref': '36ra'},
#   {'ref': '36rb'},
#   {'ref': '36va'},
#   {'ref': '36vb'},
#   {'ref': '37ra'},
#   {'ref': '37rb'},
#   {'ref': '38va'},
#   {'ref': '38vb'},
#   {'ref': '38ra'},
#   {'ref': '38va'},
#   {'ref': '38vb'},
#   {'ref': '39ra'},
#   {'ref': '39rb'},
#   {'ref': '39va'},
#   {'ref': '40ra'},
#   {'ref': '40rb'},
#   {'ref': '40va'},
#   {'ref': '40vb'},
#   {'ref': '41ra'},
#   {'ref': '41rb'},
#   {'ref': '41va'},
#   {'ref': '41vb'},
#   {'ref': '42ra'},
#   {'ref': '42rb'},
#   {'ref': '42va'},
#   {'ref': '42vb'},
#   {'ref': '43ra'},
#   {'ref': '43rb'},
#   {'ref': '44va'},
#   {'ref': '44vb'},
#   {'ref': '44ra'},
#   {'ref': '44rb'},
#   {'ref': '44va'},
#   {'ref': '44vb'},
#   {'ref': '45ra'},
#   {'ref': '45rb'},
#   {'ref': '45va'},
#   {'ref': '45vb'},
#   {'ref': '46ra'},
#   {'ref': '46rb'},
#   {'ref': '46va'},
#   {'ref': '46vb'},
#   {'ref': '47ra'},
#   {'ref': '47rb'},
#   {'ref': '47va'},
#   {'ref': '47vb'},
#   {'ref': '48ra'},
#   {'ref': '48rb'},
#   {'ref': '48va'},
#   {'ref': '48vb'},
#   {'ref': '49ra'},
#   {'ref': '49rb'},
#   {'ref': '49va'},
#   {'ref': '49vb'},
#   {'ref': '50ra'},
#   {'ref': '50rb'},
#   {'ref': '50va'},
#   {'ref': '50vb'},
#   {'ref': '51ra'},
#   {'ref': '51rb'},
#   {'ref': '52va'},
#   {'ref': '52vb'},
#   {'ref': '52ra'},
#   {'ref': '52rb'},
#   {'ref': '52va'},
#   {'ref': '52vb'},
#   {'ref': '53ra'},
#   {'ref': '53rb'},
#   {'ref': '53va'},
#   {'ref': '53vb'},
#   {'ref': '54ra'},
#   {'ref': '54rb'},
#   {'ref': '54va'},
#   {'ref': '54vb'},
#   {'ref': '55ra'},
#   {'ref': '55rb'},
#   {'ref': '55va'},
#   {'ref': '55vb'},
#   {'ref': '56ra'},
#   {'ref': '56rb'},
#   {'ref': '56va'},
#   {'ref': '56vb'},
#   {'ref': '57ra'},
#   {'ref': '57rb'},
#   {'ref': '57va'},
#   {'ref': '57vb'},
#   {'ref': '58ra'},
#   {'ref': '58rb'},
#   {'ref': '58va'},
#   {'ref': '58vb'},
#   {'ref': '59ra'},
#   {'ref': '59rb'},
#   {'ref': '59va'},
#   {'ref': '59vb'},
#   {'ref': '60ra'},
#   {'ref': '60rb'},
#   {'ref': '60va'},
#   {'ref': '60vb'},
#   {'ref': '61ra'},
#   {'ref': '61rb'},
#   {'ref': '61va'},
#   {'ref': '61vb'},
#   {'ref': '62ra'},
#   {'ref': '62rb'},
#   {'ref': '62va'},
#   {'ref': '62vb'},
#   {'ref': '63ra'},
#   {'ref': '63rb'},
#   {'ref': '63va'},
#   {'ref': '63vb'},
#   {'ref': '64ra'},
#   {'ref': '64rb'},
#   {'ref': '64va'},
#   {'ref': '64vb'},
#   {'ref': '65ra'},
#   {'ref': '65rb'},
#   {'ref': '65va'},
#   {'ref': '65vb'},
#   {'ref': '66ra'},
#   {'ref': '66rb'},
#   {'ref': '66va'},
#   {'ref': '66vb'},
#   {'ref': '67ra'},
#   {'ref': '67rb'},
#   {'ref': '67va'},
#   {'ref': '67vb'},
#   {'ref': '68ra'},
#   {'ref': '68rb'},
#   {'ref': '68va'},
#   {'ref': '68vb'},
#   {'ref': '69ra'},
#   {'ref': '69rb'},
#   {'ref': '69va'},
#   {'ref': '69vb'},
#   {'ref': '70ra'},
#   {'ref': '70rb'},
#   {'ref': '70va'},
#   {'ref': '70vb'},
#   {'ref': '71ra'},
#   {'ref': '71rb'},
#   {'ref': '71va'},
#   {'ref': '71vb'},
#   {'ref': '72ra'},
#   {'ref': '72rb'},
#   {'ref': '72va'},
#   {'ref': '72vb'},
#   {'ref': '73ra'},
#   {'ref': '73rb'},
#   {'ref': '73va'},
#   {'ref': '73vb'},
#   {'ref': '74ra'},
#   {'ref': '74rb'},
#   {'ref': '74va'},
#   {'ref': '74vb'},
#   {'ref': '75ra'},
#   {'ref': '75rb'},
#   {'ref': '75va'},
#   {'ref': '75vb'},
#   {'ref': '76ra'},
#   {'ref': '76va'},
#   {'ref': '77ra'},
#   {'ref': '77rb'},
#   {'ref': '77va'},
#   {'ref': '77vb'},
#   {'ref': '78ra'},
#   {'ref': '78rb'},
#   {'ref': '78va'},
#   {'ref': '78vb'},
#   {'ref': '79ra'},
#   {'ref': '79rb'},
#   {'ref': '79va'},
#   {'ref': '79vb'},
#   {'ref': '80ra'},
#   {'ref': '80rb'},
#   {'ref': '80va'},
#   {'ref': '80vb'},
#   {'ref': '81ra'},
#   {'ref': '81rb'},
#   {'ref': '81va'},
#   {'ref': '81vb'},
#   {'ref': '82ra'},
#   {'ref': '82rb'},
#   {'ref': '82va'},
#   {'ref': '82vb'},
#   {'ref': '83ra'},
#   {'ref': '83rb'},
#   {'ref': '83va'},
#   {'ref': '83vb'},
#   {'ref': '84ra'},
#   {'ref': '84rb'},
#   {'ref': '84va'},
#   {'ref': '84vb'},
#   {'ref': '85ra'},
#   {'ref': '85rb'},
#   {'ref': '85va'},
#   {'ref': '85vb'},
#   {'ref': '86ra'},
#   {'ref': '86rb'},
#   {'ref': '86va'},
#   {'ref': '86va'},
#   {'ref': '86vb'},
#   {'ref': '87ra'},
#   {'ref': '87rb'},
#   {'ref': '87va'},
#   {'ref': '87vb'},
#   {'ref': '88ra'},
#   {'ref': '88rb'},
#   {'ref': '88va'},
#   {'ref': '88vb'},
#   {'ref': '89ra'},
#   {'ref': '89rb'},
#   {'ref': '89va'},
#   {'ref': '89vb'},
#   {'ref': '90ra'},
#   {'ref': '90rb'},
#   {'ref': '90va'},
#   {'ref': '90vb'},
#   {'ref': '91ra'},
#   {'ref': '91rb'},
#   {'ref': '91va'},
#   {'ref': '91vb'},
#   {'ref': '92ra'},
#   {'ref': '92rb'},
#   {'ref': '92va'},
#   {'ref': '92vb'},
#   {'ref': '93ra'},
#   {'ref': '93rb'},
#   {'ref': '93va'},
#   {'ref': '93vb'},
#   {'ref': '94ra'},
#   {'ref': '94rb'},
#   {'ref': '94va'},
#   {'ref': '94vb'},
#   {'ref': '95ra'},
#   {'ref': '95rb'},
#   {'ref': '95va'},
#   {'ref': '95vb'},
#   {'ref': '96ra'},
#   {'ref': '96rb'},
#   {'ref': '96va'},
#   {'ref': '96vb'},
#   {'ref': '97ra'},
#   {'ref': '97rb'},
#   {'ref': '97va'},
#   {'ref': '97vb'},
#   {'ref': '98ra'},
#   {'ref': '98rb'},
#   {'ref': '98va'},
#   {'ref': '98vb'},
#   {'ref': '99ra'},
#   {'ref': '99rb'},
#   {'ref': '99va'},
#   {'ref': '100ra'},
#   {'ref': '100va'},
#   {'ref': '100vb'},
#   {'ref': '101ra'},
#   {'ref': '101rb'},
#   {'ref': '101va'},
#   {'ref': '101vb'},
#   {'ref': '102ra'},
#   {'ref': '102rb'},
#   {'ref': '102va'},
#   {'ref': '102vb'},
#   {'ref': '103ra'},
#   {'ref': '103rb'},
#   {'ref': '103va'},
#   {'ref': '103vb'},
#   {'ref': '104ra'},
#   {'ref': '104rb'},
#   {'ref': '104va'},
#   {'ref': '104vb'},
#   {'ref': '105ra'},
#   {'ref': '105rb'},
#   {'ref': '105va'},
#   {'ref': '105vb'},
#   {'ref': '106ra'},
#   {'ref': '106rb'},
#   {'ref': '106va'},
#   {'ref': '106vb'},
#   {'ref': '107ra'},
#   {'ref': '107rb'},
#   {'ref': '107va'},
#   {'ref': '107vb'},
#   {'ref': '108ra'},
#   {'ref': '108rb'},
#   {'ref': '108va'},
#   {'ref': '108vb'},
#   {'ref': '109ra'},
#   {'ref': '109rb'},
#   {'ref': '109va'},
#   {'ref': '109vb'},
#   {'ref': '110ra'},
#   {'ref': '110rb'},
#   {'ref': '110va'},
#   {'ref': '110vb'},
#   {'ref': '111ra'},
#   {'ref': '111rb'},
#   {'ref': '111va'},
#   {'ref': '111vb'},
#   {'ref': '112ra'},
#   {'ref': '112rb'},
#   {'ref': '112va'},
#   {'ref': '112vb'},
#   {'ref': '113ra'},
#   {'ref': '113rb'},
#   {'ref': '113va'},
#   {'ref': '113vb'},
#   {'ref': '114ra'},
#   {'ref': '114rb'},
#   {'ref': '114va'},
#   {'ref': '114vb'},
#   {'ref': '115ra'},
#   {'ref': '115rb'},
#   {'ref': '115ra'},
#   {'ref': '115va'},
#   {'ref': '115vb'},
#   {'ref': '116ra'},
#   {'ref': '116rb'},
#   {'ref': '116va'},
#   {'ref': '116vb'},
#   {'ref': '117ra'},
#   {'ref': '117rb'},
#   {'ref': '117va'},
#   {'ref': '117vb'},
#   {'ref': '118ra'},
#   {'ref': '118rb'},
#   {'ref': '118va'},
#   {'ref': '118vb'},
#   {'ref': '119ra'},
#   {'ref': '119rb'},
#   {'ref': '119va'},
#   {'ref': '119vb'},
#   {'ref': '120ra'},
#   {'ref': '120rb'},
#   {'ref': '120va'},
#   {'ref': '120vb'},
#   {'ref': '121ra'},
#   {'ref': '121rb'},
#   {'ref': '121va'},
#   {'ref': '121vb'},
#   {'ref': '122ra'},
#   {'ref': '122rb'},
#   {'ref': '122va'},
#   {'ref': '122vb'},
#   {'ref': '123ra'},
#   {'ref': '123rb'},
#   {'ref': '123va'},
#   {'ref': '123vb'},
#   {'ref': '124ra'},
#   {'ref': '124rb'},
#   {'ref': '124va'},
#   {'ref': '124vb'},
#   {'ref': '125ra'},
#   {'ref': '125rb'},
#   {'ref': '125va'},
#   {'ref': '125vb'},
#   {'ref': '126ra'},
#   {'ref': '126va'},
#   {'ref': '126vb'},
#   {'ref': '127ra'},
#   {'ref': '127rb'},
#   {'ref': '127va'},
#   {'ref': '128ra'},
#   {'ref': '128rb'},
#   {'ref': '128va'},
#   {'ref': '128vb'},
#   {'ref': '129ra'},
#   {'ref': '129rb'},
#   {'ref': '129va'},
#   {'ref': '129vb'},
#   {'ref': '130ra'},
#   {'ref': '130rb'},
#   {'ref': '130va'},
#   {'ref': '130vb'}]}

# %% [markdown]
# ## Getting the text
#
# Now that we can see what are the available passage, why not getting to the text passages ?
#
# Let see... We build this the same way than the Navigation query ! But instead, we use `document` from the entry point !
#
# ### Getting an excerpt
#
# **Not available at the moment**

# %%
BLorient718_F_1 = requests.get(
    API_URI+BLorient718["dts:passage"]+"&ref=1"
)
print(
    API_URI+BLorient718["dts:passage"]+"&ref=1"
)
print(BLorient718_F_1.text)
# The page seems to buggy at the moment
# Out:
# http://betamasaheft.eu/api/dts/document?id=urn:dts:betmasMS:BLorient718&ref=1
# <?xml version="1.0" encoding="UTF-8"?>
# <TEI xmlns="http://www.tei-c.org/ns/1.0">
#     <dts:fragment xmlns:dts="https://w3id.org/dts/api#"/>
# </TEI>

# %% [markdown]
# ### Getting the whole text
#
# That's nice ! But the text seems fairly small, so why not requesting the whole text ?

# %%
DSEthiop1_full_text = requests.get(
    API_URI+BLorient718["dts:passage"]
)
print(
    API_URI+BLorient718["dts:passage"]
)
print(DSEthiop1_full_text.text)
# Out:
# http://betamasaheft.eu/api/dts/document?id=urn:dts:betmasMS:BLorient718
# <?xml version="1.0" encoding="UTF-8"?>
# <TEI xmlns="http://www.tei-c.org/ns/1.0" xml:id="BLorient718" xml:lang="en" type="mss">
#   <teiHeader>
#     <fileDesc>
#       <titleStmt>
#         <title xml:lang="gez" xml:id="t1"> "Life" and "Miracles" of Lalibala</title>
#
#         <editor role="generalEditor" key="AB"/>
#         <editor key="NV"/>
#         <funder>Akademie der Wissenschaften in Hamburg</funder>
#       </titleStmt>
#       <editionStmt>
#         <p>  </p>
#       </editionStmt>
#       <publicationStmt>
#         <authority>Hiob-Ludolf-Zentrum für Äthiopistik</authority>
#         <publisher>Die Schriftkultur des christlichen Äthiopiens und Eritreas: Eine multimediale Forschungsumgebung / Beta maṣāḥǝft</publisher>
#         <pubPlace>Hamburg</pubPlace>
#         <availability>
#           <licence target="http://creativecommons.org/licenses/by-sa/4.0/"> This file is licensed
#             under the Creative Commons Attribution-ShareAlike 4.0. </licence>
#         </availability>
#       </publicationStmt>
#       <sourceDesc>
#         <msDesc xml:id="ms">
#           <msIdentifier>
#             <repository ref="INS00001BL"/>
#             <collection>Ethiopic Manuscripts </collection>
#             <idno>BL Oriental 718</idno>
#           </msIdentifier>
#           <msContents>
#             <msItem xml:id="ms_i1">
#                 <locus from="1r" to="130vb"/>
#                   <title type="complete" ref="LIT1470GadlaL"/>
#                     <note>Logical articulation of the content (nine items) according to the hypothesis proposed by NV</note>
#
#                     <msItem xml:id="ms_i1.1">
#                           <locus from="1r" to="33va"/>
#                 <title type="complete" ref="LIT4970PoetryLal"/>
#
#       <incipit xml:lang="gez">
#         <locus target="#1r"/>በስመ፡ አብ፡ ወወልድ፡ ወመንፈስ፡ ቅዱስ፡ ፩ አምላክ፡ ሥሉስ፡ ዘኢይሰደቅ፡ ዋሕድ። ዕሩይ፡ ታሉት፡ ዘኢይነፍድ፤ ዘሀሎ፡ እምቅድመ፡ ክዋኒሁ፡ እንዘ፡ ኢይትበዓድ፨
#       </incipit>
#       <explicit xml:lang="gez">
#             <locus target="#33rb"/>ወአመ፡ ይሠራዕ፡ ማዕደ፡ ሕይወት፡ &gt;
#             </explicit>
# <explicit xml:lang="gez" type="supplication">
#     <locus target="#33rb-va"/>
#             ይበለነ፡ ብፁዕ፡ ላሊበላ፡ በይእቲ፡ ሰዓት፡ ነየ፡ አነ፡ ወደቂቅየ፡ ዘወሀበኒ፡ እግዚአብሔር፨ ወያቁመነ፡ ምስሌሁ፡ ቅድመ፡ ገጸ፡ በግዑ፡ ኃቢኦ፡ በጽላሎተ፡ ክነፊሁ፨ ወከዲኖ፡ በመንጦላዕተ፡ ጸላሎቱ፨ ከመ፡ ኢይቅረቡ፡ ኀቤነ፡ መላእክተ፡ እሳት፡ እኁዛነ፡ አስይፍት፡ እለ፡ የዓፅዱ፡ ክርዳደ፡ አርዮሙ፡ እማእከለ፡ ስርናይ፨ ወየዓስርዎሙ፡ በበከላስስቲሆሙ፡ ለአንድዶቶሙ፡ ወለእለ፡ ይፈልጥዎሙ፡ ለኃጥአን፡ እማእከሎሙ፡ ለጻድቃን፨ ወለእለ፡ ይሌልይዎሙ፡ ለጸዋጋን፡ እማእከሎሙ፡ ለየዋሃን፨ ወእሉ፡ መላእክተ፡ መዓት፡ ከመ፡ ኢይቅረቡ፡ ኀቤነ፡ ወከመ፡ ኢይፍልጡነ፡ እምኔሁ፡ ይመግበነ፡ ሐቂፎ፡ በየማነ፡ እዴሁ፨ወያድኅና፡ እመከራ፡ ሥጋ፡ ወነፍስ፨  ለአመተ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወይዕቀባ፡ ለወለታ፡ ኂሩተ፡ ሥላሴ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#
#       </explicit>
#       </msItem>
#                 <msItem xml:id="ms_i1.2">
#                       <locus from="33vb" to="115rb"/>
#                   <title type="complete" ref="LIT4922HagVit"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#33vb"/>ንትመየጥኬ፡ ኀበ፡ ጥንተ፡ ገድሉ፡ ለዝንቱ፡ ዕፍረቱ፡ ምዑዝ፡ ከመ፡ ኢይምሰሎ፡ ዝንጋዔ፡ ለልበ፡ አብድ፡ ለዘኢያፈቅር፡ ውዳሴሆሙ፡ ለጻድቃን፡
#                 </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#115rb"/> ወከመዝ፡ ነበረ፡ በኵሉ፡ መዋዕለ፡ ሕይወቱ፡ እምአመ፡ ነግሠ፡ እስከ፡ አመ፡ ፈለሰ።
#                 </explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.3">
#                 <locus from="115rb" to="116vb"/>
#                 <title type="complete" ref="LIT4924HagMir1"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#115rb"/>ወእምዝ፡ ኮነ፡ አሐተ፡ ዕለተ፡ እንዘ፡ ይፈቅድ፡ ላሊበላ፡ ከመ፡ ይደረር፡ መጽኡ፡ ሠለስቱ፡
#                   አኃው፡  ቅሩበ፡ ጽርሐ፡ መንግሥቱ፡ ኀበ፡ ይረፍቅ፡ ውእቱ። </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#116va"/> ወእግዚእነኒ፡ ይኄውጾሙ፡ ወይትአነገድ፡ ውስተ፡ ቤቶሙ፡ ለእለ፡ ያፈቅሩ፡ ነግደ፡ በከመ፡ ተአንገደ፡ ውስተ፡ ቤቱ፡ ለአብርሃም፡ ወይባርኮሙ፡ በከመ፡ ባረኮ፡ ሎቱ፡ ወለዘርኡ፡ ወበከመ፡ ባረኮ፡ ለገብረ፡ መስቀል።
# <title>ዝንቱኬ፡ ውእቱ፡ መንክራቲሁ፡ ለገብረ፡ መስቀል፡ ዘጾረ፡ ክበደ፡ ጽሙና፡ ወክበድ፡ ጽምእ። </title>እስመ፡ ኢበልዓ፡ በመዋዕለ፡ መንግሥቱ፡ ዘእንበለ፡ ሠለስቱ፡ አፍእምት፡ ወኢሰትየ፡ ዘእንበለ፡ አሐቲ፡ ጽዋዕ።
#                 </explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.4">
#                 <locus from="116vb" to="119ra"/>
#                 <title type="complete" ref="LIT4925HagMir2"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#116va"/>ወኮነ፡ በአሐዱ፡ እመዋዕል፡ እንዘ፡ ያመጽኡ፡ ለገብረ፡ መስቀል፡ ጸባሕቶ፡ ለነጋሢ፡ ዘከመ፡
#                   ይደልዎ፡ ለንጉሥ። ከመ፡ የሀቡ፡ ወያወፍዩ፡ ግብሮሙ፡ ዘይረክቦሙ፡ ነሥኡ፡ ብዙኃ፡ መቃጽወ፡ እለ፡ ምሉዓን፡ መዓረ፡ ወፀዊሮሙ፡ በጽሑ፡ ኀበ፡ ሐይቀ፡ ፈለግ፡ ዘይወርድ፡ በኃይል፡</incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#119ra"/> በከመ፡ ዓቀቦ፡ ለዮናስ፡ በውስተ፡ ከርሠ፡ አንበሪ። ወከማሁ፡ ዓቀቦን፡ ለእማንቱ፡ ግምዔያተ፡ መዓር። በኃይለ፡ ጸሎቱ፡ ለላሊበላ፡</explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.5">
#                 <locus from="119rb" to="120va"/>
#                 <title type="complete" ref="LIT4926HagMir3"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#119rb"/>ወኮነ፡ ካዕበ፡ በአሐዱ፡ ዕለት፡ እመዋዕል፡ ተርእየ፡ <title>መንክረ፡ ትሕትና፡</title> በላዕለ፡ ገብረ፡ መስቀል፡
#                   እንዘ፡ ንጉሥ፡ ውእቱ፡ ዘተመሰለ፡ ነዳየ፡ </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#120rb"/>ወገብረ፡ መስቀል፡ እንዘ፡ ሀሎ፡ ውስተ፡ መንበረ፡ መንግሥቱ፡ ኢበልዓ፡ ወኢሰትየ፡ ለፍትወተ፡ ሥጋሁ፡ ከመ፡ ይኩን፡ ፍግዓሁ፡ ፍጹመ፡ በእደ፡ መርዓ፡ ዘኢየኃልፍ፡ በሰማያት። </explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.6">
#                 <locus from="120va" to="122rb"/>
#                 <title type="complete" ref="LIT4927HagMir4"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#120va"/>ወዓዲ፡ ኮነ፡ በአሐዱ፡ እመዋዕል። ወሀሎ፡ ውስተ፡ አሐተ፡ ሀገር፡ እምአህጉራተ፡ መንግስቱ፡
#                   አሐዱ፡ ዓላዊ፡ ዘዓከዎ፡ ለገብረ፡ መስቀል፡ ንጉሥ፡ መሲሐውያን፡ </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#122rb"/>  ወበእንተዝ፡ ሞተ፡ እስመ፡ ጸዓለነ። ርእዩኬ፡ ኦፍቁራንየ፡ ዘከመዝ፡ መድምመ፡ ዘተገብረ፡ በኃይለ፡ ጸሎቱ፡ ለገብረ፡ መስቀል፡ ወራእየሂ፡ ዘርእየ፡ እንዘ፡ ሀሎ፡ ርኁቀ። እስመ፡ በከመ፡ ይሬኢ፡ አምላኮሙ፡ ይሬእዩ፡ መምለክያኒሁ። እስመ፡ መንፈስ፡ ቅዱስ፡ ዘላዕሌሆሙ፡ ይከሥት፡ ሎሙ፡ ኵሎ፡ ኅቡአተ። </explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.7">
#                 <locus from="122va" to="122vb"/>
#                 <title type="complete" ref="LIT4928HagMir5"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#122va"/>ወአሐቲኒ፡ ዕለተ፡ ዘአርአየ፡ መንክራቲሁ፡ ገብረ፡ መስቀል፡ እፈቅድ፡ እንግርክሙ። ወሀለወት፡
#                   አሐቲ፡ ብእሲት፡ ብዕልት። ወእንዘ፡ ትዴረር፡ ወትበልዕ፡ ሥጋ፡ እንስሳ፡ አኃዘት፡ ትብላዕ፡ ሥጋ፡ ሰብእኒ፡ ዘበሐሜት። </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#122vb"/> ወዘንተ፡ ሶበ፡ ትቤ፡ ወፅአ፡ ውእቱ፡ ምታረ፡ ሥጋ፡ ምስለ፡ ደመ፡ ጕርዔሃ፡ ወወድቀ፡ ውስተ፡ ምድር። </explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.8">
#                 <locus from="122vb" to="123vb"/>
#                 <title type="complete" ref="LIT4929HagMir6"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#122vb-123ra"/>ወካዕበ፡ አሐተ፡ ዕለተ፡ አኃዘ፡ ይጽርፍ፡ ሎቱ፡ አሐዱ፡ ብእሲ፡ ለላሊበላ፡ እንዘ፡ የሐምዮ። ወብእሲቱሰ፡ ለውእቱ፡ ብእሲ፡ ተቤሎ፡ ኢትጽርፍ፡ ላዕለ፡ ገብረ፡ እግዚአብሔር፡ ወመሲሐ፡ እግዚአብሔር፡ ወእቱ፡ ዓዲ። </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#123va"/> ያድኅነነኬ፡ እግዚአብሔር፡ እስመ፡ እምዘ፡ ከመዝ፡ ልማድ፡ እስመ፡ ጳውሎስኒ፡ ይሜህረነ፡ ከመ፡ ኢንርግም፡ እስከ፡ ለሰይጣን፡ አኮ፡ ኃዚኖ፡ ለሰይጣን፡ ዘይሜህር፡ ከመዝ፡ አላ፡ ከመ፡ ኢንልክፎ፡ ጥቀ፡ ለመርገም፡ በልሳንነ፡ ከመ፡ ኢንድኃጽ፡ ላዕለ፡ እኁነ።  </explicit>
#               </msItem>
#               <msItem xml:id="ms_i1.9">
#                 <locus from="123vb" to="130vb"/>
#                 <title type="complete" ref="LIT4930HagVirt"/>
#                 <incipit xml:lang="gez">
#                   <locus target="#123vb"/>ስምዑኬ፡ ኦፍቁራንየ፡ እንግርክሙ፡ ዘከመ፡ ኮነ፡ ግብረ፡ ፀአቶን፡ ለእላንቱ፡ አብያተ፡
#                   ክርስቲያናት፡ እምልበ፡ ምድር። </incipit>
#                 <explicit xml:lang="gez">
#                   <locus target="#130rb"/>ናሁኬ፡ ለካእኩ፡ ለክሙ፡ ኦፍቁራንየ፡ ንስተተ፡ <title>ዜና፡ እምትሩፋቲሁ፡ ለገብረ፡ መስቀል፡</title> ከመ፡ ይትፈሣሕ፡ ልብክሙ፡ ወይኩነነ፡ ለኵልነ፡ እለ፡ ተጋበእነ፡ ዝየ።</explicit>
#               </msItem>
#             </msItem>
#           <msItem xml:id="ms_i2">
#             <locus from="1r" to="130vb"/>
#             <title type="complete" ref="LIT1470GadlaL"/>
#             <note>Physical  articulation of the content proposed by the scribe</note>
#             <msItem xml:id="ms_i2.1">
#               <incipit xml:lang="gez">
#                 <title>Creation of the world by the Holy Trinity</title>
#                 <locus target="#1r"/>በስመ፡ አብ፡ ወወልድ፡ ወመንፈስ፡ ቅዱስ፡ ፩ አምላክ፡ ሥሉስ፡ ዘኢይሰደቅ፡ ዋሕድ። ዕሩይ፡ ታሉት፡ ዘኢይነፍድ፤ ዘሀሎ፡ እምቅድመ፡ ክዋኒሁ፡ እንዘ፡ ኢይትበዓድ፨
#               </incipit>
# <explicit xml:lang="gez">
#   <title/>
#   <locus target="#5vb"/>እንዘ፡ አብ፡ ይረድእ፡ ለወጢን፡ በለብዎ፡ ወእንዘ፡ ወልድ፡ ያጸንዕ፡ በአስተሰናእዎ፨ ወመንፈስ፡ ቅዱስ፡ እንዘ፡ ይከውን፡ ፈጸሜ፡ ኃይለ፡ ቃል፡ በአስተታልዎ፨ በሰላመ፡ ዚ
# አሁ፡ አሜን፨
# </explicit>
# <explicit xml:lang="gez" type="supplication">
#   <locus target="#5vb"/>ጸሎቱ፡ ወበረከቱ፡ ወሀብተ፡ ረድኤቱ፡ ለዝንቱ፡ ብፁዕ፡ የሃሉ፡ ምስለ፡ ፍቅርቱ፡ ንግሥትነ፡ ወለተ፡
#     ኢየሱስ፡ ወምስለ፡ ወልዳ፡ መስፍን፡ ኃይለ፡ ኢየሱስ፡ ለዓለመ፡ ዓለም፡ አሜን፨
# </explicit>
# <note>Text contained on f.1r, line 1 up to f.5vb, line 21 is to be found in Perruchon's edition on page 1, line 1 up to page 7, line 18 (‘Introduction’.). In this description by counting lines I disregarde any extra notes or punctuation in the manuscript and titles in Perruchon's edition. The beginning is marked as monthly reading for the 12th of Sane. The first folio recto is layouted with red inks. It ends with supplication on f.5vb and marked with a cross. </note>
# </msItem>
# <msItem xml:id="ms_i2.2">
#     <title>Christology and Lālibalā</title>
# <incipit xml:lang="gez">
# <locus target="#6ra"/>አቀድም፡ አእኵቶቶ፡ ለእግዚአብሔር፡ በእንተ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ዝውእቱ፡ ወልዱ፡ ወቃሉ፡ ለአብ፡ ዘበሕፅነ፡ አቡሁ፡ ሠረፀ፡ ፍሬ፡ ስብሐት፡ ዓቃቤ፡ ሥራይ፡ ዘወረደ፡ እምሰማያት፡ ከመ፡ ይደይ፡ ርጢኖ፡ ዲበ፡ እለ፡ ቈስሉ፡ በንስከተ፡ አርዌ፡ አስዋር፡ ወአልህምተ፨
# </incipit>
# <explicit xml:lang="gez">
#     <locus target="#8va"/>ፍሬ፡ ተመርትኒ፡ ካልእ፡ አርአያሁ፡ ወአምሳሊሁ፡ ወጣዕመ፡ መዓዛሁ፡ ወፍሬ፡ መልጰጶንሂ፡ ካልእ፡ አርአያሁ፡ ወአምሳሊሁ፨ ወፍሬ፡ ዕንጐታትሂ፡ ካልዕ፡ አርአያሁ፡ ወአምሳሊሁሙ፨
#     </explicit>
#     <note>Text contained on f.6ra, line 1 up to f.8va, line 15 is to be found in Perruchon's edition on page 7, line 19 up to page 10, line 25 (‘Seconde Introduction’.). It starts on the new page and new line, lines 1,2,5,6 are written with red inks. The end is marked with three  ፨ and dotted line. </note>
#   </msItem>
#   <msItem xml:id="ms_i2.3">
#       <title>Praise of King Lālibalā's virtues.</title>
#     <incipit xml:lang="gez">
#       <locus target="#8vab"/>ወከማሁኬ፡ ዝንቱኒ፡ ብእሴ፡ አምላክ፡ ላሊበላ፡ እንዘ፡ ንጉሥ፡ ውእቱ፡ ዘተመሰለ፡ ወዓሌ፨ እንዘ፡ እግዚአ፡ ነባርያን፡ ዘተመሰለ፡ ነባሬ፨ እንዘ፡ እግዚአ፡ መኳንንት፡ ተመሰለ፡ ተኰናኔ፨
# </incipit>
# <explicit xml:lang="gez">
#   <locus target="#17rb-va"/>ወለነኒ፡ የሀበነ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ሰይፈ፡ ረድኤት፡ በከመ፡ ወሀቦ፡ ለላሊበላ፡ ሰይፈ፡ መዊዕ፡ ከመ፡ ይውቂ፡ ክሣዶ፡ ለዝንቱ፡ አርዌ፡ ርጉም፡ ወይረስየነ፡ ለነኒ፡ ከመ፡ ናውቂ፡ ክሣዶ፡ በከመ፡ አውቀዮ፡ ውእቱ፡ አሜን፨
# </explicit>
# <note>The text starts on the new line and first two lines are written with red inks. The end is defined by "Amen" and the beginning of the following text written with red inks. </note>
# </msItem>
# <msItem xml:id="ms_i2.4">
#   <title>Praise of King Lālibalā's virtues.</title>
#   <incipit xml:lang="gez">
#
#     <locus target="#17va"/>ወዝንቱሰ፡ ብእሲ፡ ክቡር፡ ኮከብ፡ ፅዱል፡ ዘያንሶሱ፡ መልዕልተ፡ ዓየር፡ በጢሎ፡ እምሕሊና፡ ዘበምድር፨ አልቦ፡ ዘገብረ፡ ምግባራተ፡ ዘያምዕዖ፡ ለመንፈሰ፡ ለእግዚአብሔር።
# </incipit>
# <explicit xml:lang="gez">
# <locus target="#18vb"/>በከመ፡ ይቤ፡ እግዚእነ፡ አልቦ፡ ዘይእኅዝ፡ ፅርፈ፡ ወየሐርስ፡ ድኅሪተ፨ ወይከውን፡ ድልወ፡ ለመንግሥተ፡ ሰማያት፨ ርትዕት፡ ይእቲ፡ መንግሥተ፡ ሰማያት፨ ወዘንተ፡ ሰሚዖ፡ ኮነ፡ ሐረሳዊ፡ ዘመንፈስ፨ እስመ፡ ሰሚዖ፡ ሰብእ፡ ቃለ፡ ሕይወት፡ የሐውር፡ በፍኖተ፡ ሕይወት፨
# </explicit>
# <explicit xml:lang="gez" type="supplication">
#                                     <locus target="#18vb"/>
# ወበዝንቱ፡ ቃለ፡ ሕይወት፡ ዕቀባ፡ ለንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወዕቀቦሙ፡ ለውሉዳ፡ ኃይለ፡
# ኢየሱስ፡ ኃይለ፡ ሚካኤል፡ ወልደ፡ ማርያም፡ ወለአዋልዲሃ፡ ወለተ፡ ማርያም፡ ኂሩተ፡ ሥላሴ፡ ለዓለመ፡ ዓለም፡ አ፤
# </explicit>
#       <note>First two lines are written with red inks.The text ends with a supplication note.</note>
#     </msItem>
#     <msItem xml:id="ms_i2.5">
#         <title>Praise of King Lālibalā's virtues.</title>
# <incipit xml:lang="gez">
#   <locus target="#19ra"/>ወቅዱስኒ፡ ወብፁዕ፡ ላሊበላ፡ አኮ፡ ሰሚዖ፡ ቃለ፡ መንፈስ፡ ዘየኀድግ፡ ዘእንበለ፡ ይግበር፡ እስመ፡ ይፈርህ፡ ቃለ፡ ሐዋርያ፡ ዘይቤ፡ እመቦ፡ ዘያጸምዖ፡ ለቃል፡ ወኢይገብሮ፨
# </incipit>
# <explicit xml:lang="gez">
#   <locus target="#19vb-20ra"/>እስመ፡ ይቤ፡ ጥበቡ፡ እንከ፡ ወአጥብቡ፡ ልበክሙ፨ እስመ፡ ጸላኢክሙ፡ ጋኔን፡ ይጥሕር፡ ከመ፡ አንበሳ፡ ወየኃሥሥ፡ ዘይውኅጥ፨ ወቆመ፡ ዲበ፡ ኰኵሐ፡ ሃይማኖት፡ ዘኢያንቀለቅል፡ መሠረቱ፡ በኃይለ፡ ነፋሳት፨ እለ፡ እሙንቱ፡ ዓላውያን፡ እለ፡ አውከኩ፡ እምጽድቅ፨ ወተዓተቱ፡
# እምርትዕ፡ ወእምሃይማኖት፡ መንክር። በከመ፡ ይቤ፡ አጽንዑ፡ ቀዊመ፡ በሃይማኖትክሙ፨
# </explicit>
# <note>The beginning is marked as monthly reading for the 12th of Ḥāmle. The text starts on the new page and new line, first two lines are written with red inks. The end is defined by the left space.</note>
#     </msItem>
#         <msItem xml:id="ms_i2.6">
#             <title>Praise of King Lālibalā's mercy.</title>
#           <incipit xml:lang="gez">
# <locus target="#20ra"/>ወኮነ፡ ልቡ፡ ጽሌ፡ ዘሕግ፡ ዘይሜህር፡ ርትዓ፡ ወምጽዋተ፡ ወምሒረ፡ ነዳያን፡ ወሰርየ፡ ለአባስያን፨ በከመ፡ ይቤ፡ እግዚእነ፡ በወንጌል። ለእመ፡ አበሰ፡ ለከ፡ እኁከ፡ ኅድግ፡ ሎቱ፡ ስብዓ፡ በበስብዕ፨
#           </incipit>
#           <explicit xml:lang="gez">
# <locus target="#21va"/>ናሁ፡ ከመ፡ አዕይንተ፡ አግብርት፡ ውስተ፡ እደ፡ አጋአዝቲሆሙ፡ ወከመ፡ ዓመት፡ ውስተ፡ እደ፡ እግዝታ፨ ከማሁ፡ አዕይንቲነ፡ ኀበ፡ እግዚአብሔር፡ አምላክነ፨ እስከ፡ አመ፡ ይሠሃለነ፨
#           </explicit>
#           <note>The text starts on the new line and first two lines are written with red inks. The end is defined by the left space.</note>
#         </msItem>
#   <msItem xml:id="ms_i2.7">
#       <title>Comparison of King Lālibalā to the angels.</title>
# <incipit xml:lang="gez">
#   <locus target="#21va"/>ወበዝ፡ ካዕበ፡ ላሊበላ፡ ብፁዕ፡ ንጉሠ፡ ኢትዮጵያ፡ ወምክሐ፡ ኵሉ፡ አድያሚሃ፡ ተመሰሎሙ፡ ለትጉሃነ፡ ሰማይ፨ እስመ፡ ኢወሀበ፡ ንዋመ፡ ለአዕይንቲሁ፨ ወኢድቃሰ፡ ለቀራንብቲሁ፨
# </incipit>
# <explicit xml:lang="gez">
#   <locus target="#23vb"/>ሐፀነቶ፡ መርዓተ፡ ንጉሥ፡ ሰማያዊ፡ እስመ፡ አእመረት፡ ከመ፡ ይከውና፡ ወልዳ፡ ዘምክህ፡ ዘይትሜካህ፡ በፍናዊሃ፡ ወበኃሢሠ፡ ሕገጊሃ፨ በከመ፡ ትቤ፡ ሐና፡ እመ፡ ሳሙኤል፡ ወዘሰ፡ ይትሜካህ፨ በአእምሮ፡ ወበለብዎ፡ እግዚአብሔር፨ በገቢረ፡ ፍትሕ፡ ወጽድቅ፡ በማእከለ፡ ምድር፨
# </explicit>
# <note>The text starts on the new line and first two lines are written with red inks. The end is defined by the left space </note>
#   </msItem>
#       <msItem xml:id="ms_i2.8">
#           <title>Praise of King Lālibalā</title>
# <incipit xml:lang="gez">
#     <locus target="#23vb-24ra"/>ወላሊበላኒ፡ አፍቀረ፡ አጥባቲሃ፡ ለዘሐፀነቶ፡ እስመ፡ ይጥዕሞ፡ አጥባቲሃ፡ እምወይን፡ ወአፈዋቲሃኒ፡ ይምዕዝ፡ እምኵሉ፡ ዕፍረታት፡ በከመ፡ ይቤ፡ ሰሎሞን፡ በውስተ፡ መኃልየ፡ መኃልይ፡ አዳም፡ አጥባትኪ፡ እምወን፨
# </incipit>
# <explicit xml:lang="gez">
#   <locus target="#31rb"/>ፍትወቱ፡ ለሥጋ፡ ወፍትወቱ፡ ለዓይን፡ ወስራሑ፡ ለመንበርት፡ ኢኮነ፡ ዝንቱ፡ እምኀበ፡ እግዚአብሔር፨ አላ፡ እምዓለም፡ ወዓለምኒ፡ የኃልፍ፡ ወፍትወቱኒ፨  ወዘሰ፡ ይገብር፡ ፈቃዶ፡ ለእግዚአብር፡ ይነብር፡ ለዓለም፨
# </explicit>
# <note>The text starts on the new line and first two lines are written with red inks. The text marked with three kind of ፨</note>
#       </msItem>
#       <msItem xml:id="ms_i2.9">
#           <title>Humility of Lālibalā</title>
# <incipit xml:lang="gez">
#   <locus target="#31rb"/>ወበእንተ፡ ዝንቱ፡ ብፁዕ፡ ወቅዱስ፡ ላሊበላ፡ ኢጥዕመ፡ ግሙራ፡ እምፍግዕቶሙ፡ ለኃጥአን፡ ወኢእምአልባሰ፡ ቀጠንት፡ ወኢእማዕድ፡ ጥዕማት፨ እንዘ፡ ይሴፎ፡ በሊዓ፡ እማዕደ፡ ሕይወት፨
#   </incipit>
#   <explicit xml:lang="gez">
#     <locus target="#32rb-va"/>በዝንቱኬ፡ ቃላት፡ ወበፍቅረ፡ መንፈስ፡ ቅዱስ፡ ተወርዚዎ፡ ብፁዕ፡ ላሊበላ፡ ዝኅዙኃ፡ ገድል፡ ተወካፌ፡ ምንዳቤ፡ ሥጋ፡ ከመ፡ ይኩን፡ ሥሉጠ፡ ላዕለ፡ ዕፀ፡ ሕይወት፨ በከመ፡ ይቤ፡ ቴዎጎሎስ፡ ወልደ፡ ነጐድጓድ፨ ብፁዓን፡ እለ፡ ያነጽሑ፡ አልባሲሆሙ፨ ከመ፡ ይኩን፡ ሥልጣኖሙ፡ ላዕለ፡ ዕፀ፡ ሕይወት፨ አመ፡ ይሰደዱ፡ ወይወፅኡ፡ አፍአ፡ ሐምስቱ፡ አክላብ፡ እሉ፡ እሙንቱ፡ መሠርያን፡ ወዘማውያን፡ ወቀታልያን፡ ወእለ፡ ያጣዕው፡ ወኵሎሙ፡ እለ፡ ያፈቅሩ፡ ግብረ፡ ሐሰት፨ ወእሉ፡ አመ፡ ይወፅኡ፡ እምከብካበ፡ መርዓ፡ መንገለ፡ አፍአ፨
#     </explicit>
#     <note>The text starts on the new line and first two lines are written with red inks.  The end is defined by the beginning of the following text written with red inks on the new line. </note>
#   </msItem>
# <msItem xml:id="ms_i2.10">
#     <title>Lālibalā dwells in the Heavenly Kingdom.</title>
# <incipit xml:lang="gez">
#   <locus target="#32va"/>ወውእቱሰ፡ ላሊበላ፡ ይበውእ፡ ተጸዊዖ፡ በቃለ፡ መርዓዊ፡ ሰማያዊ፡ ዘይብል፡ ንዑ፡ ኀቤየ፡ ቡሩካኑ፡ ለአቡየ፡ ትረሱ፡ መንግሥተ፡ ሰማያት፡ ዘአስተዳለወ፡ ለክሙ፡ እምቅድመ፡ ይትፈጠር፡ ዓለም፨
# </incipit>
# <explicit xml:lang="gez">
# <locus target="#33ra"/>ወለጻድቃኒሁ፡ ቡሩካን፨ እለ፡ ፆሩ፡ ክበዳ፡ ወላህባ፡ ለዕለት፨
# </explicit>
# <explicit xml:lang="gez" type="supplication">
# <locus target="#33ra-va"/>ወለነኒ፡ አሥራተ፡ ምሕረት፡  ይንሥአነ፡ ምክሀ፡ ኵልነ፡ ብፁዕ፡ ላሊበላ፡ ከመ፡ ንባእ፡ ምስሌሁ፡ ኀበ፡ ቦአ፡ ላሊሁ፨ ወከመ፡ ንርፍቅ፡ ኀበ፡ ረፈቀ፡ ውእቱ፡ ከመ፡ ንሳተፎ፡ በፍሥሐሁ፨ ወከመ፡ ንደለው፡ በተድላሁ፨ ወከመ፡ ናንሶሱ፡ ውስተ፡ ቤተ፡ መርዓ፡ ሐዳስ፨ ዘኢይበውእ፡ ውስቴታ፡ ዘኢለብሰ፡ ልብሰ፡ ከብካብ፡ መርዓ፡ ወዘኢተሠርገወ፡ በብርሃነ፡ ሥላሴ፡ ወአመ፡ ይሠራዕ፡ ማዕደ፡ ሕይወት፡ ይበለነ፡ ብፁዕ፡ ላሊበላ፡ በይእቲ፡ ሰዓት፡ ነየ፡ አነ፡ ወደቂቅየ፡ ዘወሀበኒ፡ እግዚአብሔር፨ ወያቁመነ፡ ምስሌሁ፡ ቅድመ፡ ገጸ፡ በግዑ፡ ኃቢኦ፡ በጽላሎተ፡ ክነፊሁ፨ ወከዲኖ፡ በመንጦላዕተ፡ ጸላሎቱ፨ ከመ፡ ኢይቅረቡ፡ ኀቤነ፡ መላእክተ፡ እሳት፡ እኁዛነ፡ አስይፍት፡ እለ፡ የዓፅዱ፡ ክርዳደ፡ አርዮሙ፡ እማእከለ፡ ስርናይ፨ ወየዓስርዎሙ፡ በበከላስስቲሆሙ፡ ለአንድዶቶሙ፡ ወለእለ፡ ይፈልጥዎሙ፡ ለኃጥአን፡ እማእከሎሙ፡ ለጻድቃን፨ ወለእለ፡ ይሌልይዎሙ፡ ለጸዋጋን፡ እማእከሎሙ፡ ለየዋሃን፨ ወእሉ፡ መላእክተ፡ መዓት፡ ከመ፡ ኢይቅረቡ፡ ኀቤነ፡ ወከመ፡ ኢይፍልጡነ፡ እምኔሁ፡ ይመግበነ፡ ሐቂፎ፡ በየማነ፡ እዴሁ፨ወያድኅና፡ እመከራ፡ ሥጋ፡ ወነፍስ፨  ለአመተ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወይዕቀባ፡ ለወለታ፡ ኂሩተ፡ ሥላሴ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#
# </explicit>
# <note>The text starts on the new line and first two lines are written with red inks. It ends with a supplication note. The end is marked with three  ፨ and dotted line.</note>
# </msItem>
# <msItem xml:id="ms_i2.11">
#     <title>How important is to venerate saints.</title>
# <incipit xml:lang="gez">
#   <locus target="#33vb"/>ንትመየጥኬ፡ ኀበ፡ ጥንተ፡ ገድሉ፡ ለዝንቱ፡ ዕፍረቱ፡ ምዑዝ፡ ከመ፡ ኢይምሰሎ፡ ዝንጋዔ፡ ለልበ፡ አብድ፡ ለዘኢያፈቅር፡ ውዳሴሆሙ፡ ለጻድቃን፡ ወለዘ፡ ኢይትጌበር፡ ለረብሐ፡ መንፈስ፨ እስመ፡ ቦእምውስተ፡ ሕዝብ፡ እለ፡ ያንጐረጕሩ፡ ሶበ፡ ይሰምዑ፡ ኑኃ፡ ውዳሴሆሙ፡ ለጻድቃን፨
#   </incipit>
#   <explicit xml:lang="gez">
#   <locus target="#34vb-35ra"/>ወሶቤሃ፡ ይትፌሣሕ፡ ሰይጣን፡ ምስለ፡ አጋንንቲሁ፡ እስመ፡ በሀብለ፡ ሀኬት፡ አሲሮ፡ አውፅኦሙ፡ ወይኤምኆሙ፡ ሐቂፎ፡ ክሣዶ፡ ከመ፡ ዘይኤምኅ፡ አብ፡ ወልዶ፡ ፍቁሮ፨ ወይተልዎሙ፡ ኀበ፡ ሖሩ፡ እንዘ፡ ይሜግብዎሙ፡ አጋንንቲሁ፡ ይምነ፡ ወጽግመ፡ ከዋላ፡ ወፍጽመ፡
#   </explicit>
#   <explicit xml:lang="gez" type="supplication">
#   <locus target="#34vb-35ra"/>  ያድኅነነ፡ እግዚአብሔር፡ እመክፈልቶሙ፡ ለእሉ፨ ወያጽሕቅ፡ ልበነ፡ ለሰሚዓ፡ ቃላቲሁ፡ ወለገቢረ፡ ትእዛዛቲሁ፨ ወይረስየነ፡ ድልዋነ፡ ከመ፡ ንኅድር፡ ውስተ፡ ቤቱ፨ ወከመ፡ ንጻመድ፡ ውስተ፡ ቤተ፡ መቅደሱ፡ በኵሉ፡ መዋዕለ፡ ሕይወትነ፨ ወያርእየነ፡ በዘኖሠምሮ፡ ሎቱ፡ በኃይለ፡ ጸሎቱ፡ ለዝንቱ፡ ፀሐየ፡ ጽድቅ፡ ዘስሙ፡ ላሊበላ፡ ወይዕቀባ፡ ለአመተ፡ እግዚአብሔር፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#
#     </explicit>
#   <note>The beginning is marked as monthly reading for the 12th of Naḥāse. The text starts in the new column and new line, lines 1, 2, 5, 6 are written with red inks. It ends with a supplication note. The end is marked with dotted line. </note>
#   </msItem>
#   <msItem xml:id="ms_i2.12">
#       <title>Preamble to the life of Lālibalā.</title>
#   <incipit xml:lang="gez">
#       <locus target="#35ra"/>ስምዑኬ፡ ኦፍቁራንየ፡ እለ፡ ተኃሥሡ፡ በረከተ፡ ጸጋሁ፡ ለጻድቅ፡ ወእለ፡ ትፃምው፡ ለፍቅረ፡ ላሊበላ፡ ከመ፡ ትርወዩ፡ እምነቅዓ፡ ገድሉ፡ ጥዑም፨
#     </incipit>
#     <explicit xml:lang="gez">
#         <locus target="#35va"/>እንዘ፡ ታከብርዎ፡ ከመ፡ መላእክት፨ ወከመ፡ ነቢያት፡ ወሐዋርያት፨ ወከመ፡ ጻድቃን፡ ወሰማዕት፡ ወከመ፡ ደናግል፡ ወመነኮሳት፨ እስመ፡ ውእቱኒ፡ ኢሐፀ፡ እምኔሆሙ፨
#     </explicit>
#       <explicit xml:lang="gez" type="supplication">
#           <locus target="#35va-vb"/>ጸሎቱ፡ ወስእለቱ፡ ወሀብተ፡ ረድኤቱ፡ ወበረከተ፡ ተስፋሁ፡ የሃሉ፡ ምስለ፡ አመተ፡ እግዚአብሔር፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ወምስለ፡ ኵልክሙ፡ ዝየ፡ እለ፡ ሀለውክሙ፡ ዝየ፡ ወእለ፡ መጻእክሙ፡ እምርኁቅ፡ ወእምቅሩብ፨ እንዘ፡ ትትአመኑ፡ በጽላሎተ፡ ክነፊሁ፡ ወውእቱኒ፡ ኢይርኃቅ፡ እምኔክሙ፨ ለዓለመ፡ ዓለም፡ አሜን፨
#           </explicit>
#     <note>The text contained on f.35ra, line 3 up to f.35vb, line 7 is to be found in Perruchon's edition on page 11, line 1 up to line 22 (‘L'auteur commence a raconter la vie de Lalibala’.).The text starts on the new line and first two lines are written with red inks. It ends with a supplication note. The end is marked with dotted line.</note>
#     </msItem>
#     <msItem xml:id="ms_i2.13">
#         <title>How Lālibalā was born in Roḥā.</title>
# <incipit xml:lang="gez">
# <locus target="#35vb"/>ወሀለወት፡ አሐቲ፡ ሀገር፡ እምአህጉራተ፡ ኢትዮጵያ፡ እንተ፡ ትሰመይ፡ ሮሐ፡ ሀገረ፡ ሙላዱ፡ ለብፁዕ፡ ላሊበላ፡
# </incipit>
# <explicit xml:lang="gez">
#   <locus target="#37rb"/>አላ፡ መላእክት፡ እሙንቱ፡ እለ፡ ተመሰሉ፡ አንህብተ፡ እንዘ፡ ያኤምሩ፡ ንግሦ፨ ወጸቃውዓተ፡ ምግባር፡ ዘይትቀዳሕ፡ እምኔሁ፨ እስመ፡ ሀለዎ፡ ለብፁዕ፡ ላሊበላ፡ ከመ፡ ይልበስ፡ ወይፈጽም፡ ዘንተ፡ ኵሎ፡ ትንቢታተ፡ ዘበምድር፡ እንተ፡ ይእቲ፡ ምግባረተ፡ ጽድቅ፨
#   </explicit>
# <note>The text contained on f.35vb, line 8 up to f.37rb, line 19 is to be found in Perruchon's edition on page 12, line 1 up to page 13 line 21 (‘Naissance de Lalibala’.). The text starts on the new line and first two lines are written with red inks. The end is marked with three  ፨. </note>
#     </msItem>
#     <msItem xml:id="ms_i2.14">
#       <title>How Lālibalā grew up in a beautiful man.</title>
# <incipit xml:lang="gez">
#     <locus target="#37rb-va"/> ወእምዝ፡ ልሕቀ፡ እንዘ፡ የሐፅኖ፡ መንፈስ፡ ቅዱስ፡ ወያጸንዖ፡ በኃይል፡ ወበጥበብ፡ ወበምክር፡ ወበግርማ፡ መንክር፨ ወኵለንታሁኒ፡ አዳም፡ ውእቱ፨
#   </incipit>
#   <explicit xml:lang="gez">
#     <locus target="#39rab"/> ወይቤሉ፡ ሀለዎ፡ ይኩን፡ ንጉሠ፡ አመ፡ ልሕቀ፡ ዝንቱ፡ ውእቱ፡ ቀዳሜ፡ መንክራት፡ ዘኮነ፡ በላዕለ፡ ብፁዕ፡ ላሊበላ፡ ዘተቀብዓ፡ ኃይለ፡ ውስተ፡ ቈናዝዓ፡ ድማሁ፡ ከመ፡ ሶምሶን፡ ቃዴ፡ እስራኤል፡ እስመ፡ ናዝራዊሁ፡ ለእግዚአብሔር፡ ቅዱስ፡ ውእቱ፨
#   </explicit>
#     <explicit xml:lang="gez" type="supplication">
#         <locus target="#39rb"/> ጸሎቱ፡ ወስእለቱ፨ ወሀብተ፡ ረድኤቱ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ወይባርከመ፡ ለኵልነ፡ ዝየ፡ እለ፡ ሀለውነ፡ ውሉደ፡ ቤተ፡ ክርስቲያን፡ ለዓለመ፡ ዓለም፡ አሜ፨
#       </explicit>
#   <note>Thw text contained on f.37rb, line 20 up to f.38vb, line 11 is to be found in Perruchon's edition on page 13, line 22 up to page 14, line 24 (‘Portrait de Lalibala’.). The text starts on the new line and first two lines are written with red inks. It ends with a supplication note. The end is marked with three  ፨ and with dotted line.</note>
#   </msItem>
#   <msItem xml:id="ms_i2.15">
#     <title>Lālibalā volunterly embraces the death for the love of the others.</title>
# <incipit xml:lang="gez">
#     <locus target="#40ra"/> ወእምዝ፡ እነግረክሙ፡ ካልአኒ፡ ነከራ፡ ዘተገብረ፡ በላዕለ፡ ብፁዕ፡ ላሊበላ፡ አመ፡ ውርዛዌሁ፨ ወዝንቱሰ፡ ዘእከሥት፡ ለክሙ፡ ይእዜ፡ በቍዔት፡ ውእቱ፡ ለነፍሳቲክሙ፨
# </incipit>
#   <explicit xml:lang="gez">
#     <locus target="#45va"/>ወሪዶ፡ እምሰማያት፡ እንዘ፡ አልቦ፡ ዘአገበሮ፡ ለቢሶ፡ ትስብእተ፨ ወመዊቶ፡ ጸገወ፡ ሕይወተ፡ ለምውታን፡ እስመ፡ በፈቃዱ፡ ጥዕመ፡ ሞተ፡ በእንተ፡ እሊአሁ፡ ወበእንተ፡ ፍቁራኒሁ፡ ምእመናን፨
#     </explicit>
# <note>The text contained on f.41ra, line 19 up to f.44va, 7 line  is to be found in Perruchon's edition on page 15, line 1 up to page 18 line 23 (‘Le frère de Lalibala cherche a le faire mourir’.).The beginning is marked as monthly reading for the 12th of Maskaram. The text starts on the new page and new line, lines 1, 2, 5, 6 are written with red inks. The end is defined by the left space. </note>
#   </msItem>
#   <msItem xml:id="ms_i2.16">
#     <title>Lālibalā became like Jesus Christ. Ascention to the heavens.</title>
#     <incipit xml:lang="gez">
#       <locus target="#45vab"/>ወላሊበላኒ፡ አማን፡ ተመሰሎ፡ ለመድኃኒ፡ ኵሉ፡ ዓለም፡ እስመ፡ በፈቃዱ፡ ሰትየ፡ ጽዋዓ፡ ሞት፡ በእንተ፡ ፍቅረ፡ ካልኡ፡ እስመ፡ ሰምዓ፡ ቃለ፡ እንዘ፡ ይብል፡ እስመ፡ ተፋቅሮሰ፡ ፍጹም፡ ሕግ፡ ውእቱ፨
#       </incipit>
#       <explicit xml:lang="gez">
#           <locus target="#65ra"/>ኀበ፡ ሀለወ፡ እግዚኦሙ፡ ዘተሰምየ፡ እኁሆሙ፡ በከመ፡ ይቤ፡ ለሊሁ፡ ዘተሳተፈ፡ ምስሌሆሙ፡ ሥጋ፡ ወደመ፡ ወዓፅመ፡ ወጸጒረ፡ ወአሥራወ፨ ወበእንተ፡ ዝንቱ፡ እብለክሙ፡ ኦኃውየ፨ እስመ፡ ነሣእኩ፡ ዘዚአክሙ፡ ከመ፡ አሀብክሙ፡ ዘዚአየ፨ ወኀበ፡ ሀሎኩ፡ አነ፡ ህየ፡ ይሄሉ፡ ዘይትለአክኒ፨
#       </explicit>
#       <note>The text contained on f.45va, line 14 up to f.46ra, line 14 is to be found in Perruchon's edition on page 18, line 24 up to page 19, line 13. The text contained on f.47ra, line 13 up to f.48vb, line 3 is to be found in Perruchon's edition on page 19, line 14 up to page 21, line 11 ('Lalibala est ravi dans les cieux'.). The text contained on f.53ra, line 1 up to f.53rb, line 3 line is to be found in Perruchon's edition page 21, line 12 up to line 20. The text containted on f.56ra, line 3 up to f.56ra, line 16 is to be found in perruchon's edition on page 21, line 21 up to page 22, line 1. The text starts on the new line and first two lines are written with red inks. Apparently, the upper margin indication for monthly reading on the 12th of Ṭǝqǝmt is applicable to the text that follows.The end is defined by the left space.</note>
#   </msItem>
#   <msItem xml:id="ms_i2.17">
#       <title>Lālibalā is in the heavens.</title>
#     <incipit xml:lang="gez">
#         <locus target="#65rb"/>ኢሰማዕከኑ፡ ኦብእሲ፡ እንዘ፡ ይነግር፡ ዕበየ፡ ልዕልናክሙ፡ ጳውሎስ፡ ዘከመ፡ ትትሌዓሉ፡ እምኔነ፡ ወይብል፡ እስመ፡ አኮ፡ እመላእክተ፡ ዘነሥኦ፡ ለዘነሥኦ፨ አላ፡ እምዘርአ፡ አብርሃም፡ አልዓለ፨
#       </incipit>
#       <explicit xml:lang="gez">
#           <locus target="#65vb"/>ወእፈቅድ፡ ከመ፡ ይርአዩ፡ ስብሐትየ፡ ዘወሀብከኒ፨ ዘሀሎ፡ ምስሌከ፡ እምቅድመ፡ ይትፈጠር፡ ዓለም፨ እስመ፡ አነሂ፡ አፍቀርክዎሙ፡ በከመ፡ አንተ፡ አፍቀርከኒ፨
#         </explicit>
#       <note>The beginning is marked as monthly reading for the 12th of Ḫǝdār. The end is marked with three  ፨. </note>
#       </msItem>
#       <msItem xml:id="ms_i2.18">
#           <title>Lālibalā is in the heavens.</title>
#         <incipit xml:lang="gez">
#             <locus target="#65vb-66ra"/>ዝንቱኬ፡ ቃል፡ ዘየዓርገክሙ፡ መልዕልተ፡ ኪሩቤል፡ ወሱራፌል፡ ኀበ፡ ሀለወ፡ ለባሴ፡ ሥጋክሙ፡ ወዓቃሜ፡ ኪዳን፡ ምስሌክሙ፡ ዘተካየድክሙ፡ ለእለ፡ ትገብሩ፡ ፈቃዶ፡ ከመ፡ ተሀልው፡ ኀበ፡ ሀለወ፨ ወከመ፡ ትንበሩ፡ ኀበ፡ ነበረ፨
#             </incipit>
#             <explicit xml:lang="gez">
#                 <locus target="#68rb"/>ወምዕማዲሁኒ፡ ወሠራዊቲሁኒ፡ ዘዕፅ፡ ወመክደናኒ፡ ዘሠቅ፡ እንተ፡ ላዕሉ፨ ወአንተሰ፡ አኮ፡ ዘተኃሥሥ፡ ዕፀ፡ ለአዕማድ፡ ወለምዕማዱ፡ ወለሠርዌሁ፨
#                 </explicit>
#             <note>The text starts on the new line and first two lines are written with red inks. The end is defined by the left space. </note>
#       </msItem>
#       <msItem xml:id="ms_i2.19">
#         <title>How God showed Lālibalā ten monolithic churches.</title>
#         <incipit xml:lang="gez">
#             <locus target="#68rb"/>ወዘንተ፡ ብሂሎ፡ አርአዮ፡ አብያተ፡ ዓቢያተ፡ ዘእምአሐቲ፡ ዕብን፡ ወኊልቆንሰ፡ ለእማንቱ፡ አብያተ፡ ዘአርአዮ፡ ፲ እማንቱ፨
#             </incipit>
#             <explicit xml:lang="gez">
#               <locus target="#68va"/>ወቦ፡ እምኔሆን፡ ዘኅብረ፡ ሐመደ፡ ክቦ፡ ኅበሪሆን። ወቦ፡ እምኔሆን፡ ዘዓቢይ፡ ኑኃ፡ ግደሚሆን። ለአሐቲ፡ እምአሐቲ፡ የዓቢ፡ ዓዲ፡ ኑኃ፡ ሥሮን፨
#             </explicit>
#             <note>The text contained on f.68rb, line 8 up to f.68va, line 20  is to be found in Perruchon's edition page 22, line 2 up to line 13 ('Dieu montre à Lalibala les dix églises monolithes du ciel',). The text starts on the new line and first two lines are written with red inks. The end is marked with three  ፨. </note>
#             </msItem>
#             <msItem xml:id="ms_i2.20">
#                   <title/>
# <incipit xml:lang="gez">
# <locus target="#68vb"/>ወዘንተ፡ ኵሎ፡ እምድኅረ፡ አርአዮ፡ ለላሊበላ፡ ዝኩ፡ እግዚአ፡ ኃይል፡ ዘይነብር፡ ውስተ፡ ሰማይ፡ ስፉሕ፡ ዘኅብረ፡ በረድ። ዘሀሎ፡ መልዕልተ፡ ርእሶሙ፡ ለ፬ቱ፡ እንስሳ፡ እለ፡ እሙንቱ፡ ኪሩባውያን፨
# </incipit>
# <explicit xml:lang="gez">
#   <locus target="#69va"/>ዘተናገርክዎ፡ ገጸ፡ በገጽ፡ ከመ፡ ዘይትናገር፡ ብእሲ፡ ምስለ፡ ቢጹ። እስከ፡ ተሰብሐ፡ ኅብረ፡ ገጹ፡ እምነጽሮ፡ ምዕዛርየ፨
# </explicit>
# <note>The beginning is marked as monthly reading for the 12th of Tāḫsās. The text starts in a new column new line, first two lines are written with red inks. The end is defined by the left space.  </note>
#             </msItem>
#             <msItem xml:id="ms_i2.21">
#               <incipit xml:lang="gez">
#               <locus target="#69vb-70ra"/>ወዘንተ፡ ሰሚዖ፡ ብፁዕ፡ ላሊበላ፡ ሰገደ፡ ቅድመ፡ ገጹ፡ ለአኃዜ፡ ኵሉ፨ ወአኃዘ፡ ይንብብ፡ ወይቤ፡ እግዚኦ፡ አነኑ፡ እክል፡ ከመ፡ እግበር፡ ዘንተ፡ ኦጽራሐ፡ መንግሥትከ፡ ዘአርአይከኒ፡ ዓሠርተ፡ አብያተ፡ እምአሐቲ፡ ኰኵሕ።
#               </incipit>
#               <explicit xml:lang="gez">
#                 <locus target="#70rb-70va"/>ወባሕቱ፡ በምክንያተ፡ ተልእኮ፡ በእንቲአሆን፡ ትሰመይ፡ አንተ፡ ገባሪሆን፡ ወአርአዮ፡ ካዕበ፡ ሐፃውንተ፡ በዘቦቶን፡  ይትገበር፡ አርአያሆን፡ ለእማንቱ፡ አብያተ፡ ክርስቲያናት፡ ዘርእየ፡ በውስተ፡ ሰማይ፡ ሳብዕ።
#                 </explicit>
#               <note>The text starts on the new line and first line is written with red inks. The end is defined by the left space.</note>
#             </msItem>
#             <msItem xml:id="ms_i2.22">
#               <incipit xml:lang="gez">
#                   <locus target="#70va"/>ወብፁዕ፡ ላሊበላ፡ ሰሚዖ፡ ኵሎ፡ ዘነበቦ፡ እግዚእ፡ ኃያላን፡ ወርእዮ፡ ኵሎ፡ ዘአርአዮ፡ ይቤ፡ ፈቃድከ፡ ለይኩን፡ እግዚኦ፡ ወአኮ፡ ፈቃደ፡ ዚአየ፡ ወባሕቱ፡ ለይርድአኒ፡ ኃይልከ፡ እስመ፡ ፅቡስ፡ አነ።
#                   </incipit>
#                   <explicit xml:lang="gez">
#                     <locus target="#71vb"/> ወከመዝ፡ እትአኰት፡ ወእሴባሕ፡ እምእለ፡ ይኔጽሩ፡ ማኅፈዳተ፡ መቅደስየ፡ ዘሀለዋ፡ ያስተርእያ፡ ዲበ፡ ምድር፡ እምአሐቲ፡ ኰኵሕ። ወአነሂ፡ ናሁ፡ አቀውም፡ ምስሌከ፡ ኪዳነ፡ ዮም፡ በዛቲ፡ ዕለት፨
#                     </explicit>
#                   <note>The text starts on the new line and first two lines are written with red inks. The end is defined by the beginning of the following text written with red inks on the new line.</note>
#                   </msItem>
#                   <msItem xml:id="ms_i2.23">
#                     <incipit xml:lang="gez">
#                   <locus target="#71vb-72ra"/> ኵሉ፡ ዘይበጽሕ፡ ውስተ፡ ማኅፈዳት፡ ዘሀለወከ፡ ትሕንጾን፡ ወይትጋነይ፡ በውስቴቶን። እንዘ፡ ይትአመን፡ በኃይለ፡ ጸሎትከ፡ ወይዜክረከ፡ ወይብለከ፡ መሐረኒ፡ እግዚኦ፡ ወተሠሃለኒ።
#                   </incipit>
#                   <explicit xml:lang="gez">
#                     <locus target="#74ra"/>ወአነ፡ እወዲ፡ ፍርሃተ፡ ውስተ፡ ልበ፡ ኵሎሙ፡ እለ፡ የዓልውከ። ወዑቅ፡ አንተሂ፡ ከመ፡ ታዕትት፡ እምሕዝበ፡ መንግሥትከ፡ ኵሎ፡ ዓመፃ፡ ወግፍዓ።
#                     </explicit>
#                   <note>The text starts on the new line and first two lines, i.e. lines 16, 17 of the column, as well as lines 20, 21 are written with red inks. The end is defined by the left space.</note>
#                   </msItem>
#                   <msItem xml:id="ms_i2.24">
#                     <incipit xml:lang="gez">
#                   <locus target="#74ra"/>ወዘንተ፡ ኵሎ፡ ኪዳነ፡ ሰሚዖ፡ ብፁዕ፡ ላሊበላ፡ ሰገደ፡ ወዲቆ፡ በገጹ፡ በቅድመ፡ እግዚአ፡ ኃያላን፡ ወይቤ፡ እግዚአ፡ እግዚእየ፡ ምንትኑ፡ አነ፡ ከመ፡ እኩን፡ ንጉሠ፡ ዲበ፡ ሕዝብከ፡ ዘአልብየ፡ አእምሮ።
#                   </incipit>
#                   <explicit xml:lang="gez">
#                     <locus target="#75ra"/>ወዘንተ፡ ብሂሎ፡ ለዝኩ፡ መልአክ፡ ለዘአዕረጎ፡ እምድር፡ ይቤሎ፡ እንዘ፡ ይብል፡ ናሁ፡ ረሰይኩከ፡ ወሤምኩከ፡ ከመ፡ ትኩን፡ ዓቃቢሁ፡ በኵሉ፡ መዋዕሊሁ።
#                     </explicit>
#                   <note>The text starts on the new line and first two lines are written with red inks. The end is defined by the left space.</note>
#                   </msItem>
#                   <msItem xml:id="ms_i2.25">
#                     <incipit xml:lang="gez">
#                       <locus target="#75ra"/>ወይቤሎ፡ ካዕበ፡ ለብፁዕ፡ ወለቅዱስ፡ ላሊበላ፡ ወአንተሂ፡ ኢትተክዝ፡ በይነ፡ መንግሥት፡ እስመ፡ አነ፡ በእንተ፡ ክብር፡ ኃላፊ፡ ዘእሠይመከ።
#                       </incipit>
#                       <explicit xml:lang="gez">
#                         <locus target="#75vab"/>አላ፡ ነበረ፡ ውስተ፡ ዓቢይ፡ ፍሥሐ፡ ውስተ፡ ዓፀደ፡ ትጉሃን፡ ወውስተ፡ አብያተ፡ ብርሃን፡ ከመ፡ ኤርምያስ፡ ነቢይ፡ ዘርእየ፡ ምስጢራተ፡ ትንቢት፡ በእንተ፡ ርደቱ፡ ለእግዚእነ፡ እምሰማይ፡ ወበእንተ፡ ተመስሎቱ፡ ሰብአ፡
#                       </explicit>
#                       <note>The text contained on f.75ra, line 9 up to f.75vb, line 5 is to be found in Perruchon's edition on page 22, line 14 up to page 23, line 15 ('Lalibala reçoit l'ordre de construire des églises semblables; son retour sur la terre'., continues in the following unit). The text starts on the new line and first two lines are written with red inks. The end is defined by the beginning of the following text written with red inks.</note>
#                       </msItem>
#                       <msItem xml:id="ms_i2.26">
#                         <title>Having seen the mysteries of the heaven and being appointed to the thrown, on the third day Lālibalā comes back to the earth.  </title>
#                         <incipit xml:lang="gez">
#                             <locus target="#75vb"/>ወብፁዕ፡ ላሊበላ፡ በሣልስት፡ ዕለት፡ ተመይጠ፡ ዲበ፡ ምድር፡ ርእዮ፡ ወነጺሮ፡ ምሥጢራተ፡ ሰማይ፡ ወተቀቢዎ፡ ቅብዓ፡ መንግሥት፨
#                             </incipit>
#                             <explicit xml:lang="gez">
#                               <locus target="#75ra"/>ወባሕቱ፡ ኢተሀበሉ፡ ይግንዝዎ፡ እስመ፡ ኢቈረ፡ ሥጋሁ፡ ከመ፡ ሕገ፡ በድን፡ በዝንቱ፡ ሠሉስ፡ መዋዕል፤ እስመ፡ ምውቅ፡ ሥጋሁ፡ በላህበ፡ መንፈስ፡ ቅዱስ፡ ዘኅዱር፡ ውስቴቱ፨
#                               </explicit>
#                       <note>The text contained on f.75vb, line 6 up to f.77ra, line 8 is to be found in Perruchon's edition on page 23, line 15 up to page 24, line 3 ('Lalibala reçoit l'ordre de construire des églises semblables; son retour sur la terre'., continues in the following unit). The text starts on the new line and first two lines are written with red inks. The end is defined by the beginning of the following text written with red inks.
# </note>
# </msItem>
#                       <msItem xml:id="ms_i2.27">
#                         <incipit xml:lang="gez">
#                           <locus target="#77ra"/>ወላሊበላሰ፡ ነቅሐ፡ እምስካቡ፡ ከመ፡ ዘጽሕወ፡ እምወይን፨ ወአብርሃ፡ ገጹ፡ ከመ፡ ፀሐይ፡ እምነ፡ ራዕያት፡ ዘርእየ፡ ወእምነ፡ ስብሐቲሁኒ፡ ለእግዚአብሔር፨
#                           </incipit>
#                           <explicit xml:lang="gez">
#                             <locus target="#78rab"/>ወካልኡን፡ ይቤ፡ አፍቅሩ፡ ቢጸክሙ፡ እስመ፡ ተፋቅሮ፡ ይደመሰሶን፡ ለኵሎን፡ ኃጣውእ፨ አማንኬ፡ ተፈጸመ፡ ቃለ፡ ሐዋርያ፡ ዘይቤ፡ በላዕለ፡ ብፁዕ፡ ላሊበላ፡ ፈርየሂ፡ ወተመክዓበ፨
#                             </explicit>
#                             <explicit xml:lang="gez" type="supplication">
#                                 <locus target="#78rb"/>ወለነኒ፡ ይረስየነ፡ ጽሑቃነ፡ ለአፍቅሮ፡ ቢጽነ፨ እግዚእነ፡ ወመድኃኒነ፡ ኢየሱስ፡ ክርስቶስ፡ በጸሎቱ፡ ወበስእለቱ፡ ወበሀብተ፡ ረድኤቱ፨ ወበፃማ፡ ገድለ፡ ዚአሁ፡ ወበሐፈ፡ ድካሙ፡ ዘተወክፈ፡ በሥጋሁ፡ ዝንቱ፡ ብእሲ፡ ብፁዕ፡ ወቅዱስ፡ ላሊበላ፡ ዘተሰምየ፡ገብረ፡ መስቀል፡ ወያድኅና፡ እመከራ፡ ሥጋ፡ ወነፍስ፨ ለንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#                             </explicit>
#                           <note>The text contained on f.77ra, line 8 up to f.78rb, line 21 is to be found in Perruchon's edition on page 24, line 3 up to page 25, line 21 ('Lalibala reçoit l'ordre de construire des églises semblables; son retour sur la terre'.). First two lines are written with red inks. It ends with a supplication note. The end is marked with three  ፨. </note>
#                           </msItem>
#                           <msItem xml:id="ms_i2.28">
#                             <title>Lālibalā runs away to the desert.</title>
#                             <incipit xml:lang="gez">
#                               <locus target="#78va"/>ወእምድኅረዝ፡ ነበረ፡ ብፁዕ፡ ላሊበላ፡ እንዘ፡ ይትዌከፍ፡ ኵሎ፡ ፅዕለተ፡ ወኵሎ፡ ምናኔ፡ እምኀበ፡ አዝማዲሁ፨
#                               </incipit>
#                               <explicit xml:lang="gez">
#                                   <locus target="#79vb"/>ወብፁዕኒ፡ ላሊበላ፡ ነበረ፡ እንዘ፡ ይሜግቦ፡ ኃይለ፡ መንፈስ፡ ቅዱስ፨ ወሲሳዮ፡ ይሴሰይ፡ ንዒዎ፡ አራዊተ፡ በከመ፡ ነገርናክሙ፡ ቅድመ፨
#                               </explicit>
#                               <explicit xml:lang="gez" type="supplication">
#                                   <locus target="#79vb"/>በረከተ፡ ጸሎቱ፡ የሃሉ፡ ምስለ፡ አመተ፡ እግዚአብሔር፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወኃይለ፡ ሚካኤል፡ ወልደ፡ ማርያም፡ ወለአዋልዲሃ፡ ወለተ፡ ማርያም፡ ኂሩተ፡ ሥላሴ፡ ወበረከተ፡ ጸጋሁ፡ የሃሉ፡ ላዕለ፡ ኵልነ፡ እለ፡ ተጋባእነ፡ ውስተ፡ ዛቲ፡ ቅድስት፡ ቤተ፡ ክርስቲያን፨ ለዓለመ፡ ዓለም፡ አሜን፨
#                                   </explicit>
#                               <note> The text contained on f.78va, line 1 up to f.79vb, line 20 is to be found in Perruchon's edition on page 25, line 22 up to page 27, line 17 (‘Lalibala se retire au désert’.) The text starts on the new page and new line, first two lines are written with red inks. It ends with a supplication note. The end is marked with three  ፨ and a dotted line.</note>
#                               </msItem>
#                               <msItem xml:id="ms_i2.29">
# <title>Lālibalā marries Masqal Kǝbrā. He is blamed for marrying an engaged woman, but helped by an angel he escapes the punishment.</title>
#                                 <incipit xml:lang="gez">
#                                   <locus target="#80ra"/>ወከመዝ፡ እንዘ፡ ሀለወ፡ ብፁዕ፡ ላሊበላ፡ በውስተ፡ ገዳም፡ አስተርአዮ፡ መልአከ፡ እግዚአብሔር፡ ዘአዕረጎ፡ ውስተ፡ ሰማይ፨ ወዘተአዘዘ፡ ከመ፡ ይዕቀቦ፡ በኵሉ፡ መዋዕሊሁ፨
#                                   </incipit>
#                                   <explicit xml:lang="gez">
#                                       <locus target="#85vb"/>ወመፍቅደ፡ ሩጸቶሙ፡ ለገይሰ፡ ቤተ፡ ክርስቲያን፡ ወለናዝዞ፡ ሙቁሐን። ወስነ፡ ይዋሄሆሙ፡ ዘይትሜሰል፡ ከመ፡ ይዋሄ፡ በግዕ። ወሀብተ፡ ምጽዋቶሙ፡ ዘኅቡእ፡ ወዘክሡት።
#                                       </explicit>
#                                       <explicit xml:lang="gez" type="supplication">
#                                           <locus target="#85vb-86ra"/>ወኵሉ፡ ጻሕቀ፡ ተጸምዶሙ፡ ዘፆሩ፡ በሥጋሆሙ፡ ላሊበላ፡ ወመስቀል፡ ክብራ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ወላዕለ፡ ኵሎሙ፡ እለ፡
#                                           ይትአመኑ፡ በኃይለ፡ ጸሎቶሙ፡ ለእሉ፡ ክልኤሆሙ፡ አዕናቍ፡ ፅዱላን፡ እለ፡ ያዋክዩ፡ ወያበርሁ፡ በውስተ፡ ጽልመት፡ ይኩነነ፡ መርሃ፡
#                                           በኀበ፡ ኵሉ፡ ዘወፈርነ፨ ወበኀበ፡ ኵሉ፡ ዘኣቶነ፨ በፍጽምነ፡ ወበከዋላነ፡ በይምንነ፡ ወበጽግምነ፨ እስከ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#                                       </explicit>
#                                   <note>The text contained on f.80ra, line 1 up to f.86ra, line 17 is to be found in Perruchon's edition  on page 27, line 18 up to page 35, line 16 (‘Mariage de Lalibala; son frère le fait venir pour l'en punir’.). The beginning is marked as monthly reading for the 12th of Ṭǝrr. The text starts on the new page and new line, lines 1, 2, 5, 6 are written with red inks.  It ends with a supplication note. The end is marked with a dotted line.</note>
#                                   </msItem>
#                                   <msItem xml:id="ms_i2.30">
#                                     <title>Lālibalā runs away to the desert with Masqal Kǝbrā.</title>
#                                     <incipit xml:lang="gez">
#                                       <locus target="#86rab"/>ወእምዝ፡ ሐለየ፡ ላሊበላ፡ ኵሎ፡ ምንዳቤያቲሁ፡ ዘረከቦ፡ እምኀበ፡ ኵሎሙ፡ አዝማዲሁ፡ ወእምኀበ፡ ኵሎሙ፡ ሕዝብ፡ ዘተዓይነ፡ ኵርጓኔ፡ ዘንጉሥ፨
#                                       </incipit>
#                                       <explicit xml:lang="gez">
#                                         <locus target="#87rb"/>አመ፡ ሖረ፡ በትእዛዘ፡ ዚአከ፡ ወበትእዛዘ፡ መምህሩ፡ ከመ፡ ኢይርአይ፡ ሙስናሃ፡ ለኢየሩሳሌም፡ በምክንያተ፡ ድውያን፡ እስመ፡ አዘዘ፡ ኤርሚያስ፡ ነቢይ፡ ከመ፡ ያምጽእ፡ በለሰ፡ ለፈውሶ፡ ድውያን። ወበህየ፡ ከደንኮ፡ በመንጦላዕተ፡ ሣህልከ። እንዘ፡ ትሴስዮ፡ ንዋመ፡ ሠናየ፡ ፷ ወ ፮ተ፡ ዓመተ።
#                                       </explicit>
#                                           <explicit xml:lang="gez" type="supplication">
#                                             <locus target="#87rb"/>ወለነኒ፡ በዘፈቀድከ፡ ትክል፡ አጽንዖተነ። ወለከ፡ ስብሐት፡ ለዓለም፡ ዓለም፡ አሜን፨
#                                             </explicit>
#                                       <note>The text contained on f.86ra, line 18 up to f.86va, line 10 is to be found in Perruchon's edition on page 35, line 17 up to page 36, line 6 (‘Lalibala retourne au désert avec sa femme’.). The text starts on the new line and first  line, i.e. line 18, as well as line 20 are written with red inks. Apparently, the upper margin indication for monthly reading on the 12th of Yakkātit is applicable to the text that follows.It ends with a supplication note. The end is defined by the left space.</note>
#                                       </msItem>
#                                       <msItem xml:id="ms_i2.31">
#                                           <title>After their prayers for food, Lālibalā and Masqal Kǝbrā find partridges which they eat.</title>
#                                         <incipit xml:lang="gez">
#                                           <locus target="#87rb-87va"/>ወእምዝ፡ ሶበ፡ ፈጸሙ፡ ጸሎቶሙ፡ አንሶሰወት፡ መስቀል፡ ክብረ፡ ውስተ፡ ውሣጤ፡ በዓት፡ ወረከበት፡ በህየ፡ ጴርድክሴ፡ ዓቢየ፡ ወዜነወቶ፡ ለምታ።
#                                           </incipit>
#                                           <explicit xml:lang="gez">
#                                             <locus target="#87va"/>ወወድቀ፡ ማእከለ፡ ቴዓይኒሆሙ። ወዓውደ፡ ደባትሪሆሙ፡ በልዑ፡ ወጸግቡ፡ ጥቀ። ወኢያሕጣእኮሙ፡ እምዘ፡ ፈቀዱ።
#                                             </explicit>
#                                             <explicit xml:lang="gez" type="supplication">
#                                               <locus target="#87vab"/>ወለነኒ፡ ኢኅጣእከነ፡ ለአግብርቲከ፡ እለ፡ ስዱዳን፡ እምሰብእ፡ በእንተ፡ ኃጢአትነ። ወውእተ፡ ዖፈ፡ ተሴስዮሙ፡ ኃደሩ፡ እንዘ፡ የአኵትዎ፡ ለእግዚአብሔር። ጸሎቶሙ፡ ወበረከቶሙ፡ የሃሉ፡ ምስለ፡ ፍቅርቶሙ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡
#                                               ለዓለመ፡ አሜን፨
#                                               </explicit>
#                                           <note>The text contained on f.87rb, line 16 up to f.87va, line 8 is to be found in Perruchon's edition on page 36, line 7 up to line 11. The text starts on the new page and new line, three line, namely lines 17, 19 and 21 are written with red inks. It ends with a supplication note. The end is marked with a dotted line.</note>
#                                           </msItem>
#                                           <msItem xml:id="ms_i2.32">
#                                             <title>Lālibalā and Masqal Kǝbrā live in a cave, like Prophet Isaiah and other prophets. They run further to the east from the persecution. Archangel Gābrǝ’el announces to the family that Lālibalā will make a pilgrimage to Jerusalem. </title>
#                                             <incipit xml:lang="gez">
#                                               <locus target="#87vb"/>ወእምዝ፡ ነበሩ፡ ክልኤሆሙ፡ እምይእቲ፡ ዕለት፡ ውስተ፡ ይእቲ፡ በዓት፡ ኀበ፡ በጽሑ፡ በይእቲ፡ ዕለት፡ እንዘ፡ ይሴሰዩ፡ ዘአቅረበ፡ ሎሙ፡ መንፈስ፡ ቅዱስ፡ እምአቃቂራተ፡ ገዳም፡ እንዘ፡ ይትሜሰልዎ፡ ለመክብበ፡ ነቢያት፡ ኢሳይያስ፡ ወለካልአኒሁኒ፡ ነቢያት፡ ዘነበሩ፡
#
#                                               </incipit>
#                                               <explicit xml:lang="gez">
#                                                 <locus target="#90ra"/>ላሊበላሰ፡ ወመስቅል፡ ክብራ፡ ነበሩ፡ ህየ፡ በተጸምዶ፡ ዓቢይ፡ በጾም፡ ወበጸሎት፡ በቀዊም፡ ወበሰጊድ፡  መጠነ፡ ነበሩ፡ ውስተ፡ ይእቲ፡ ብሔር፡ ኅቡረ።
#                                                 </explicit>
#                                                 <explicit xml:lang="gez" type="supplication">
#                                                   <locus target="#90ra"/>ጸሎቶሙ፡ ወበረከቶሙ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#                                                   </explicit>
#                                               <note>The text contained on f.87vb, line 8 up to line 16 is to be found in Perruchon's edition on page 36, line 12 up to line 15. The text contained on f.88ra, line 4 up to f.88rb, line 1 is to be found in Perruchon's edition page 36, line 15 up to line 22. The text cointained on f.88vb, line 1 up to f.89ra, line 7 is to be found in Perruchon's edition on page 36, line 23 up to page 37, line 8. The text contained on f.89rb, line 7 up to f.89va, line 12 is to be found in Perruchons's edition on page 37, line 9 up to line 19 ('L’ange Gabriel annonce à Masqal Kebra le prochain départ de Lalibala pour Jérusalem'.). The text contained on f.89vb, line 2 up to line 21 is to be found in Perruchon's edition on page 37, line 20 up to page 38, line 4. The text starts on the new line, first two lines are written with red inks. It ends with a supplication note. The end is marked with a dotted line.</note>
# </msItem>
# <msItem xml:id="ms_i2.33">
#   <incipit xml:lang="gez">
#     <locus target="#90ra"/>ወእምዝ፡ እምድኅረ፡ ኅዳጥ፡ መዋዕል፡ አስተርአዮሙ፡ ገብርኤል፡ ሊቀ፡ መላእክት፡ ወይቤሎሙ፡ ሰላም፡ ለክሙ፡ ኦአግብርተ፡ እግዚአብሔር።
#     </incipit>
#     <explicit xml:lang="gez">
#       <locus target="#95va"/>ወኖሎተ፡ መርዔትከ፡ ወርትዕተ፡ ሃይማኖትከ፡ ኢታሰስል፡ እምልቦሙ፡ ለእለ፡ የአምኑ፡ ብከ። ለከ፡ ይደሉ፡ እግዚኦ፡ ስብሐት፡ በጽዮን። ወለከ፡ ይትፌኖ፡ ጸሎት፡ በኢየሩሳሌም። ለዓለመ፡ ዓለም፡ አሜን፨
#       </explicit>
#     <note>The text starts on the new line and first two lines are written with red inks. Apparently, the upper margin indication for monthly reading on the 12th of Maggābit is applicable to the text that follows. The end is marked with three  ፨.</note>
#     </msItem>
#     <msItem xml:id="ms_i2.34">
#         <incipit xml:lang="gez">
#           <locus target="#95va"/>ወዘንተ፡ ብሂሎ፡ ሊቀ፡ ጳጳሳት፡ ወፅአ፡ ኣፍኣ፡ ውስተ፡ ዴዴ፡ ኀበ፡ ሀለወ፡ ላሊበላ፡ ወሶበ፡ ርእዮ፡ ብፁዕ፡ ላሊበላ፡ ወድቀ፡ ውስተ፡ ምድር፡ እንዘ፡ ይሰግድ፡ ሎቱ፡ ታሕተ፡ እገሪሁ፡ ለሊቀ፡ ጳጳሳት።
#           </incipit>
#           <explicit xml:lang="gez">
#             <locus target="#96vb"/>ወዘመርሆሙ፡ ለእስራኤል፡ መዓልተ፡ በደመና፡ ወኵሉ፡ ሌሊተ፡ በብርሃነ፡ እሳት። ውእቱ፡ ለይምራህከ፡ ወይሠርሕ፡ ወያብርህ፡ ፍኖተከ፡ ወይትወከፍ፡ ንግደተከ።
#             </explicit>
#           <note>The text starts on the new line and first two lines are written with red inks. The end is defined by the left space.</note>
#     </msItem>
#     <msItem xml:id="ms_i2.35">
#         <incipit xml:lang="gez">
#           <locus target="#96vb"/>
#           </incipit>
#           <explicit xml:lang="gez">
#             <locus target="#100vb"/>ወዘከመ፡ ትሬኢ፡ ሕሊና፡ ልብየ፡ ግበር፡ ሊተ። ወዘከመ፡ ተአምር፡ ፈቃደ፡ ስእለትየ። ፈጽም፡ ሊተ፡ በኂሩትከ፡ ኦእግዚእየ።
#             </explicit>
#             <explicit xml:lang="gez" type="supplication">
#               <locus target="#100vb"/>ወአርኢ፡ ሣህለከ፡ ወምሕረተከ፡ ላዕለ፡ ወለተ፡ ኢየሱስ፡ አመትከ፡ ለዓለመ፡ ዓለም፡ አሜን፨
#               </explicit>
#           <note>The text starts on the new line and first two lines are written with red inks. It ends with a supplication note. The end is marked by a dotted line. </note>
#           </msItem>
#           <msItem xml:id="ms_i2.36">
#               <incipit xml:lang="gez">
#                 <locus target="#100vb-101ra"/>ወይቤሎ፡ እግዚአ፡ ኵሉ፡ ናሁ፡ አንሰ፡ እብለከ፡ ዘኢይሔሱ፡ ቃልየ፡ ወኢይዔምፅ፡ ኪዳንየ። ምስለ፡ ዓሠርቱ፡ ወክልኤቱ፡ አርዳእየ፡ ይኩን፡ ማኀደርከ፡ ወምስሌሆሙ፡ ይኩን፡ መክፈትከ፡ በኵሉ፡ ክብር፡ ወዘይትአመንሂ፡ በጸሎትከ።
#                 </incipit>
#                 <explicit xml:lang="gez">
#                     <locus target="#104rb"/> ወለከሰ፡ ፃማከሂ፡ ዘተወከፍከ፡ ወኪዳንከሂ፡ ዘአቀምኩ፡ ለከ፡ ጽሕፍት፡ ይእቲ፡ ወልክዕት። ውስተ፡ ኢየሩሳሌም፡ ሰማያዊት። ወጽሕፈታሰ፡ አኮ፡ በማየ፡ ሕመት፡ አላ፡ በደመ፡ ሕግ፡ ወኪዳን፡ በዘቦቱ፡ ይጸሐፍ፡ አስማተ፡ ኵሎሙ፡ ቅዱሳን፡
#                   </explicit>
#                   <explicit xml:lang="gez" type="supplication">
#                     <locus target="#104rb"/>ከማሁ፡ አቅም፡ ኪዳነከ፡ ለንግሥትነ፡ ወለተ፡ ኢየሱስ፡ አመትከ፡ አሜን።
#                     </explicit>
#                   <note>The text starts on the new line and first two lines, namely lines 12, 13, as well as lines 16, 17 are written with red inks. Apparently, the upper margin indication for monthly reading on the 12th of Miyāzyā is applicable to the text that follows. It ends with a supplication note.</note>
#                   </msItem>
#                   <msItem xml:id="ms_i2.37">
#                       <incipit xml:lang="gez">
#                         <locus target="#104va"/>ወዘንተ፡ ሶበ፡ ይቤሎ፡ አኃዜ፡ ኵሉ፡ ዓለም፡ ዘይነብር፡ ላዕለ፡ ሰረገላ፡ ኪሩቤል፡ ሰገደ፡ ብፁዕ፡ ወቅዱስ፡ ላሊበላ፡ ውስተ፡ ምድር፡ ወአእኰቶ፡ ለእግዚአብሔር፡ እንዘ፡ ይብል። አአኵተከ፡ እግዚኦ፡  እስመ፡ ተወከፍከኒ።
#                         </incipit>
#                         <explicit xml:lang="gez">
#                             <locus target="#105rb"/>  ወአንሰ፡ ወኢአሐተ፡ ቅሥፈታተ፡ ኢፆርኩ፡ ጥቀ፡ ዘከመ፡ ፆሩ፡ አግብርቲከ። ወባሕቱ፡ አርአይከ፡ ምሕረተከ፡ በላዕሌየ፡
#                             </explicit>
#                         <note>The text starts on the new page, new line and first two lines are written with red inks. The end is defined by the beginning of the following text on the new line, written with red inks.</note>
#                         </msItem>
#                         <msItem xml:id="ms_i2.38">
#                             <incipit xml:lang="gez">
#                               <locus target="#105rb"/>ወይቤሎ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ለብፁዕ፡ ወለቅዱስ፡ ላሊበላ፡ አማን፡ አማን፡ እብለከ፡ እምእሉ፡ ኵሎሙ፡ እለ፡ ዘከርኮሙ፡ ኢየሐፅፅ፡ ዕሤትከ፡ በኀቤየ፡ ወይእዜኒ፡ አፅምዕ፡ በልባዌ፡ ዘእነግረከ፡ አነ።
#                               </incipit>
#                               <explicit xml:lang="gez">
#                                   <locus target="#107rab"/> እስመ፡ ብዙኃት፡ ነፍሳት፡ እለ፡ ይድኅና፡ በውስቴቶን፡ ተአሚኖን፡ በኃይለ፡ ጸሎትከ፡ ወተጸዊኖን፡ በትንብልና፡ ዚአከ። ወአነሂ፡ ኢያሴስል፡ ጸጋየ፡ ወምሕረትየ፡ እምኔሆን። ወሀብተ፡ ረድኤትየ፡ ኢያአትት፡ እምውስተ፡ አብያቲሆን። ወርስቶን፡ ምስሌ፡ ርስትከ።
#                                   </explicit>
#                                   <explicit xml:lang="gez" type="supplication">
#                                     <locus target="#107rb"/>ወለዛቲኒ፡ ንግሥት፡ ወለተ፡ ኢየሱስ፡ ዘሐነጸት፡ ሕንጻ፡ ማኅፈድከ፨እንዘ፡ ትሲፎ፡ ኪዳነከ፤ ይኩን፡
#                                     ማኅደራ፡ ምስሊከ፨ እመኒ፡ እድ፡ ወእመኒ፡ አንስት፡ ይኩን፡ ምስሌከ፡ ማኅደሮሙ፡ ለእለ፡ ይትአመኑ፡ በኃይለ፡ ጸሎትከ፨ ለዓለመ፡
#                                     ዓለም፡ አሜን፨
#                                     </explicit>
#                               <note>The text starts on the new line and first two lines are written with red inks. It ends with a supplication note. The end is marked with a dotted line. </note>
#                               </msItem>
#                               <msItem xml:id="ms_i2.39">
#                                   <incipit xml:lang="gez">
#                                     <locus target="#107rb"/>ወዘንተ፡ ሶበ፡ ይቤሎ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ለብፁዕ፡ ወለቅዱስ፡ ላሊበላ፡ ተፈሥሐ፡ ወተሐሥየ፡ ብፁዕ፡ ላሊበላ፡ ወተመልዓ፡ እምኃይለ፡ መንፈስ፡ ቅዱስ።
#                                     </incipit>
#                                     <explicit xml:lang="gez">
#                                         <locus target="#108va"/>ወካዕበ፡ አንተኒ፡ ትመውኦ፡ ወለኵሉ፡ መናግንቲሁ። ወብዙኃን፡ እለ፡ ተሰምዩ፡ በዝንቱ፡ ስም፡ ወኢኃብረ፡ ስሞሙ፡ ምስለ፡ ምግባሮሙ።
#                                         </explicit>
#                                         <explicit xml:lang="gez" type="supplication">
#                                           <locus target="#108vab"/>ወለከሰ፡ ስመከኒ፡ ኃብር፡ ምስለ፡ ምግባርከ። ሰላምየ፡ ወኃይለ፡ ረድኤትየ፡ ወፍቅርየ፡ ወትውክልተ፡ መስቀልየ፡ የሃሉ፡ ምስሌከ፡ ወምስለ፡ ወለተ፡ ኢየሱስ፡ ንግሥት፡ እመትየ፡ ለዓለም፡ ዓለም።
#
#                                           </explicit>
#                                     <note>The text starts on the new line and first two lines are written with red inks. It ends with a supplication note.</note>
#                                     </msItem>
#                                     <msItem xml:id="ms_i2.40">
#                                         <incipit xml:lang="gez">
#                                           <locus target="#108vb"/>ወዘንተ፡ ብሂሎ፡ ባረኮ፡ እግዚእነ፡ ወዓርገ፡ ውስተ፡ ሰማይ፡ እንዘ፡ ይሬእዮ፡ ላሊበላ፡ በከመ፡ ርእይዎ፡ አርዳኢሁ፡ ምስለ፡ እሙ፡ አመ፡ ዓርገ፡ ፄዊዎ፡ ፄዋ፡
#                                           </incipit>
#                                           <explicit xml:lang="gez">
#                                               <locus target="#116rb-va"/>ዝንቱኬ፡ ውእቱ፡ መንክራቲሁ፡ ለገብረ፡ መስቀል፡ ዘፆረ፡ ክበደ፡ ጽሙና፡ ወክበደ፡ ጽምዕ። እስመ፡ ኢበልዓ፡ በመዋዕለ፡ መንግሥቱ፡ ዘእንበለ፡ ሠለሥቱ፡ አፍዕምት። ወኢሰትየ፡ ዘእንበለ፡ አሐቲ፡ ጽዋዕ።
#                                               </explicit>
#                                               <explicit xml:lang="gez" type="supplication">
#                                                 <locus target="#116vab"/>ጸሎቱ፡ ወስእለቱ፡ ወሀብተ፡ ረድኤቱ፡ ወአሶተ፡ ጸጋሁ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡
#                                                 ወምስለ፡ ውሉዳ፡ ኃይለ፡ ኢየሱስ፡ ኃይለ፡ ሚካኤል፡ ወምስለ፡ አዋልዲሃ፡ ወለተ፡ ማርያም፡ ኂሩተ፡ ሥላሴ፡ ወምስለ፡ ኵሎሙ፡
#                                                 ነጋድያን፡ እለ፡ መጽኡ፡ እንዘ፡ ይትአመኑ፡ በኃይለ፡ ጸሎቱ፡ ለዝንቱ፡ ብእሲ፡ ፀዋራ፡ ግብረ፡ ምንኵስና፡ ዘበንግሥ፡ ውእቱ፡
# ...
#             ብእሲት፡ ብዕልት። ወእንዘ፡ ትዴረር፡ ወትበልዕ፡ ሥጋ፡ እንስሳ፡ አኃዘት፡ ትብላዕ፡ ሥጋ፡ ሰብእኒ፡ ዘበሐሜት። ወሐመየቶ፡ ለ<hi rend="rubric">ላሊበላ፡</hi> በነገር፡ ካልእ፡ እንዘ፡ ትጸርፍ፡ ሎቱ፡ ወተፍዕመት፡ ሥጋ፡ ወሐነቃ፡ ውእቱ፡ ሥጋ፡ ወኢወረደሂ፡
#             ታሕተ፡ ወኢወፅአ፡ ኣፍኣ። አላ፡ ነበረ፡ ማእከለ፡ ጕርዔሃ፡ እንዘ፡ ያጠውቃ፡ ዘበሐኒቅ። ወፈቀደ፡ ይፃእ፡ ዓይና፡ እምብዝኃ፡ ጥዋቄ፡
#             ሕንቀት። ወጸርሐት፡ በ<hi rend="rubric">ው</hi>ስተ፡ <cb n="b"/> ልበ፡ እንዘ፡ ትብል፡ አበስኩ፡ ለከ፡ ኦእግዚእየ፡<hi rend="rubric">ገብረ፡ መስቀል፡ </hi> መሲሑ፡ ለእግዚአብሔር። ወኢይደግም፡ እምይእዜ፡ ጸውዖተከ። ወኢይዘክር፡ ስመከ፡ በእከይ፡
#             ዘእንበለ፡ በሠናይ። ወዘንተ፡ ሶበ፡ ትቤ፡ ወፅአ፡ ውእቱ፡ ምታረ፡ ሥጋ፡ ምስለ፡ ደመ፡ ጕርዔሃ፡ ወወድቀ፡ ውስተ፡ ምድር። ጸሎቱ፡ ወስእለቱ፡
#               ለ<hi rend="rubric">ገብረ፡ መስቀል፡ </hi> የሃሉ፡ ምስለ፡ ንግሥትነ፡ <hi rend="rubric">ወለተ፡ ኢየሱስ፡
#             </hi>ወሐብለ፡ ረድኤቱ፡ ይሕንቆ፡ ለዕድውነ፡ አሜን። <hi rend="rubric">ወካዕበ፡ አሐተ፡ ዕለተ፡ ኣኃዘ፡ ይጽርፍ፡ ሎቱ፡ አሐዱ፡
#               ብእሲ፡</hi> ለ<hi rend="rubric">ላሊበላ፡</hi> እንዘ፡ የሐምዮ። ወብእሲቱሰ፡ ለውእቱ፡ ብእሲ፡ ተቤሎ፡ ኢትጽርፍ፡ ላዕለ፡
#             ገብረ፡ እግዚአብሔር፡ ወመሲሐ፡ እግዚአብሔር፡ ወእቱ፡ <!--ው? DR 2017-08-31-->
#           </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="123">
#           <ab>
#             <pb n="123r"/>
#             <cb n="a"/> ዓዲ። ወተምዓ፡ ለብእሲቱ፡ ወተንሥአ፡ እምኀበ፡ ይነብር፡ ወዓርገ፡ ውስተ፡ ምስካቡ፡ ወኖመ። ወሶበ፡ ነቅሐ፡ እምንዋሙ፡
#             ረከበ፡ ክልኤተ፡ አዕይንቲሁ፡ ዕውራነ፡ ወዜነዋ፡ ለብእሲቱ፡ ከመ፡ ዖሩ፡ አዕይንቲሁ። ወብእሲቱሰ፡ ትቤሎ፡ ኢይቤለከኑ፡ ኢትጽርፍ፡ ላዕለ፡
#             ገብረ፡ እግዚአብሔር፡ አርአየኬ፡ እግዚአብሔር፡ ኃይሎ፡ ላዕሌከ፡ እስመ፡ ጸረፍከ፡ ላዕለ፡ ገብሩ፡ በዑረተ፡ ልብከ። ወእግዚአብሔር፡ አዖሮን፡
#             ለአዕይንቲከ። ከመ፡ ይኩን፡ ዕውረ፡ ውሥጥከኒ፡ ወአፍአከኒ፡ ወይእዜኒ፡ ኢትኅዘን፡ በእንተ፡ ዑረተ፡ አዕይንቲከሰ። አላ፡ ኅዘን፡ በእንተ፡
#             ነፍስከ፡ እስመ፡ ትትኳነን፡ በእሳተ፡ ገሃነም፡ ለእመ፡ ኢነሳሕከ። በከመ፡ ይቤ፡ እግዚእነ፡ <cb n="b"/> በወንጌል፡ ኵሉ፡ ዘነበበ፡
#             ጽርፈተ፡ ላዕለ፡ ወልደ፡ እጓለ፡ እመሕያው፡ ይትኃደግ፡ ሎቱ፡ ወዘሰ፡ ጸረፈ፡ ዲበ፡ መንፈስ፡ ቅዱስ፡ ኢይትኃደግ፡ ሎቱ፡ ኢበዝ፡ ዓለም፡
#             ወኢበዘይመጽእ። ዘጸረፈሰ፡ ዲበ፡ እጓለ፡ እመሕያው፡ ዘይቤ፡ ላዕለ፡ እለ፡ ኢተጠምቁ። ወዘሰ፡ ጸረፈ፡ ላዕለ፡ መንፈስ፡ ቅዱስ፡ ዲበ፡ እለ፡
#             ነሥኡ፡ መንፈሰ፡ ቅዱሰ፡ እምከርሠ፡ ጥምቀት፡ ወይእዜኒ፡ ኢይምሰልከ፡ ዲበ፡ ሰብእ፡ ዘጸረፍከ። አላ፡ ዲበ፡ መንፈስ፡ ቅዱስ። ወከመዝ፡
#             ገሠጸቶ፡ ይእቲ፡ ብእሲት፡ ለብእሲሃ፡ እስመ፡ መንፈስ፡ ቅዱስ፡ አስተናገራ። ወይእዜኒ፡ ኦፍቁራንየ፡ ኢይፃእ፡ ጽርፈት፡ እምአፉነ፡ ላዕለ፡
#             እኁነ፡ ክርስቲያናዊ፡ እስመ፡ ተወልደ፡ <pb n="123v"/>
#             <cb n="a"/> እመንፈስ፡ ቅዱስ። ወበእንተዝ፡ ንሰመይ፡ ጸራፍያነ፡ ላዕለ፡ መንፈስ፡ ቅዱስ፡ ሶበ፡ ጸረፍነ፡ ላዕለ፡ ክርስቶሳዊ።
#             ያድኅነነኬ፡ ቅግዚአብሔር፡ እስመ፡ እምዘ፡ ከመዝ፡ ልማድ፡ እስመ፡ ጳውሎስኒ፡ ይሜህረነ፡ ከመ፡ ኢንርግም፡ እስከ፡ ለሰይጣን፡ አኮ፡ ኃዚኖ፡
#             ለሰይጣን፡ ዘይሜህር፡ ከመዝ፡ አላ፡ ከመ፡ ኢንልክር፡ ጥቀ፡ ለመርገም፡ በልሳንነ፡ ከመ፡ ኢንድኃጽ፡ ለዕለ፡ እኁነ። ንትማኅፀንኬ፡ በኃይለ፡
#             ጸሎቱ፡ ለ<hi rend="rubric">ገብረ፡ መስቀል፡ </hi> ከመ፡ ያዑሮ፡ ለሰይጣን፡ ዘያስሕተነ፡ ወዘይሜህረነ፡ ከመ፡ ንጽርፍ፡ በከመ፡
#             አዖሮ፡ ለውእቱ፡ ብእሲ፡ ዘጸረፈ፡ ላዕሌሁ፡ ጸሎቱ፡ ወስእለቱ፡ ወበረከቱ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ <hi rend="rubric">ወለተ፡
#               ኢየሱስ፡ </hi>
#             <cb n="b"/> ወምስለ፡ ወልዳ፡ <hi rend="rubric">ኃይለ፡ ኢየሱስ፡ </hi>ወይባርከነ፡ ለኵልነ፡ አሜን፤ <hi rend="rubric">ስምዑኬ፡ ኦፍቁራንየ፡ እንግርክሙ፡ ዘከመ፡ ኮነ፡ ግብረ፡ </hi>ፀአቶን፡ ለእላንቱ፡ አብያተ፡ ክርስቲያናት፡
#             እምልበ፡ ምድር። በእደ፡ <hi rend="rubric">ላሊበላ፡ </hi>ልዑለ፡ ዝክር፡ ወዘከመ፡ እፎ፡ ግብረ፡ ሕንጻሆን፡ ኮነ፡ እንበለ፡
#             ዕፅ፡ ወመሬት፡ ወዘእንበለ፡ አኅባለ፡ ጠፈር፡ ወመዋጽሕተ። ሰማዕክሙኑ፡ ዘከመዝ፡ ግብረ፡ ዜና፡ ወሚመ፡ ርኢክሙኑ፡ በአዕይንቲክሙ፡ ዘከመዝ፡
#             መንክረ፡ ወዘከመዝ፡ መድምመ፡ መድፍን፡ ኅቡእ፡ ዘተከሥተ፡ በእደ፡ <hi rend="rubric">ላሊበላ፡ </hi>እምልብኒ፡ ተመሥጠረ፡
#             ወእምሕሊናኒ፡ ተሠወረ፡ ዝኩ፡ ገባሬ፡ ኵሉ፡ ወፈጣሬ፡ ኵሉ፡ </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="124">
#           <ab>
#             <pb n="124r"/>
#             <cb n="a"/> ዘአምጽአ፡ ኵሎ፡ ዓለመ፡ በጽዋዔ፡ ቃሉ፡ አመ፡ በጽሐ፡ ጊዜሁ፡ ለሕንጻ፡ እሎን፡ አብያተ፡ ክርስቲያናት። ወአመ፡ ወርዘወ፡
#             ሐናጺሆን፡ በሥጋኒ፡ ወበመንፈስኒ። ፈቀደ፡ እግዚአብሔር፡ ከመ፡ ይክሥት፡ መድፍኖ፡ ኅቡአ፡ ዘነበረ፡ እምቀዳሚ፡ ተከቢቶ። አመ፡ ሣረረ፡
#             ምድረ፡ ወሐለየ፡ ከመ፡ ያርኢ፡ ምሥጢሮ፡ ለሕዝብ፡ ለእለ፡ ይደልዎሙ፡ ከሢቶ፡ እምልበ፡ ምድር፡ ወጥበብ፡ መንክር፡ ወበምሥጢር፡ ኅቡእ።
#             በከመ፡ አውፅአ፡ ቀዳሚ፡ እምከርሠ፡ ምድር፡ ኵሎ፡ አዝርእተ፡ ምድር፡ በበዘመዱ፡ ወበበአርአያሁ። ወዕፀወኒ፡ ከማሁ፡ በበአርአያሁ፡
#             ወበበአምሳሊሁ። ወአንስሳኒ፡ ብዙኃ፡ በበአርአያሆሙ፡ ወበበአምሳሊሆሙ። <cb n="b"/> ወከማሁ፡ ፈቀደ፡ ለእሎንሂ፡ አብያተ፡ ክርስቲያናት፡
#             ያወፅኦን፡ እምድር፡ አኮ፡ ዘአሐዱ፡ ኅብሮን። ወኢሂ፡ ዘአሐዱ፡ ግብረቶን፡ ወኢተኃብር፡ አሐቲ፡ ምስለ፡ ካልእታ፡ በኵሉ፡ ኅብራ፡ ወበኵሉ፡
#             ግብራ። ወሶበ፡ በጽሐ፡ ጊዜሁ፡ ከመ፡ ይትከሠታ፡ ኵሎን፡ አብያተ፡ ክርስቲያናት፡ ዓሠርቱ፡ ዘእምአሐቲ፡ ዕብን። ይቤሎ፡ እግዚአብሔር፡ ለ<hi rend="rubric">ላሊበላ፡ </hi>በጽሐ፡ ጊዜሁ፡ ከመ፡ ይትከሠታ፡ አብያተ፡ ክርስቲያናት፡ በእደ፡ ዚአከ፡ ዘአርአይኩከ፡ ቀዳሚ።
#             ወአንተኒ፡ ጽናዕ፡ ወተኃየል፡ ከመ፡ ትፈጽም፡ መልእክተከ። እስመ፡ ብዙኃን፡ ነፍሳት፡ ይድኅኑ፡ በውስቴቶን። አስተፋጥን፡ ሐኒጾቶን። ወናሁ፡
#             አዘዝክዎሙ፡ ለመላእክትየ፡ ከመ፡ ይርድኡከ። <pb n="124v"/>
#             <cb n="a"/>
#             <hi rend="rubric">ወላሊበላ፡</hi> አግበረ፡ ሐፃውንተ፡ ብዙኃ፡ ዘዘ፡ ዚአሁ፡ ግብረቶን። ቦለጸሪብኒ፡ ወቦ፡ ሐፂን፡ ለመፍጽሕኒ፡
#             ወቦ፡ ሐፂን፡ ለወቂር። ዘንተ፡ ኵሎ፡ ሐፃውንተ፡ ገብረ። ወካልኣነኒ፡ ብዙኃተ፡ ሐፃውንተ፡ ገብረ፡ በዘይትፌጸም፡ ሕንጻ፡ መቅደስ፡
#             ዘእምአሐቲ፡ ኰኵሕ፡ ወእምአሜሃሰ፡ ኢሐለየ፡ <hi rend="rubric">ላሊበላ፡</hi> ሕሊና፡ ዘበምድር፡ ኢለመፍቅደ፡ ሥጋሁ፡
#             ወለመፍቅደ፡ ብእሲቱ። አላ፡ ይሔሊ፡ ኵሎ፡ አሚረ፡ በእንተ፡ እሎን፡ አብያተ፡ ክርስቲናት፡ ከመ፡ ይፈጽም፡ በከመ፡ ርእየ፡ በውስተ፡ ሰማይ፡
#             እንዘ፡ ያኄይሎ፡ መንፈስ፡ ቅዱስ፡ በኵሉ፡ ውስተ፡ ኵሉ። ወአግቢሮ፡ ሐፃውንተ፡ በዘይገብር፡ ሕንጻ፡ መቅደስ፡ አዘዞሙ፡ ለኵሎሙ፡ <cb n="b"/> ሕዝብ፡ ከመ፡ ይትጋብኡ፡ ኀቤሁ። ወይቤሎሙ፡ ሶበ፡ ተጋብኡ፡ ንግሩ፡ ዓስበክሙ፡ ዘትነሥኡ፡ ኵልክሙ እለ፡ ትትራድኡኒ፡ ውስተ፡
#             ሕንጻ፡ አብያተ፡ ክርስቲያናት፡ እስመ፡ አዘዘኒ፡ እግዚአብሔር፡ ከመ፡ እግበር። አንትሙኒ፡ ንግሩ፡ በበቃልክሙ፡ ዘከመ፡ ትነሥኡ፡ ዓስበክሙ።
#             ዘሂ፡ ይትራዳእ፡ ውስተ፡ ግብረ፡ ጸሪብ። ወዘሂ፡ ይፃሙ፡ በአውፅኦ፡ መሬት። ወኵልክሙ፡ ንግሩ፡ በበቃልክሙ፡ ወዘከመ፡ ትቤሉኒ፡ እሁበክሙ፡
#             ከመ፡ ኢትበሉኒ፡ አገበረነ፡ እንበለ፡ ፈቃድነ፡ ከመ፡ ኢይኩን፡ ፃማክሙ፡ በከ፡ ሶበ፡ ታንጐረጕሩ። ወነገሩ፡ ኵሎሙ፡ በከመ፡ ሕሊና፡ ልቦሙ።
#             ውእቱኒ፡ ወሀቦሙ፡ በከመ፡ ይቤልዎ፡ ወኢያንተገ፡ ውሂቦቶሙ፡ </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="125">
#           <ab>
#             <pb n="125r"/>
#             <cb n="a"/> እምአመ፡ ወጠነ፡ ሐኒጸ፡ አብያተ፡ ክርስቲያናት፡ እስከ፡ ፈጸመ፡ ለለዕለቱ፡ ይሁቦሙ፡ ዓስቦሙ። ለዘይወቅርሂ፡
#             ወለዘይጸርብሂ፡ ወለዘያወፅእሂ፡ መሬተ፡ እምጽራበ፡ ቤተ፡ ክርስቲያን፤ ወእምውስተ፡ ሕዝብሰ፡ ብዙኃን፡ እለ፡ ተረክቡ፡ ምሉዓነ፡ ጥበብ። እለ፡
#             ወደየ፡ ላዕሌሆሙ፡ እግዚአብሔር፡ መንፈሰ፡ አእምሮ፡ ከመ፡ ቤሲላኤል፡ ወኢልያብ። ወተደለወ፡ <hi rend="rubric">ገብረ፡ መስቀል፡
#             </hi>ከመ፡ ይግበር፡ በከመ፡ አርአዮ፡ እግዚአብሔር፡ ወአኃዘ፡ ይውጥን። ወመላእክትኒ፡ አኃዙ፡ ያንሶስው፡ ምስሌሁ፡ እንዘ፡ ይሜጥኑ፡ ሎቱ፡
#             ምድረ፡ በበአምጣኖን፡ ለኵሉ፡ በበፆታሁ፡ ለንዑስኒ፡ ወለዓቢይኒ። ወውእተኒ፡ ምድረ፡ <cb n="b"/> ኀበ፡ ገብረ፡ አብያተ፡ ክርስቲያናት፡
#             ተሣየጡ፡ በወርቁ፡ እምኀቤሆሙ፡ ለእለ፡ ይኴንንዋ፡ ለይእቲ፡ ምድር፡ እንዘ፡ ያፈደፍድ፡ ኂሩተ። ወለእመሰ፡ ፈቀደ፡ ከመ፡ ይንሣእ፡ መኑ፡
#             እምከልኦ፡ ለንጉሥ። ወገብረ፡ ቀዳሚተ፡ ቤተ፡ ክርስቲያነ፡ በከመ፡ አርአዮ፡ እግዚአብሔር፡ በመንክር፡ ግብር፡ ወበመድምም፡ ኪን፡
#             ዘኢይትከሀሎ፡ ለእጓለ፡ እመሕያው፡ ከመ፡ ይግበር፡ ዘእንበለ፡ ጥበበ፡ እግዚአብሔር። ወአሠነየ፡ አፍአሂኒ፡ ወውሥጣኒ፡ ወአሠርገዋ፡ በመሳክው፡
#             ሠናያን፡ ወስቅሱቃን፡ እሙንቱ፡ ወሰቅሰቆሙኒ፡ ኢኮነ፡ ዘዕፅ፡ ወአዕማዲሆሙኒ፡ ብልዙናት፡ እማንቱ። ወገብረ፡ እንተ፡ ቅድሜሃኒ፡ ክልኤተ፡
#             አብያተ፡ <pb n="125v"/>
#             <cb n="a"/> ክርስቲያናት። ወሙፃኦንሰ፡ አሐዱ፡ አንቀጽ፡ ወይፈልጦን፡ አንቀጽ፡ ውሣጣይ። ወእንተ፡ ድኅሬሃኒ፡ ገብረ፡ አሐተ፡ ቤተ፡
#             ክርስቲያን፡ ዓባየ። ወአሠነያ፡ በብዙኅ፡ ሠርጕ። ወአኮ፡ በወርቅ፡ ወበብሩር፡ አላ፡ ሠርጓኒ፡ ዘዕብን። ወኍልቈ፡ አዕማዲሃሰ፡ ፸ ወ ፪ቱ፡
#             በኍልቈ፡ ፸ ወ ፪ቱ፡ አርድእት፡ እንተ፡ በየማናኒ፡ ገብረ፡ አሐተ፡ ቤተ፡ ክርስቲያነ፡፡ ወእንተ፡ በጸጋማኒ፡ ገብረ፡ አሐተ፡ ቤተ፡
#             ክርስቲያነ። ወሰመያ፡ ለቀዳሚት፡ <hi rend="rubric">ቤተ፡ ማርያም፡</hi> ወለእንተ፡ ቅድሜሃኒ፡ ክልኤተ፡ አብያተ፡ ክርስቲያናት፡
#             ለአሐቲ፡ ሰመያ፡ ደብረ፡ ሲና፡ ወለካልእታኒ፡ ሰመያ፡ ጎልጎታ፡ ወለእንተ፡ የማናኒ፡ ሰመያ፡ ቤተ፡ መስቀል። ወለእንተ፡ ፀጋማኒ፡ <cb n="b"/> ሰመያ፡ ቤተ፡ ደናግል። ወከመዝ፡ አስተአኃዘ፡ ፭ተ፡ ቤተ፡ ክርስቲያናተ፡ ሠናያነ፡ ዘእምአሐቲ፡ ኰኵሕ። ወክልኤተኒ፡ አብያተ፡
#             ክርስቲያናተ፡ ሠናያተ፡ ዘእምአሐቲ፡ ኰኲሕ። ወክልኤተኒ፡ አብያተ፡ ክርስቲያናት፡ ገብረ፡ ሠናያተ፡ ወግብረቶንሰ፡ ብዑድ፡ ውእቱ፡ ወቅሩባን፡
#             እማንቱ። ወባሕቱ፡ ይፈልጦን፡ ቅጽር፡ ዘሀሎ፡ ማእከሎን። ወለእልክቱሂ፡ ክልኤሆን፡ ሰመያ፡ ለአሐቲ፡ ቤተ፡ ገብርኤል።ወለካልእታኒ፡ ሰመያ፡
#             ቤተ፡ አባ፡ መጣዕ። ወከመዝ፡ አስተአኃዘ፡ እሎንተ፡ ክልኤተ፡ አብያተ፡ ክርስቲያናት። ወደመሮን፡ በቅጽር፡ ወፈለጦን፡ ካዕበ፡ በቅጽር፡
#             ወገብረ፡ ካዕበ፡ ክልኤተ፡ አብያተ፡ ክርስቲያናተ፡ መአድማነ፡ </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="126">
#           <ab>
#             <pb n="126r"/>
#             <cb n="a"/> ሕንፃ፡ ላሊበላ፡ miniature <pb n="126v"/>
#             <cb n="a"/> ወግብረቶንሰ፡ ኢይኃብር፡ ለክልኤሆን። ወለእሎንሂ፡ ሰመያ፡ ለአሐቲ፡ ቤተ፡ መርቆሬዎስ። ወለካልእታኒ፡ ሰመያ፡ ቤተ፡
#             አማኑኤል። ወከመዝ፡ አስተአኃዞን፡ ለክልኤሆን፡ አብያተ፡ ክርስቲያናት፡ ወገብረ፡ አሐቲኒ፡ ቤተ፡ ክርስቲያነ፡ እንተ፡ ባሕቲታ፡ ወግብረታኒ፡
#             ብዑደ፡ ውእቱ፡ በትእምርተ፡ መስቀል፡ ገብራ፡ በከመ፡ አመሩ፡ ሎቱ፡ መላእክት። ወበከመ፡ አርአይዎ፡ እንዘ፡ ይሜጥኑ፡ ሎቱ፡ ምድረ። ወሰመያ፡
#             ላቲኒ፡ ቤተ፡ ጊዮርጊስ። ወከመዝ፡ ፈጸሞን፡ ለዓሠርቱ፡ አብያተ፡ ክርስቲያናት። ወግብረቶንሰ፡ ዘዘዚአሆን፡ ወአርአያሆንሂ፡ ዘዘዚአሆን።
#             ወአልቦ፡ ዘገብረ፡ <hi rend="rubric">ገብረ፡ መስቀል፡ </hi>ወኢምንተኒ፡ ዘእንበለ፡ ዘአርአዮ፡ <cb n="b"/> እግዚአብሔር።
#             አላ፡ ገብረ፡ በከመ፡፡ ርእየ፡ በውስተ፡ ሳብዕ፡ ሰማይ፡ ወኢወሰከ፡ ኢዲበ፡ ኑኆን፡ ወኢዲበ፡ ቆሞን፡ ወኢዲበ፡ ሰሮን፡ አላ፡ በከመ፡ ርእየ፡
#             በከመ፡ ይቤሎ፡ እግዚአብሔር፡ ኢትወስክ፡ ኢዲበ፡ ቆሞን፡ ወኢዲበ፡ ሰሮን። ወሶበ፡ አኃዘ፡ ይውጥን፡ ሕንጻሆን፡ አኃዙ፡ መላእክትኒ፡
#             ይትራድእዎ፡ በውስተ፡ ኵሉ፡ ግብር። ወኮኑ፡ አሐደ፡ መርዔተ፡ መላእክት፡ ወሰብእ፡ በውእቱ፡ መዋዕል። እስመ፡ ተደመሩ፡ መላእክት፡ ኀበ፡
#             ኵሎሙ፡ መስተገብራነ፡ ቤተ፡ ክርስቲያን፡ ኀበ፡ ጸረብትኒ፡ ወኀበ፡ ወቀርትኒ። ወኀበ፡ ፀወርተ፡ መሬትኒ፡ መዓልተሰ፡ ይትጌበሩ፡ መላእክት፡
#             ምስለ፡ ሰብእ፡ ውስተ፡ ሕንጻ፡ አብያተ፡ ክርስቲያን። ወሌሊተሰ፡ ይትገበሩ፡ መላእክት፤ </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="127">
#           <ab>
#             <pb n="127r"/>
#             <cb n="a"/> መዓልተ፡ ሶበ፡ ይገብሩ፡ አሐተ፡ ዕመተ። ወበሳኒታ፡ ይትረከብ፡ ከዊኖ፡ አርባዕተ፡ ዕመተ። እስመ፡ መላእክት፡ ይገብሩ፡
#             በኵሉ፡ ለያልይ። ወእለ፡ ርእዩ፡ ይቤሉ፡ ምንትኑዝ፡ መንክር። ንሕነሰ፡ ኃደግነ፡ አሐሰ፡ ዕመተ፡ ታማልም። ወይእዜሰ፡ ኮነ፡ አርባዕተ፡
#             ዕመተ። እስመ፡ ኢይአምሩ፡ እሙንቱ፡ ሰብእ፡ ከመ፡ መላእክት፡ ይገብሩ፡ እስመ፡ ኢይሬእይዎሙ። ወ<hi rend="rubric">ላሊበላ</hi>ሰ፡ የአምርዎ፡ ዘንተ፡ እስመ፡ የአምሩ፡ መላእክት፡ ኂሩቶ። ወበእንተዝ፡ ኢይሤወርዎ፡ እስመ፡ ኮንዎ፡ ኣብያጸ፡ እሳታውያን፡
#             ወበእንተዝ፡ ኢይትኃብእዎ፡ ወከመዝ፡ ፈጸመ፡ ሐኒጸቶን፡ ለእላንቱ፡ አብያተ፡ ክርስቲያናት፡ ዓሠርቱ። ወግብረቶንሰ፡ <cb n="b"/>
#             እምአሐዱ፡ ዕብን። ርእዩኬ፡ ኦፍቁራንየ፡ ዘከመዝ፡ ብእሴ፡ ዘበእዴሁ፡ ተከሥታ፡ እሎን፡ አብያተ፡ ክርስቲያናት፡ ዘኢተገብረ፡ ዘከማሆን፡
#             በኀበ፡ ካልአን፡ በሐውርት። በአይ፡ ልሳን፡ ንክል፡ ነጊረ፡ ግብረቶን፡ ለእሎን፡ አብያተ፡ ክርስቲያናት። ወግብረተ፡ ቅጽሮንሂ፡ ኢንክል፡
#             ነጊረ፡ ኅድጉሰ፡ እንተ፡ ውሥጦን። ዘርእየኒ፡ ኢይጸግብ፡ በነጽሮ። ወበአንክሮኒ፡ ኢይክል፡ ልብ፡ ፈጽሞ። እስመ፡ መንክር፡ ተገብረ፡ በእደ፡
#               <hi rend="rubric">ላሊበላ፡ </hi>ዘኢይትከሀሎ፡ ለሥጋዊ፡ ከመ፡ ይኈልቍ፡ መንክራቲሁ። እመቦ፡ ዘይኌልቆሙ፡ ለከዋክብተ፡
#             ሰማይ። ይኋልቆሙ፡ ለመንክራትኒ፡ ዘተገብራ፡ በእደ፡ <hi rend="rubric">ላሊበላ፡</hi>
#             <pb n="127v"/>
#             <cb n="a"/> ቤተ፡ ማርያምን፡ እም{}ዳአነፀ፡ miniature </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="128">
#           <ab>
#             <pb n="128r"/>
#             <cb n="a"/> ወለእመሰቦ፡ ዘይፈቅድ፡ ከመ፡ ይርአይ፡ ገብረ፡ ሕንጻሆን፡ ለአብያተ፡ ክርስቲያናት፡ ዘተገብራ፡ በእደ፡ <hi rend="rubric">ላሊበላ፡ </hi>ይምጻእ፡ ወይርአይ፡ በአዕይንቲሁ፡ እስመ፡ አኮ፡ ዘይበልያ፡ ሕንጻ፡ ማኅፈዱ፡ ለ<hi rend="rubric">ላሊበላ፡ </hi>ከመ፡ ደብተራ፡ ሙሴ። ወኢሂ፡ ከመ፡ ምኵራበ፡ ሰሎሞን፡ ዘይነስትዎን፡ ዓላውያን። ማኅፈደ፡
#             ደብተራሁሰ፡ ለ<hi rend="rubric">ገብረ፡ መስቀል፡</hi> ኢያንቀለቅላ፡ ወኢይማስና፡ እስከ፡ ታስተርኢ፡ ኢየሩሳሌም፡ ሰማያዊት፡
#             ዲበ፡ ምድር፡ እንተ፡ ድሉት፡ ለኅሩያን፡ እለ፡ ይደልዎሙ፡ ከመ፡ ይኅድሩ፡ ውስቴታ። <hi rend="rubric">ጴጥሮስ፡</hi> ወ<hi rend="rubric">ጳውሎስ፡</hi> ምስለ፡ <hi rend="rubric">ኢየሱስ፡</hi> ሊቆሙ፡ ፈጸሙ፡ ሐኒጾተ፡ መርጡላ፡
#             ለድንግል፡ በሠለስቱ፡ አዕባን፡ እንዘ፡ ይለመልማ፡ <cb n="b"/> ከመ፡ ሰምዕ፡ በትእዛዘ፡ እግዚአብሔር። ወ<hi rend="rubric">ላሊበላ፡ </hi>ኒ፡ ፈጸመ፡ ዓሠርተ፡ አብያተ፡ ክርስቲያናት፡ በአሐዱ፡ ዕብን። እንዘ፡ ትረድኦ፡ ጸጋ፡ እግዚአብሔር፡ ምስለ፡
#             ኃይላቲሁ። <hi rend="rubric">ጴጥሮስ፡</hi> ወ<hi rend="rubric">ጳውሎስ፡</hi> ሐነጹ፡ ነፍሳተ፡ ብዙኃ፡ በአሐዱ፡
#             ሐይማኖት። ወ<hi rend="rubric">ላሊበላ፡ </hi>ኒ፡ ሐነጸ፡ ብዙኃ፡ አብያተ፡ ክርስቲያናት፡ በአሐዱ፡ ዕብን። <hi rend="rubric">ጴጥሮስ፡</hi> ወ<hi rend="rubric">ጳውሎስ፡</hi> ሣረሩ፡ አብያተ፡ ክርስቲያናት፡ ዲበ፡ አሐዱ፡
#             ኰኵሕ። ወግብረቶንሰ፡ በፅቡር፡ ወበአኅባለ፡ ጠፈር፡ ወበመዋጽሕት፡ ዘዕፅ፡ ወአዕማዲሆንኒ፡ ዘዕፅ። ወ<hi rend="rubric">ላሊበላ፡
#             </hi>ኒ፡ ሣረረ፡ ብዙኃተ፡ አብያተ፡ ክርስቲያናት፡ ዘእምአሐዱ፡ ዕብን፡ ዘአልቦ፡ ጽቡረ፡ ለመአኅዝቲሆን፡ <pb n="128v"/>
#             <cb n="a"/> ዘአልቦ፡ ጠፈር፡ ለመአቀዶን፡ ወዘአልቦ፡ መሥዕርተ፡ ለመክደኖን። ወኵሎሰ፡ ግብረቲሆን፡ ኢንክል፡ ንንግር፡ በበገጹ።
#             እስመ፡ ብዙኅ፡ ፆታ፡ ግብረቶን። ናሁ፡ ተስዕነኒ፡ ሊተሰ፡ ላዕላዓ፡ ልሳን፡ ከመ፡ እጽሐፍ፡ ለክሙ፡ ኵሎ፡ ኂሩታቲሁ፡ ለዝንቱ፡ ብእሲ፡
#             ክቡር፡ <hi rend="rubric">ላሊበላ፡ </hi>ዘከብረ፡ እምኵሎሙ፡ መሬታውያን፡ በጥበብኒ፡ ወበስነ፡ ጽድቅኒ፡ ተብህለ፡ ከመ፡
#             ሰሎሞን፡ ጠቢብ፡ እምኵሉ፡ እጓለ፡ እመሕያው፡ ወእምኵሎሙ፡ ጠቢባነ፡ ግብጽ። ወውእቱኒ፡ ገብረ፡ ምኵራበ፡ በኢየሩሳሌም፡ በአዕባን፡ ዓበይት፡
#             ዘዘሳምን፡ ወዘዘ፡ ሳብዕ፡ ኑኆን። እንዘ፡ ይረድኦ፡ ኪራም፡ ንጉሠ፡ ጢሮስ፡ በዕፀወ፡ ቄድሮና፡ <cb n="b"/> ወበዕፀወ፡ ጳውቄና፡
#             ወበዕፀወ፡ ቄጳርስ። ወፈጸመ፡ ክልኤቱ፡ አብያተ። ቤተ፡ እግዚአብሔርኒ፡ ወቤተ፡ ርእሱኒ፡ በ፳፡ ዓመት። ወ<hi rend="rubric">ላሊበላ፡ </hi>ሰ፡ ገብረ፡ ዓሠርተ፡ አብያተ፡ ክርስቲያናት፡ በአሐዱ፡ ዕብን፡ እንዘ፡ ይረድኦ፡ ወልደ፡ እግዚአብሔር። እምእለ፡
#             ክልኤቱ፡ ጠቢባን፡ ተገብራ፡ ክልኤቱ፡ ምኵራባት። ምኵራቡሰ፡ ለአሐዱ፡ ጠቢብ፡ በዕብን፡ ወበዕፀው፡ ወበአሕባል፡ ወበፅቡር። ወካልኡኒ፡ ጠቢብ፡
#             ገብረ፡ ማኅፈዳቲሁ፡ ዘእምአሐቲ፡ ዕብን። እንዘ፡ ኢይፈቅድ፡ ወኢምንተኒ፡ ለመፍቅዶን። ወኢዕፀ፡ ለመሳክዊሆን፡ ወኢአኅባለ፡ ለመአቂዶን፡
#             ወኢፅቡረ፡ ለመአኅዝቲሆን። እስመ፡ በአሐቲ፡ ዕብን፡ ፈጸመ፡ ኵሎ፡ </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="129">
#           <ab>
#             <pb n="129r"/>
#             <cb n="a"/> ፲፯ ግብረታቲሆን። ግብረ፡ ቅጽሮንሂ፡ ዘእምአሐዱ፡ ዕብን። ወግብረተ፡ ውሣጥያቲሆንሂ፡ ዘእምአሐዱ፡ ዕብን። ወእምፃማ፡
#             ውሣጥያቲሆንሰ፡ የዓቢ፡ ፃማ፡ ቅጽራቲሆን። ኵሉኬ፡ ሰብእ፡ እንዘ፡ ኢትዮጵያዊ፡ ውእቱ፡ ዘኢበጽሐ፡ ውስተ፡ ሀገረ፡ ሮሐ፡ ቅድስት፡ እንዘ፡
#             ይሰምዕ፡ ዜናሆን፡ ለእላንቱ፡ አብያተ፡ ክርስቲያናት፡ እለ፡ ተገብራ፡ ዘእምአሐቲ፡ ዕብን፡ ይትሜሰል፡ ከመ፡ ብእሲ፡ ዘኢያፈቅር፡ ከመ፡
#             ይርአይ፡ ገጾ፡ ለእግዚእነ፡ ወመድኃኒነ፡ <hi rend="rubric">ኢየሱስ፡ ክርስቶስ፡</hi> ወብፁዕሰ፡ ወቅዱስ፡<hi rend="rubric">ላሊበላ፡ </hi> ሶበ፡ ፈጸመ፡ ሕንጻሆን፡ ለእማንቱ፡ አብያተ፡ <cb n="b"/> ክርስቲያናት፡ ዘከመ፡ አርአዮ፡
#             እግዚአብሔር። ኢፈቀደ፡ ከመ፡ ይጐንዲ፡ ላዕሌሁ፡ ሢመተ፡ መንግሥት፡ ወኢፈቀደ፡ ከመ፡ ትዕዱ፡ ላዕለ፡ ወልዱኒ። አላ፡ ይቤ፡ ይሚጣ፡ ለዚቲ፡
#             ሢመተ፡ መንግሥት፡ ወያግብአ፡ ኀበ፡ እስራኤል። እስመ፡ ሎሙ፡ ይቤሎሙ፡ በእንቲአክሙ፡ ፈጠርክዎሙ፡ ለኵሎሙ፡ አሕዛብ፡ ወካዕበ፡ መሐለ፡ ሎሙ፡
#             እንዘ፡ ይብል፡ ኢይሜንኖሙ፡ ለሕዝበ፡ ያዕቆብ። ወኢያስተሐቅሮሙ፡ ለሕዝበ፡ እስራኤል። እስመ፡ ኪያሆሙ፡ ኃረይኩ፡ እምኵሎሙ፡ አሕዛብ። በከመ፡
#             ይቤ፡ ነቢይ፡ መሐለ፡ እግዚአብሔር፡ ለዳዊት፡ በጽድቅ፡ <pb n="129v"/>
#             <cb n="a"/> ወኢይኔስሕ። እስመ፡ ይቤሎ፡ አነብር፡ ዲበ፡ መንበርከ፡ ወይእዜኒ፡ ለያግብኣ፡ እግዚአብሔር፡ ለዛቲ፡ መንግሥት፡ ኀበ፡
#             እስራኤል፡ ወኢይትኃጣእ፡ እምነ፡ ቤተ፡ እስራኤል፡ ዘይነብር፡ ዲበ፡ መንበረ፡ መንግሥት። ኢያጐንዲ፡ እግዚአ፡ ኃያላን፡ ዛቲ፡ ሢመተ፡
#             መንሥት፡ ኢያጐንዲ፡ እግዚኣ፡ ኃያላን፡ ዛቲ፡ ሢመተ፡ መንግሥት፡ ኢዲቤየ፡ ወኢዲ፡ አዝማድየ። ወናሁ፡ አንሰ፡ ፈጸምኩ፡ መልእክትየ፡
#             ዘበእንቲአሃ፡ ሤመኒ፡ ሢመተ፡ መንግሥት። እንዘ፡ ለሊሁ፡ እግዚአብሔር፡ ይገብር፡ በእደ፡ መላእክቲሁ። ከመዝ፡ ይቤ፡ <hi rend="rubric">ገብረ፡ መስቀል፡ </hi>ንጉሥ፡ እስመ፡ ኢያፈቅር፡ ሢመተ፡ ዘበምድር፡ <cb n="b"/> ፈጺሞ፡ መልእክቶ፡
#             ወመጽዊቶ፡ ኵሎ፡ ጥሪቶ። እስከ፡ ኢይተርፍ፡ አሣዕነ፡ ዲበ፡ እገሪሁ። ወአሠርጊዎ፡ አብያተ፡ ክርስቲያናቲሁ፡ ዘገብረ፡ በውስተ፡ ኵሉ፡
#             በሐውርት። ወእሎንተኒ፡ ዓሠርተ፡ ማኅፈዳተ፡ ዘገብረ፡ ዘእምአሐቲ፡ ዕብን። አሠርገወ፡ በሠርጕ፡ ዘይደሉ፡ ለቤተ፡ ክርስቲያን፡ በመስቀልኒ፡
#             ወበአልባስኒ፡ ወቦ፡ ዘአሠርጊዎን፡ በሥዕልኒ። ወፈድፋደሰ፡ ገብረ፡ መድምመ፡ በመካነ፡ ጎልጎታ። በድነ፡ መካሀ፡ ዘለበግዑ፡ ዘኢየዓፂ፡ በድኑ።
#             ወካልአነሂ፡ ሥዕለተ፡ ብዙኃ፡ ገብረ፡ እስመ፡ በእንቲአሆን፡ ይተግህ፡ መዓልተ፡ ወሌሊተ። ወኢይሔሊ፡ ካልአ፡ መፍቅደ፡ ሥጋ፡ ኢመብልዓ፡
#             ለሲሲቱ። </ab>
#         </div>
#         <div type="textpart" subtype="folio" n="130">
#           <ab>
#             <pb n="130r"/>
#             <cb n="a"/> ወኢልብሰ፡ ለዓራዙ። ወኢተከዘ፡ በእንተ፡ ብእሲቱኒ፡ ወበእንተ፡ ውሉዱኒ፡ ዘእንበለ፡ በእንዚአሆን፡ ለአብያተ፡
#             ክርስቲያናት። ወሶበ፡ ፈጸሞን፡ ጸለየ፡ በውስቴቶን፡ እንዘ፡ ይብል፡ ኵሉ፡ ዘጌሠ፡ ውስተ፡ እላንቱ፡ አጽራሐ፡ ቅድሳቲከ፡ ዘገበርከ፡ በእደ፡
#             ዚአየ፡ ሀበኒ፡ አሥራተ፡ ኦእግዚእየ፨ ወይቤሎ፡ እግዚአብሔር፡ ይኩንከ፡ በከመ፡ ትቤ። ለእመ፡ ጌሠ፡ ውስተ፡ ቤተ፡ ክርስቲያንከ፡ በንጹሕ፡
#             ኦኅሩይየ፡ ከማሁ፡ በከመ፡ ሰአልከ። አንተሰ፡ ፈጸምከ፡ መልእክተከ፡ ወዓቀብከ፡ ሃይማኖተከ። እምይእዜሰ፡ ጽኑሕ፡ ለከ፡ አክሊለ፡ ጽድቅ፡
#             ወርኅው፡ ለከ፡ ኆኅተ፡ መንግሥተ፡ ሰማያት፡ ከመ፡ ትባእ፡ በፍሥሐ። ወዘንተ፡ እምድኅረ፡ <cb n="b"/> ይቤሎ፡ መድኃኒነ። ሐመ፡ ብፁዕ፡
#               <hi rend="rubric">ላሊበላ፡ </hi> ንስቲተ፡ ወአዕረፈ፡ አመ፡ ፳ ወ ፪፡ ለወርኃ፡ ሐዚራን። ወተመጠው፡ ነፍሶ፡ ንጽሕት፡
#             መላእክተ፡ ብርሃን። ወፆሮ፡ <hi rend="rubric">ገብርኤል፡ </hi>ዲበ፡ አክናፊሁ። ወካልአን፡ መላእክት፡ እንዘ፡ ይዜምሩ፡
#             በቅድሜሁ፡ ወበጽኅሬሁ። አዕረግዎ፡ ውስተ፡ ሰማይ። ወአተወ፡ <hi rend="rubric">ገብረ፡ መስቀል፡</hi> ውስተ፡ ምዕራፊሁ፡
#             ዘለዓለም። ወኃደረ፡ ምስለ፡ <hi rend="rubric">ጴጥሮስ፡ </hi>ወ<hi rend="rubric">ጳውሎስ፡</hi> እስመ፡ ከመዝ፡
#             ኪዳን፡ ተውህቦ፡ እምኀበ፡ መድኅን፡ ናሁኬ፡ ለካእኩ፡ ለክሙ፡ ኦፍቁራንየ፡ ንስቲተ፡ ዜና፡ እምትሩፋቲሁ፡ ለ<hi rend="rubric">ገብረ፡ መስቀል፡ </hi>ከመ፡ ይትፈሣሕ፡ ልብክሙ፡ ወይኩነነ፡ ለኵልነ፡ እለ፡ ተጋባእነ፡ ዝየ፡ ኃይለ፡ ጸሎቱ፡ ጊራ፡ <pb n="130v"/>
#             <cb n="a"/> ምክህ፡ ለርእስነ። ወጸዳለ፡ ሱራሔ፡ ለገጽነ። ወኵሕለ፡ መድኃኒት፡ ለአዕይንቲነ። ወአዕኑገ፡ ሣህል፡ ለእዛኒነ። ወመዓዛ፡
#             ሠናየ፡ ለአዕናፈነ። ወማኅተመ፡ ጽድቅ፡ ለከናፍሪነ። ወሞጣሕተ፡ ፍሥሐ፡ ለዘባንነ። ወእልታሐ፡ መዊእ፡ ለእንግድዓነ፤ ወአውቃፈ፡ ምሕረት፡
#             ለእደዊነ። ወሕልቀተ፡ ፍቅር፡ ለአፃብኢነ። ወአሣዕነ፡ አድኅኖ፡ ለእገሪነ። ወስቴ፡ ሕይወት፡ ለጽምዕነ። ወኅብስተ፡ መና፡ ለርኃብነ። ወኀበ፡
#             ቦአ፡ ቤተ፡ መርዐ፡ መርዓ፡ ምስሌሁ፡ ያብአነ። በጽላሎተ፡ ክነፊሁ፡ እንዘ፡ ይከድነነ። ወኀበ፡ ረፈቀ፡ ያርፍቀነ። ለዓለመ፡ ዓለም፡ አሜን፨
#             ................................................................
#             ................................................................
#             .................................................................. <cb n="b"/> ለዘጸሐፎ፡
#             ወለዘአጽሐፎ፨ ለዘአንበቦ፡ ወለዘተርጐሞ፡ ወለዘሰምዓ፡ ቃላቲሁ፡ ኅቡረ፡ ይምሐሮሙ፡ እግዚአብሔር፡ በመንግሥተ፡ ሰማያት። በጸሎታ፡ ለ<hi rend="rubric">ማርያም፡</hi> ወዲተ፡ አምላክ። ወበትንብልናሆሙ፡ ለ<hi rend="rubric">ሚካኤል፡</hi> ወ<hi rend="rubric">ገብርኤል፡</hi> ወበጸሎተ፡ ነቢያት፡ ወሐዋርያት፡ ወበጸሎተ፡ ጻድቃን፡ ወሰማዕት። ወበጸሎተ፡ <hi rend="rubric">ላሊበላ፡ </hi> ወ<hi rend="rubric">መስቀል፡ ክብራ፡ </hi>እግዚአብሔር፡ ይምሐራ፡ ለንግሥትነ፡
#               <hi rend="rubric">ወለተ፡ ኢየሱስ፡ /</hi>ወለውሉዳ፡ <hi rend="rubric">ኃይለ፡ ኢየሱስ፡</hi> ኃይለ፡ <hi rend="rubric">ሚካኤል፡</hi> ወልደ፡ <hi rend="rubric">ማርያም፡</hi> ወላአዋልዲሃ፡ <hi rend="rubric">{ወለተ፡ ማርያም፡} ኂሩተ፡ ሥላሴ፡</hi> ለዓለመ፡ ዓለም፡ አሜን።
#             ..............................................................
#             .............................................................
#             ............................................................. </ab>
#         </div>
#       </div>
#     </body>
#   </text>
# </TEI>
