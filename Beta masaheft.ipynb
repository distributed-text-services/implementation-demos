# %% [markdown]
# Beta maṣāḥǝft
# ===
#
# The Beta maṣāḥǝft implementation is a specific implementation built by Pietro Liuzzo
#
# ## Configuration
#
# The following cell are used to avoid rewriting to much cells if the address of the DTS API were to change.

# %%
import requests
import requests_cache
from pprint import pprint
from urllib.parse import urljoin

URI = "https://betamasaheft.eu/api/dts"

# define hearders for HTTP requests
h = {'User-Agent': 'DTS Client'}

# %% [markdown]
# ## Getting the available endpoints
#
# DTS entry point is a listing of the available endpoints and their URL. This means that for each implementation of DTS, this single URL will give you all the information you need to perform arbitrary queries, if you were to do so. The Beta maṣāḥǝft implementation provide the three endpoints :

# %%
entry_request = requests.get(URI, headers=h)
ENDPOINTS = entry_request.json()
ENDPOINTS
# Out:
# {'indexes': '/api/dts/indexes',
#  'annotations': '/api/dts/annotations',
#  '@context': 'api/dts/contexts/EntryPoint.jsonld',
#  'navigation': '/api/dts/navigation',
#  'collections': '/api/dts/collections',
#  '@type': 'EntryPoint',
#  'document': '/api/dts/document',
#  '@id': '/api/dts'}

# %% [markdown]
# As you can see, all three endpoints have been given URIs. Because we do not know the text we want to see, we'll browse from here :

# %% [markdown]
# ## Browsing the root of the catalog
#
# The root of the data catalog is the result of the basic GET request on the `collections` endpoint :

# %%
ROOT_COLLECTION  = requests.get(
    urljoin(URI, ENDPOINTS["collections"]),
    headers=h
).json()
ROOT_COLLECTION
# Out:
# {'@context': {'lawd': 'http://lawd.info/ontology/',
#   'dts': 'https://w3id.org/dts/api#',
#   'saws': 'http://purl.org/saws/ontology#',
#   '@vocab': 'https://www.w3.org/ns/hydra/core#',
#   'fabio': 'http://purl.org/spar/fabio',
#   'foaf': 'http://xmlns.com/foaf/0.1/',
#   'edm': 'http://www.europeana.eu/schemas/edm/',
#   'sc': 'http://iiif.io/api/presentation/2#',
#   'svcs': 'http://rdfs.org/sioc/services#',
#   'tei': 'http://www.tei-c.org/ns/1.0',
#   'ecrm': 'http://erlangen-crm.org/current/',
#   'doap': 'http://usefulinc.com/ns/doap#',
#   'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#   'dc': 'http://purl.org/dc/terms/'},
#  'dts:dublincore': {'dc:publisher': ['Akademie der Wissenschaften in Hamburg',
#    'Hiob-Ludolf-Zentrum für Äthiopistik'],
#   'dc:description': [{'@lang': 'en',
#     '@value': "The project Beta maṣāḥǝft: Manuscripts of Ethiopia and Eritrea (Schriftkultur des christlichen Äthiopiens: eine multimediale Forschungsumgebung) is a long-term project funded within the framework of the Academies' Programme (coordinated by the Union of the German Academies of Sciences and Humanities) under survey of the Akademie der Wissenschaften in Hamburg. The funding will be provided for 25 years, from 2016–2040. The project is hosted by the Hiob Ludolf Centre for Ethiopian Studies at the University of Hamburg. It aims at creating a virtual research environment that shall manage complex data related to predominantly Christian manuscript tradition of the Ethiopian and Eritrean Highlands."}]},
#  'title': 'Beta maṣāḥǝft',
#  'member': [{'title': 'Beta maṣāḥǝft Textual Units',
#    '@type': 'Collection',
#    '@id': 'https://betamasaheft.eu/textualunits',
#    'totalItems': 1921,
#    'description': 'Collection of textual units of the Ethiopic tradition'},
#   {'title': 'Beta maṣāḥǝft Narrative Units',
#    '@type': 'Collection',
#    '@id': 'https://betamasaheft.eu/narrativeunits',
#    'totalItems': 182,
#    'description': 'Collection of narrative units of the Ethiopic tradition'},
#   {'title': 'Beta maṣāḥǝft Manuscripts',
#    '@type': 'Collection',
#    '@id': 'https://betamasaheft.eu/transcriptions',
#    'totalItems': 208,
#    'description': 'Collection of Ethiopic Manuscript trasncriptions'}],
#  '@type': 'Collection',
#  '@id': 'https://betamasaheft.eu',
#  'totalItems': 3,
#  'description': "The project Beta maṣāḥǝft: Manuscripts of Ethiopia and Eritrea (Schriftkultur des christlichen Äthiopiens: eine multimediale Forschungsumgebung) is a long-term project funded within the framework of the Academies' Programme (coordinated by the Union of the German Academies of Sciences and Humanities) under survey of the Akademie der Wissenschaften in Hamburg. The funding will be provided for 25 years, from 2016–2040. The project is hosted by the Hiob Ludolf Centre for Ethiopian Studies at the University of Hamburg. It aims at creating a virtual research environment that shall manage complex data related to predominantly Christian manuscript tradition of the Ethiopian and Eritrean Highlands."}

# %% [markdown]
# The root collection has 2 items : let's go see the one made of manuscripts (`@id=https://betamasaheft.eu/transcriptions`)!

# %% [markdown]
# ## Requesting a specific collection
#
# Requesting a specific collection is simple : you go to the Collections endpoint, add the parameter `id` with the `@id` property of your item.
#
# ### Manuscripts Collections
#
# We first want to get the Manuscripts collection : it will be at the URI http://betamasaheft.eu/api/dts/collections?id=https://betamasaheft.eu/transcriptions

# %%
collection_id = "https://betamasaheft.eu/transcriptions"

# %%
Manuscript_Collection  = requests.get(
    urljoin(URI, ENDPOINTS["collections"]+f"?id={collection_id}"),
    headers=h
).json()
print(urljoin(URI, ENDPOINTS["collections"]+f"?id={collection_id}"))
pprint(Manuscript_Collection)
#Let's check page X where we have BLorient718
# Out:
# https://betamasaheft.eu/api/dts/collections?id=https://betamasaheft.eu/transcriptions
# {'@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#               'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#               'dc': 'http://purl.org/dc/terms/',
#               'doap': 'http://usefulinc.com/ns/doap#',
#               'dts': 'https://w3id.org/dts/api#',
#               'ecrm': 'http://erlangen-crm.org/current/',
#               'edm': 'http://www.europeana.eu/schemas/edm/',
#               'fabio': 'http://purl.org/spar/fabio',
#               'foaf': 'http://xmlns.com/foaf/0.1/',
#               'lawd': 'http://lawd.info/ontology/',
#               'saws': 'http://purl.org/saws/ontology#',
#               'sc': 'http://iiif.io/api/presentation/2#',
#               'svcs': 'http://rdfs.org/sioc/services#',
#               'tei': 'http://www.tei-c.org/ns/1.0'},
#  '@id': 'https://betamasaheft.eu/transcriptions',
#  '@type': 'Collection',
#  'dts:dublincore': {'dc:description': [{'@lang': 'en',
#                                         '@value': 'The project Beta maṣāḥǝft: '
#                                                   'Manuscripts of Ethiopia and '
#                                                   'Eritrea (Schriftkultur des '
#                                                   'christlichen Äthiopiens: '
#                                                   'eine multimediale '
#                                                   'Forschungsumgebung) is a '
#                                                   'long-term project funded '
#                                                   'within the framework of the '
#                                                   "Academies' Programme "
#                                                   '(coordinated by the Union '
#                                                   'of the German Academies of '
#                                                   'Sciences and Humanities) '
#                                                   'under survey of the '
#                                                   'Akademie der Wissenschaften '
#                                                   'in Hamburg. The funding '
#                                                   'will be provided for 25 '
#                                                   'years, from 2016–2040. The '
#                                                   'project is hosted by the '
#                                                   'Hiob Ludolf Centre for '
#                                                   'Ethiopian Studies at the '
#                                                   'University of Hamburg. It '
#                                                   'aims at creating a virtual '
#                                                   'research environment that '
#                                                   'shall manage complex data '
#                                                   'related to predominantly '
#                                                   'Christian manuscript '
#                                                   'tradition of the Ethiopian '
#                                                   'and Eritrean Highlands.'}],
#                     'dc:publisher': ['Akademie der Wissenschaften in Hamburg',
#                                      'Hiob-Ludolf-Zentrum für Äthiopistik']},
#  'member': [{'@id': 'https://betamasaheft.eu/DW03',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Goǧǧām, Dabra '
#                             'Warq, Dabra Warq 03 in Beta maṣāḥǝft ',
#              'dts:citeDepth': 2,
#              'dts:citeStructure': [[{'dts:citeType': 'chapter'},
#                                     {'dts:citeStructure': None,
#                                      'dts:citeType': 'month'},
#                                     {'dts:citeType': 'commemoration'}]],
#              'dts:download': 'https://betamasaheft.eu/tei/DW03.xml',
#              'dts:dublincore': {'dc:contributor': ['Daria Elagina',
#                                                    'Dorothea Reule',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['ar', 'gez', 'am'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Goǧǧām, Dabra Warq, '
#                                                        'Dabra Warq 03'}},
#              'dts:extensions': {'crm:P1_is_identified_by': ['Dabra Warq 03',
#                                                             'UNESCO 12.3',
#                                                             'EMIPMM00641'],
#                                 'dc:hasPart': 'https://betamasaheft.eu/LIT2375Synaxa'},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/DW03',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/DW03',
#              'title': 'Goǧǧām, Dabra Warq, Dabra Warq 03',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/DabraLibanosHamGG1',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Ham, Dabra '
#                             'Libānos, Golden Gospel in Beta maṣāḥǝft ',
#              'dts:citeDepth': None,
#              'dts:citeStructure': [None],
#              'dts:download': 'https://betamasaheft.eu/tei/DabraLibanosHamGG1.xml',
#              'dts:dublincore': {'dc:contributor': ['Nafisa Valieva',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Eugenia Sokolinski',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'it', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Ham, Dabra Libānos, '
#                                                        'Golden Gospel'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'Golden Gospel',
#                                 'foaf:depiction': {'@id': 'https://betamasaheft.eu/manuscript/DabraLibanosHamGG1/viewer',
#                                                    '@type': 'edm:WebResource',
#                                                    'svcs:has_service': {'@id': 'https://betamasaheft.eu/api/iiif/DabraLibanosHamGG1/manifest',
#                                                                         '@type': 'svcs:Service',
#                                                                         'dcterms:conformsTo': 'http://iiif.io/api/image',
#                                                                         'doap:implements': 'http://iiif.io/api/image/2/level1.json'}}},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'title': 'Ham, Dabra Libānos, Golden Gospel',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/DabraLibanosHamGG1',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Ham, Dabra '
#                             'Libānos, Golden Gospel in Beta maṣāḥǝft ',
#              'dts:citeDepth': 1,
#              'dts:citeStructure': [{'dts:citeType': 'line'}],
#              'dts:download': 'https://betamasaheft.eu/tei/DabraLibanosHamGG1.xml',
#              'dts:dublincore': {'dc:contributor': ['Nafisa Valieva',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Eugenia Sokolinski',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'it', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Ham, Dabra Libānos, '
#                                                        'Golden Gospel'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'Golden Gospel',
#                                 'foaf:depiction': {'@id': 'https://betamasaheft.eu/manuscript/DabraLibanosHamGG1/viewer',
#                                                    '@type': 'edm:WebResource',
#                                                    'svcs:has_service': {'@id': 'https://betamasaheft.eu/api/iiif/DabraLibanosHamGG1/manifest',
#                                                                         '@type': 'svcs:Service',
#                                                                         'dcterms:conformsTo': 'http://iiif.io/api/image',
#                                                                         'doap:implements': 'http://iiif.io/api/image/2/level1.json'}}},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'title': 'Ham, Dabra Libānos, Golden Gospel',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/DabraLibanosHamGG1',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Ham, Dabra '
#                             'Libānos, Golden Gospel in Beta maṣāḥǝft ',
#              'dts:citeDepth': 1,
#              'dts:citeStructure': [{'dts:citeType': 'line'}],
#              'dts:download': 'https://betamasaheft.eu/tei/DabraLibanosHamGG1.xml',
#              'dts:dublincore': {'dc:contributor': ['Nafisa Valieva',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Eugenia Sokolinski',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'it', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Ham, Dabra Libānos, '
#                                                        'Golden Gospel'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'Golden Gospel',
#                                 'foaf:depiction': {'@id': 'https://betamasaheft.eu/manuscript/DabraLibanosHamGG1/viewer',
#                                                    '@type': 'edm:WebResource',
#                                                    'svcs:has_service': {'@id': 'https://betamasaheft.eu/api/iiif/DabraLibanosHamGG1/manifest',
#                                                                         '@type': 'svcs:Service',
#                                                                         'dcterms:conformsTo': 'http://iiif.io/api/image',
#                                                                         'doap:implements': 'http://iiif.io/api/image/2/level1.json'}}},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'title': 'Ham, Dabra Libānos, Golden Gospel',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/DabraLibanosHamGG1',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Ham, Dabra '
#                             'Libānos, Golden Gospel in Beta maṣāḥǝft ',
#              'dts:citeDepth': 1,
#              'dts:citeStructure': [{'dts:citeType': 'line'}],
#              'dts:download': 'https://betamasaheft.eu/tei/DabraLibanosHamGG1.xml',
#              'dts:dublincore': {'dc:contributor': ['Nafisa Valieva',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Eugenia Sokolinski',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'it', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Ham, Dabra Libānos, '
#                                                        'Golden Gospel'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'Golden Gospel',
#                                 'foaf:depiction': {'@id': 'https://betamasaheft.eu/manuscript/DabraLibanosHamGG1/viewer',
#                                                    '@type': 'edm:WebResource',
#                                                    'svcs:has_service': {'@id': 'https://betamasaheft.eu/api/iiif/DabraLibanosHamGG1/manifest',
#                                                                         '@type': 'svcs:Service',
#                                                                         'dcterms:conformsTo': 'http://iiif.io/api/image',
#                                                                         'doap:implements': 'http://iiif.io/api/image/2/level1.json'}}},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'title': 'Ham, Dabra Libānos, Golden Gospel',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/DabraLibanosHamGG1',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Ham, Dabra '
#                             'Libānos, Golden Gospel in Beta maṣāḥǝft ',
#              'dts:citeDepth': 1,
#              'dts:citeStructure': [{'dts:citeType': 'line'}],
#              'dts:download': 'https://betamasaheft.eu/tei/DabraLibanosHamGG1.xml',
#              'dts:dublincore': {'dc:contributor': ['Nafisa Valieva',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Eugenia Sokolinski',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'it', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Ham, Dabra Libānos, '
#                                                        'Golden Gospel'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'Golden Gospel',
#                                 'foaf:depiction': {'@id': 'https://betamasaheft.eu/manuscript/DabraLibanosHamGG1/viewer',
#                                                    '@type': 'edm:WebResource',
#                                                    'svcs:has_service': {'@id': 'https://betamasaheft.eu/api/iiif/DabraLibanosHamGG1/manifest',
#                                                                         '@type': 'svcs:Service',
#                                                                         'dcterms:conformsTo': 'http://iiif.io/api/image',
#                                                                         'doap:implements': 'http://iiif.io/api/image/2/level1.json'}}},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/DabraLibanosHamGG1',
#              'title': 'Ham, Dabra Libānos, Golden Gospel',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/EMML4398',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Collegeville, '
#                             'Hill Museum and Manuscript Library, MS EMML no. '
#                             '4398 in Beta maṣāḥǝft ',
#              'dts:citeDepth': 3,
#              'dts:citeStructure': [{'dts:citeStructure': {'dts:citeType': 'commemoration'},
#                                     'dts:citeType': 'month'}],
#              'dts:download': 'https://betamasaheft.eu/tei/EMML4398.xml',
#              'dts:dublincore': {'dc:contributor': ['Dorothea Reule',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Collegeville, Hill '
#                                                        'Museum and Manuscript '
#                                                        'Library, MS EMML no. '
#                                                        '4398'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'MS EMML no. 4398',
#                                 'dc:hasPart': 'https://betamasaheft.eu/LIT4033Senkessar'},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/EMML4398',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/EMML4398',
#              'title': 'Collegeville, Hill Museum and Manuscript Library, MS '
#                       'EMML no. 4398',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/EMML4398',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Collegeville, '
#                             'Hill Museum and Manuscript Library, MS EMML no. '
#                             '4398 in Beta maṣāḥǝft ',
#              'dts:citeDepth': 2,
#              'dts:citeStructure': [{'dts:citeStructure': {'dts:citeType': 'line'},
#                                     'dts:citeType': 'folio'}],
#              'dts:download': 'https://betamasaheft.eu/tei/EMML4398.xml',
#              'dts:dublincore': {'dc:contributor': ['Dorothea Reule',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'gez'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Collegeville, Hill '
#                                                        'Museum and Manuscript '
#                                                        'Library, MS EMML no. '
#                                                        '4398'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'MS EMML no. 4398',
#                                 'dc:hasPart': 'https://betamasaheft.eu/LIT4033Senkessar'},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/EMML4398',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/EMML4398',
#              'title': 'Collegeville, Hill Museum and Manuscript Library, MS '
#                       'EMML no. 4398',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/EMML6458',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Collegeville, '
#                             'Hill Museum and Manuscript Library, MS EMML no. '
#                             '6458 in Beta maṣāḥǝft ',
#              'dts:citeDepth': 4,
#              'dts:citeStructure': [{'dts:citeStructure': {'dts:citeStructure': {'dts:citeType': 'line'},
#                                                           'dts:citeType': 'commemoration'},
#                                     'dts:citeType': 'month'}],
#              'dts:download': 'https://betamasaheft.eu/tei/EMML6458.xml',
#              'dts:dublincore': {'dc:contributor': ['Dorothea Reule',
#                                                    'Pietro Maria Liuzzo',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'ar', 'it', 'gez', 'am'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Collegeville, Hill '
#                                                        'Museum and Manuscript '
#                                                        'Library, MS EMML no. '
#                                                        '6458'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'MS EMML no. 6458',
#                                 'dc:hasPart': 'https://betamasaheft.eu/LIT4032SenkessarS'},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/EMML6458',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/EMML6458',
#              'title': 'Collegeville, Hill Museum and Manuscript Library, MS '
#                       'EMML no. 6458',
#              'totalItems': 0},
#             {'@id': 'https://betamasaheft.eu/EMML6451',
#              '@type': 'Resource',
#              'description': 'The transcription of manuscript Collegeville, '
#                             'Hill Museum and Manuscript Library, EMML6451 in '
#                             'Beta maṣāḥǝft ',
#              'dts:citeDepth': 1,
#              'dts:citeStructure': [{'dts:citeType': 'folio'}],
#              'dts:download': 'https://betamasaheft.eu/tei/EMML6451.xml',
#              'dts:dublincore': {'dc:contributor': ['Nafisa Valieva',
#                                                    'Alessandro Bausi'],
#                                 'dc:creator': ['Beta maṣāḥǝft Team'],
#                                 'dc:language': ['en', 'ar', 'it', 'gez', 'am'],
#                                 'dc:title': {'@lang': 'en',
#                                              '@value': 'Collegeville, Hill '
#                                                        'Museum and Manuscript '
#                                                        'Library, EMML6451'}},
#              'dts:extensions': {'crm:P1_is_identified_by': 'EMML6451',
#                                 'dc:hasPart': 'https://betamasaheft.eu/LIT1470GadlaL'},
#              'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/EMML6451',
#              'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/EMML6451',
#              'title': 'Collegeville, Hill Museum and Manuscript Library, '
#                       'EMML6451',
#              'totalItems': 0}],
#  'title': 'Beta maṣāḥǝft Manuscripts',
#  'totalItems': 208,
#  'view': {'@id': '/api/dts/collections?id=https://betamasaheft.eu/transcriptions&page=1',
#           '@type': 'PartialCollectionView',
#           'first': '/api/dts/collections?id=https://betamasaheft.eu/transcriptions&page=1',
#           'last': '/api/dts/collections?id=https://betamasaheft.eu/transcriptions&page=21',
#           'next': '/api/dts/collections?id=https://betamasaheft.eu/transcriptions&page=2',
#           'previous': None}}

# %% [markdown]
# ### London, British Library, BL Oriental 718
#
# There is a lot of collections, let check this one in details : urn:dts:betmasMS:BLorient718 (It's available in one of the pages and is an interesting, fully working collection)

# %%
BLorient718_coll_id = "https://betamasaheft.eu/BLorient718"

# %%
request_uri = urljoin(URI, ENDPOINTS["collections"]+f"?id={BLorient718_coll_id}")

# %%
BLorient718  = requests.get(request_uri,headers=h).json()

# %%
pprint(BLorient718)
# Out:
# {'@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#               'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#               'dc': 'http://purl.org/dc/terms/',
#               'doap': 'http://usefulinc.com/ns/doap#',
#               'dts': 'https://w3id.org/dts/api#',
#               'ecrm': 'http://erlangen-crm.org/current/',
#               'edm': 'http://www.europeana.eu/schemas/edm/',
#               'fabio': 'http://purl.org/spar/fabio',
#               'foaf': 'http://xmlns.com/foaf/0.1/',
#               'lawd': 'http://lawd.info/ontology/',
#               'saws': 'http://purl.org/saws/ontology#',
#               'sc': 'http://iiif.io/api/presentation/2#',
#               'svcs': 'http://rdfs.org/sioc/services#',
#               'tei': 'http://www.tei-c.org/ns/1.0'},
#  '@id': 'https://betamasaheft.eu/BLorient718',
#  '@type': 'Resource',
#  'description': 'The transcription of manuscript London, British Library, BL '
#                 'Oriental 718 in Beta maṣāḥǝft ',
#  'dts:citeDepth': 1,
#  'dts:citeStructure': [{'dts:citeType': 'folio'}],
#  'dts:download': 'https://betamasaheft.eu/tei/BLorient718.xml',
#  'dts:dublincore': {'dc:contributor': ['Dorothea Reule',
#                                        'Nafisa Valieva',
#                                        'Pietro Maria Liuzzo',
#                                        'Eugenia Sokolinski',
#                                        'Alessandro Bausi'],
#                     'dc:creator': ['Beta maṣāḥǝft Team'],
#                     'dc:language': ['en', 'gez', 'am'],
#                     'dc:title': {'@lang': 'en',
#                                  '@value': 'London, British Library, BL '
#                                            'Oriental 718'}},
#  'dts:extensions': {'crm:P1_is_identified_by': ['BL Oriental 718',
#                                                 'Wright cat. CCXCV',
#                                                 'Wright cat. 295'],
#                     'dc:hasPart': 'https://betamasaheft.eu/LIT1470GadlaL'},
#  'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/BLorient718',
#  'dts:references': '/api/dts/navigation?id=https://betamasaheft.eu/BLorient718',
#  'title': 'London, British Library, BL Oriental 718',
#  'totalItems': 0}

# %% [markdown]
# So, there is few things we can see:
#
# - The `dts:dublincore` is quite well filled :
#     - There is multiple language in the text
#     - The creator of the edition are Alessandro Bausia and Nafisa Valieva
#     - Contributor are named.
# - The data provider has given a direct link for download, in case this seems more interesting for the user, through `dts:download`
# - You see the `dts:citeDepth` ? The texts has up to 3 levels !
#     1. The first level has the name `folio`. This level has a second level:
#         1. The second of the level inside folio has the name `page`
#             1. The third of the level inside page has the name `column`
#
# Now, we have two really interesting links, let's go see what's in there !

# %% [markdown]
# ## What folio do you have ?
#
# To reply to this long but quite clear title, there is only one thing to do : go to the `dts:references` URI we see here.
#
# But wait, see the URI ? It's actually a simple construction :
#
# - We use `navigation` from `ENDPOINTS`.
# - We add the `@id` of the Resource we are interested in !
#
# ### All the *folio*s !

# %%
Folios = requests.get(
    urljoin(URI, BLorient718["dts:references"]),
    headers=h
).json()

# %%
pprint(Folios)
# Out:
# {'@base': '/api/dts/navigation',
#  '@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#               'dc': 'http://purl.org/dc/terms/',
#               'dts': 'https://w3id.org/dts/api#'},
#  '@id': '/api/dts/navigation?id=https://betamasaheft.eu/BLorient718',
#  'dc:hasVersion': 'version set to , no version links retrieved from GitHub.',
#  'dts:citeDepth': 4,
#  'dts:citeType': 'textpart',
#  'dts:level': 1,
#  'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/BLorient718',
#  'member': [{'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p1',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p2',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '1'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p2',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p3',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '2'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p3',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p4',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '3'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p4',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p5',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '4'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p5',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p6',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '5'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p6',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p7',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '6'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p7',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p8',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '7'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p8',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p9',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '8'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p9',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p10',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '9'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p10',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p11',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '10'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p11',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p12',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '11'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p12',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p13',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '12'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p13',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p14',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '13'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p14',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p15',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '14'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p15',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p16',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '15'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p16',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p17',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '16'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p17',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p18',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '17'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p18',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p19',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '18'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p19',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p20',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '19'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p20',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p21',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '20'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p21',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p22',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '21'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p22',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p23',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '22'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p23',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p24',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '23'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p24',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p25',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '24'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p25',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p26',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '25'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p26',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p27',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '26'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p27',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p28',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '27'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p28',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p29',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '28'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p29',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p30',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '29'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p30',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p31',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '30'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p31',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p32',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '31'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p32',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p33',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '32'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p33',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p34',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '33'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p34',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p35',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '34'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p35',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p36',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '35'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p36',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p37',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '36'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p37',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p38',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '37'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p38',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p39',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '38'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p39',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p40',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '39'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p40',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p41',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '40'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p41',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p42',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '41'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p42',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p43',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '42'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p43',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p44',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '43'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p44',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p45',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '44'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p45',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p46',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '45'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p46',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p47',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '46'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p47',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p48',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '47'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p48',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p49',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '48'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p49',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p50',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '49'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p50',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p51',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '50'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p51',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p52',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '51'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p52',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p53',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '52'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p53',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p54',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '53'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p54',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p55',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '54'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p55',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p56',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '55'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p56',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p57',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '56'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p57',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p58',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '57'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p58',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p59',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '58'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p59',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p60',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '59'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p60',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p61',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '60'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p61',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p62',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '61'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p62',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p63',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '62'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p63',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p64',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '63'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p64',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p65',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '64'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p65',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p66',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '65'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p66',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p67',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '66'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p67',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p68',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '67'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p68',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p69',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '68'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p69',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p70',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '69'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p70',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p71',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '70'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p71',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p72',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '71'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p72',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p73',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '72'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p73',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p74',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '73'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p74',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p75',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '74'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p75',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p76',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '75'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p76',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p77',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '76'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p77',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p78',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '77'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p78',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p79',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '78'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p79',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p80',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '79'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p80',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p81',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '80'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p81',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p82',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '81'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p82',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p83',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '82'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p83',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p84',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '83'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p84',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p85',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '84'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p85',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p86',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '85'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p86',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p87',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '86'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p87',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p88',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '87'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p88',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p89',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '88'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p89',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p90',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '89'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p90',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p91',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '90'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p91',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p92',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '91'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p92',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p93',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '92'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p93',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p94',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '93'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p94',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p95',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '94'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p95',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p96',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '95'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p96',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p97',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '96'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p97',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p98',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '97'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p98',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p99',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '98'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p99',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p100',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '99'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p100',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p101',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '100'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p101',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p102',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '101'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p102',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p103',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '102'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p103',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p104',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '103'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p104',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p105',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '104'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p105',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p106',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '105'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p106',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p107',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '106'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p107',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p108',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '107'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p108',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p109',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '108'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p109',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p110',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '109'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p110',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p111',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '110'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p111',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p112',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '111'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p112',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p113',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '112'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p113',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p114',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '113'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p114',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p115',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '114'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p115',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p116',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '115'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p116',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p117',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '116'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p117',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p118',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '117'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p118',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p119',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '118'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p119',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p120',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '119'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p120',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p121',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '120'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p121',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p122',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '121'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p122',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p123',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '122'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p123',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p124',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '123'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p124',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p125',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '124'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p125',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p126',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '125'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p126',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p127',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '126'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p127',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p128',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '127'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p128',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p129',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '128'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p129',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p130',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '129'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p130',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p131',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '130'}]}

# %%
# let's print only the first 20 results
for m in Columns['member'][:20]:
    print(m['dts:citeType'], m['dts:ref'])
# Out:
# folio 1
# unit 1.tei:ab[1]
# folio 2
# unit 2.tei:ab[1]
# folio 3
# unit 3.tei:ab[1]
# folio 4
# unit 4.tei:ab[1]
# folio 5
# unit 5.tei:ab[1]
# folio 6
# unit 6.tei:ab[1]
# folio 7
# unit 7.tei:ab[1]
# folio 8
# unit 8.tei:ab[1]
# folio 9
# unit 9.tei:ab[1]
# folio 10
# unit 10.tei:ab[1]

# %% [markdown]
# ### Give me all the columns !

# %%
Columns = requests.get(
    urljoin(URI, BLorient718["dts:references"] + "&level=1"),
    headers=h
).json()

# %%
pprint(Columns)
# Out:
# {'@base': '/api/dts/navigation',
#  '@context': {'@vocab': 'https://www.w3.org/ns/hydra/core#',
#               'dc': 'http://purl.org/dc/terms/',
#               'dts': 'https://w3id.org/dts/api#'},
#  '@id': '/api/dts/navigation?id=https://betamasaheft.eu/BLorient718',
#  'dc:hasVersion': 'version set to , no version links retrieved from GitHub.',
#  'dts:citeDepth': 4,
#  'dts:citeType': 'textpart',
#  'dts:level': 1,
#  'dts:passage': '/api/dts/document?id=https://betamasaheft.eu/BLorient718',
#  'member': [{'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p1',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p2',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '1'},
#             {'dts:citeType': 'unit', 'dts:ref': '1.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p2',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p3',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '2'},
#             {'dts:citeType': 'unit', 'dts:ref': '2.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p3',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p4',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '3'},
#             {'dts:citeType': 'unit', 'dts:ref': '3.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p4',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p5',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '4'},
#             {'dts:citeType': 'unit', 'dts:ref': '4.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p5',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p6',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '5'},
#             {'dts:citeType': 'unit', 'dts:ref': '5.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p6',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p7',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '6'},
#             {'dts:citeType': 'unit', 'dts:ref': '6.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p7',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p8',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '7'},
#             {'dts:citeType': 'unit', 'dts:ref': '7.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p8',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p9',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '8'},
#             {'dts:citeType': 'unit', 'dts:ref': '8.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p9',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p10',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '9'},
#             {'dts:citeType': 'unit', 'dts:ref': '9.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p10',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p11',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '10'},
#             {'dts:citeType': 'unit', 'dts:ref': '10.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p11',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p12',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '11'},
#             {'dts:citeType': 'unit', 'dts:ref': '11.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p12',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p13',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '12'},
#             {'dts:citeType': 'unit', 'dts:ref': '12.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p13',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p14',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '13'},
#             {'dts:citeType': 'unit', 'dts:ref': '13.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p14',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p15',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '14'},
#             {'dts:citeType': 'unit', 'dts:ref': '14.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p15',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p16',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '15'},
#             {'dts:citeType': 'unit', 'dts:ref': '15.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p16',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p17',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '16'},
#             {'dts:citeType': 'unit', 'dts:ref': '16.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p17',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p18',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '17'},
#             {'dts:citeType': 'unit', 'dts:ref': '17.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p18',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p19',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '18'},
#             {'dts:citeType': 'unit', 'dts:ref': '18.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p19',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p20',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '19'},
#             {'dts:citeType': 'unit', 'dts:ref': '19.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p20',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p21',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '20'},
#             {'dts:citeType': 'unit', 'dts:ref': '20.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p21',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p22',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '21'},
#             {'dts:citeType': 'unit', 'dts:ref': '21.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p22',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p23',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '22'},
#             {'dts:citeType': 'unit', 'dts:ref': '22.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p23',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p24',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '23'},
#             {'dts:citeType': 'unit', 'dts:ref': '23.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p24',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p25',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '24'},
#             {'dts:citeType': 'unit', 'dts:ref': '24.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p25',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p26',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '25'},
#             {'dts:citeType': 'unit', 'dts:ref': '25.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p26',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p27',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '26'},
#             {'dts:citeType': 'unit', 'dts:ref': '26.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p27',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p28',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '27'},
#             {'dts:citeType': 'unit', 'dts:ref': '27.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p28',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p29',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '28'},
#             {'dts:citeType': 'unit', 'dts:ref': '28.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p29',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p30',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '29'},
#             {'dts:citeType': 'unit', 'dts:ref': '29.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p30',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p31',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '30'},
#             {'dts:citeType': 'unit', 'dts:ref': '30.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p31',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p32',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '31'},
#             {'dts:citeType': 'unit', 'dts:ref': '31.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p32',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p33',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '32'},
#             {'dts:citeType': 'unit', 'dts:ref': '32.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p33',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p34',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '33'},
#             {'dts:citeType': 'unit', 'dts:ref': '33.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p34',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p35',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '34'},
#             {'dts:citeType': 'unit', 'dts:ref': '34.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p35',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p36',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '35'},
#             {'dts:citeType': 'unit', 'dts:ref': '35.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p36',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p37',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '36'},
#             {'dts:citeType': 'unit', 'dts:ref': '36.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p37',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p38',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '37'},
#             {'dts:citeType': 'unit', 'dts:ref': '37.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p38',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p39',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '38'},
#             {'dts:citeType': 'unit', 'dts:ref': '38.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p39',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p40',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '39'},
#             {'dts:citeType': 'unit', 'dts:ref': '39.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p40',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p41',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '40'},
#             {'dts:citeType': 'unit', 'dts:ref': '40.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p41',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p42',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '41'},
#             {'dts:citeType': 'unit', 'dts:ref': '41.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p42',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p43',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '42'},
#             {'dts:citeType': 'unit', 'dts:ref': '42.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p43',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p44',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '43'},
#             {'dts:citeType': 'unit', 'dts:ref': '43.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p44',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p45',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '44'},
#             {'dts:citeType': 'unit', 'dts:ref': '44.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p45',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p46',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '45'},
#             {'dts:citeType': 'unit', 'dts:ref': '45.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p46',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p47',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '46'},
#             {'dts:citeType': 'unit', 'dts:ref': '46.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p47',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p48',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '47'},
#             {'dts:citeType': 'unit', 'dts:ref': '47.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p48',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p49',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '48'},
#             {'dts:citeType': 'unit', 'dts:ref': '48.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p49',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p50',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '49'},
#             {'dts:citeType': 'unit', 'dts:ref': '49.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p50',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p51',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '50'},
#             {'dts:citeType': 'unit', 'dts:ref': '50.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p51',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p52',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '51'},
#             {'dts:citeType': 'unit', 'dts:ref': '51.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p52',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p53',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '52'},
#             {'dts:citeType': 'unit', 'dts:ref': '52.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p53',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p54',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '53'},
#             {'dts:citeType': 'unit', 'dts:ref': '53.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p54',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p55',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '54'},
#             {'dts:citeType': 'unit', 'dts:ref': '54.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p55',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p56',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '55'},
#             {'dts:citeType': 'unit', 'dts:ref': '55.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p56',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p57',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '56'},
#             {'dts:citeType': 'unit', 'dts:ref': '56.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p57',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p58',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '57'},
#             {'dts:citeType': 'unit', 'dts:ref': '57.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p58',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p59',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '58'},
#             {'dts:citeType': 'unit', 'dts:ref': '58.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p59',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p60',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '59'},
#             {'dts:citeType': 'unit', 'dts:ref': '59.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p60',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p61',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '60'},
#             {'dts:citeType': 'unit', 'dts:ref': '60.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p61',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p62',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '61'},
#             {'dts:citeType': 'unit', 'dts:ref': '61.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p62',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p63',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '62'},
#             {'dts:citeType': 'unit', 'dts:ref': '62.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p63',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p64',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '63'},
#             {'dts:citeType': 'unit', 'dts:ref': '63.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p64',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p65',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '64'},
#             {'dts:citeType': 'unit', 'dts:ref': '64.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p65',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p66',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '65'},
#             {'dts:citeType': 'unit', 'dts:ref': '65.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p66',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p67',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '66'},
#             {'dts:citeType': 'unit', 'dts:ref': '66.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p67',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p68',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '67'},
#             {'dts:citeType': 'unit', 'dts:ref': '67.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p68',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p69',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '68'},
#             {'dts:citeType': 'unit', 'dts:ref': '68.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p69',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p70',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '69'},
#             {'dts:citeType': 'unit', 'dts:ref': '69.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p70',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p71',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '70'},
#             {'dts:citeType': 'unit', 'dts:ref': '70.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p71',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p72',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '71'},
#             {'dts:citeType': 'unit', 'dts:ref': '71.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p72',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p73',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '72'},
#             {'dts:citeType': 'unit', 'dts:ref': '72.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p73',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p74',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '73'},
#             {'dts:citeType': 'unit', 'dts:ref': '73.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p74',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p75',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '74'},
#             {'dts:citeType': 'unit', 'dts:ref': '74.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p75',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p76',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '75'},
#             {'dts:citeType': 'unit', 'dts:ref': '75.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p76',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p77',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '76'},
#             {'dts:citeType': 'unit', 'dts:ref': '76.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p77',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p78',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '77'},
#             {'dts:citeType': 'unit', 'dts:ref': '77.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p78',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p79',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '78'},
#             {'dts:citeType': 'unit', 'dts:ref': '78.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p79',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p80',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '79'},
#             {'dts:citeType': 'unit', 'dts:ref': '79.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p80',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p81',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '80'},
#             {'dts:citeType': 'unit', 'dts:ref': '80.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p81',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p82',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '81'},
#             {'dts:citeType': 'unit', 'dts:ref': '81.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p82',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p83',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '82'},
#             {'dts:citeType': 'unit', 'dts:ref': '82.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p83',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p84',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '83'},
#             {'dts:citeType': 'unit', 'dts:ref': '83.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p84',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p85',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '84'},
#             {'dts:citeType': 'unit', 'dts:ref': '84.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p85',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p86',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '85'},
#             {'dts:citeType': 'unit', 'dts:ref': '85.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p86',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p87',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '86'},
#             {'dts:citeType': 'unit', 'dts:ref': '86.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p87',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p88',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '87'},
#             {'dts:citeType': 'unit', 'dts:ref': '87.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p88',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p89',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '88'},
#             {'dts:citeType': 'unit', 'dts:ref': '88.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p89',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p90',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '89'},
#             {'dts:citeType': 'unit', 'dts:ref': '89.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p90',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p91',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '90'},
#             {'dts:citeType': 'unit', 'dts:ref': '90.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p91',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p92',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '91'},
#             {'dts:citeType': 'unit', 'dts:ref': '91.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p92',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p93',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '92'},
#             {'dts:citeType': 'unit', 'dts:ref': '92.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p93',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p94',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '93'},
#             {'dts:citeType': 'unit', 'dts:ref': '93.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p94',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p95',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '94'},
#             {'dts:citeType': 'unit', 'dts:ref': '94.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p95',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p96',
# ...
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '99'},
#             {'dts:citeType': 'unit', 'dts:ref': '99.tei:ab[1]'},
#             {'dts:citeType': 'unit', 'dts:ref': '99.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p100',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p101',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '100'},
#             {'dts:citeType': 'unit', 'dts:ref': '100.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p101',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p102',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '101'},
#             {'dts:citeType': 'unit', 'dts:ref': '101.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p102',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p103',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '102'},
#             {'dts:citeType': 'unit', 'dts:ref': '102.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p103',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p104',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '103'},
#             {'dts:citeType': 'unit', 'dts:ref': '103.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p104',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p105',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '104'},
#             {'dts:citeType': 'unit', 'dts:ref': '104.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p105',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p106',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '105'},
#             {'dts:citeType': 'unit', 'dts:ref': '105.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p106',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p107',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '106'},
#             {'dts:citeType': 'unit', 'dts:ref': '106.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p107',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p108',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '107'},
#             {'dts:citeType': 'unit', 'dts:ref': '107.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p108',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p109',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '108'},
#             {'dts:citeType': 'unit', 'dts:ref': '108.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p109',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p110',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '109'},
#             {'dts:citeType': 'unit', 'dts:ref': '109.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p110',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p111',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '110'},
#             {'dts:citeType': 'unit', 'dts:ref': '110.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p111',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p112',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '111'},
#             {'dts:citeType': 'unit', 'dts:ref': '111.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p112',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p113',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '112'},
#             {'dts:citeType': 'unit', 'dts:ref': '112.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p113',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p114',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '113'},
#             {'dts:citeType': 'unit', 'dts:ref': '113.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p114',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p115',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '114'},
#             {'dts:citeType': 'unit', 'dts:ref': '114.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p115',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p116',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '115'},
#             {'dts:citeType': 'unit', 'dts:ref': '115.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p116',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p117',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '116'},
#             {'dts:citeType': 'unit', 'dts:ref': '116.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p117',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p118',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '117'},
#             {'dts:citeType': 'unit', 'dts:ref': '117.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p118',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p119',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '118'},
#             {'dts:citeType': 'unit', 'dts:ref': '118.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p119',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p120',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '119'},
#             {'dts:citeType': 'unit', 'dts:ref': '119.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p120',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p121',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '120'},
#             {'dts:citeType': 'unit', 'dts:ref': '120.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p121',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p122',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '121'},
#             {'dts:citeType': 'unit', 'dts:ref': '121.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p122',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p123',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '122'},
#             {'dts:citeType': 'unit', 'dts:ref': '122.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p123',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p124',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '123'},
#             {'dts:citeType': 'unit', 'dts:ref': '123.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p124',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p125',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '124'},
#             {'dts:citeType': 'unit', 'dts:ref': '124.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p125',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p126',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '125'},
#             {'dts:citeType': 'unit', 'dts:ref': '125.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p126',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p127',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '126'},
#             {'dts:citeType': 'unit', 'dts:ref': '126.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p127',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p128',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '127'},
#             {'dts:citeType': 'unit', 'dts:ref': '127.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p128',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p129',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '128'},
#             {'dts:citeType': 'unit', 'dts:ref': '128.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p129',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p130',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '129'},
#             {'dts:citeType': 'unit', 'dts:ref': '129.tei:ab[1]'},
#             {'dts:citeType': 'folio',
#              'dts:dublincore': {'dc:source': [{'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p130',
#                                                '@type': 'sc:Canvas'},
#                                               {'@id': 'https://betamasaheft.eu/api/iiif/BLorient718/canvas/p131',
#                                                '@type': 'sc:Canvas'}]},
#              'dts:ref': '130'},
#             {'dts:citeType': 'unit', 'dts:ref': '130.tei:ab[1]'}]}

# %%
# let's print only the first 20 results
for m in Columns['member'][:20]:
    print(m['dts:citeType'], m['dts:ref'])
# Out:
# folio 1
# unit 1.tei:ab[1]
# folio 2
# unit 2.tei:ab[1]
# folio 3
# unit 3.tei:ab[1]
# folio 4
# unit 4.tei:ab[1]
# folio 5
# unit 5.tei:ab[1]
# folio 6
# unit 6.tei:ab[1]
# folio 7
# unit 7.tei:ab[1]
# folio 8
# unit 8.tei:ab[1]
# folio 9
# unit 9.tei:ab[1]
# folio 10
# unit 10.tei:ab[1]

# %% [markdown]
# ## Getting the text
#
# Now that we can see what are the available passage, why not getting to the text passages ?
#
# Let see... We build this the same way than the Navigation query ! But instead, we use `document` from the entry point !
#
# ### Getting an excerpt

# %%
request_uri = urljoin(URI, BLorient718["dts:passage"]+"&ref=1")

# %%
BLorient718_F_1 = requests.get(request_uri,headers=h)

# %%
# why this time  we don't receive back a JSON answer?
# because we are querying the `document` endpoint, whose
# serialization format is TEI/XML!
BLorient718_F_1.headers['Content-Type']
# Out:
# 'application/tei+xml; charset=utf-8'

# %%
print(request_uri)
# Out:
# https://betamasaheft.eu/api/dts/document?id=https://betamasaheft.eu/BLorient718&ref=1

# %%
print(BLorient718_F_1.text)
# Out:
# <TEI xmlns="http://www.tei-c.org/ns/1.0">
#     <dts:fragment xmlns:dts="https://w3id.org/dts/api#">
#         <div type="textpart" subtype="folio" n="1" xml:id="f1">
#                <ab>
#                   <pb n="1r"/>
#                   <cb n="a"/>
#                   <hi rend="rubric">በስመ፡ አብ፡ ወወልድ፡ ወመንፈስ፡ ቅዱስ፡ ፩ </hi> አምላክ፡ ሥሉስ፡ ዘኢይሰደቅ፡ ዋሕድ፨ ዕሩ<hi rend="rubric">ይ፡ ታሉት፡ ዘኢይነፍድ፤ ዘሀሎ፡ እምቅድመ፡ ክ</hi> ዋኒሁ፡ እንዘ፡ ኢይትበዓድ፨ ወእምህላዊሁ፡ እንዘ፡
#             ኢየሐፅፅ፡ ወኢይፈደፍድ፨ በአናስረ፡ ዓ <hi rend="rubric">ለም፡ ዘኢይተረጐም፡ ወኢይትዔለድ፨ ወዘ</hi> ኢይትፈለጥ፡ ወልድ፡
#             እምአቡሁ፡ ወመንፈስ፡ እምወልድ፨ ዘአምጽአ፡ ዓለመ፡ በቃለ፡ ጽ <hi rend="rubric">ውዓ፡ እምኀበ፡ ኢሀሎ፡ በአሐቲ፡ ምክር፡
#               ወበአ</hi> ሐቲ፡ ፈቃድ፨ ዘሣረራ፡ ለምድር፡ በልቡና፡ <cb n="b"/> ዘኢ <hi rend="rubric">ይኄለድ፨ ወሰማይኒ፡
#               ዘአንበራ፡ በዓየር፡ እሳት፡ </hi> ዘይነድድ፨ ወለእሳትኒ፡ ዘሰፍሖ፡ በዓየር፡ ሰማይ፡ <hi rend="rubric">እንበለ፡ ገሢሥ፡
#               በእድ፤ ወለነፋስ፡ ዘረበቦ፡ ዲበ፡ </hi> ሰረገላ፡ ጽልመት፡ እንበለ፡ መሠረት፡ ወድድ፤ አርጊዖ፡ ማየ፡ ዘረሰየ፡ ሰማየ፡ ወሰቀሎ፡
#             ከመ፡ ቀመር፡ <hi rend="rubric">ወዓምድ፨ ዘረሰዮሙ፡ ለመላእክቲሁ፡ </hi> መንፈሰ፡ ወለእለ፡ ይትለአክዎ፡ አይቁና፡ ዘነድ፨
#             ዘይመይጦ፡ ለንጥረ፡ መብረቅ፡ ወያጸንዖ፡ <hi rend="rubric">ለነጐድጓድ፨ ዘይፌትቶ፡ ለዕብነ፡ በረድ፨ እ</hi> ምከርሠ፡ ደመና፡
#             በበሕጠታቲሁ፡ ከመ፡ ይረድ፨ <pb n="1v"/>
#                   <cb n="a"/> ዘይጌሥፆ፡ ለፀዓዕ፡ ወይዘርዎ፡ ለጊሜ፡ ከመ፡ ሐመድ፨ ጌልጌላሁ፡ ዘነበልባል፡ ወሰረገላሁ፡ መርዕድ፨ ዘያረምማ፡ ለማዕበለ፡
#             ባሕር፡ ወያዝኅና፡ ለሞገደ፨ ዘኢየኃልቅ፡ ምስፍናሁ፡ ለትውልደ፡ ትውልድ፨ ወኢይትዌዳእ፡ ምኵናኑ፡ ለዘመደ፡ ዘመድ፨ ጥንተ፡ መዋዕሊሁ፡
#             ዘኢይትኌለቍ፡ ወስፍሐ፡ ሀልዎቱ፡ ዘኢይትኄለድ፨ ዘለሐኮ፡ ለአዳም፡ በአርአያሁ፡ ከመ፡ ይትገሃድ፨ ለዘከመዝ፡ እግዚእ፡ እንዘ፡ እገኒ፡
#             ወእሰግድ፨ እነግር፡ ዜና፡ ገድለ፡ ፃማሁ፡ ብፁዕ፡ ወለቅዱስ፡ ብእሲ፡ ክቡር፡ ወርኡስ፡ ስቡሕ፡ <cb n="b"/> ወውዱስ፨ ለባሴ፡ ንጹሕ፡
#             ዘኢለከፎ፡ ደነስ፨ ፀዋሬ፡ ንዴት፡ ዘምስለ፡ ንግሥ፤ ዘኢያንሶሰወ፡ በፍኖት፡ መብዕስ፨ ዘኢተሀይጰ፡ በአሕፃሁ፡ መስተቃርን፡ ዘውእቱ፡
#             ዲያብሎስ፡ ደብረ፡ ወርቅ፡ ወደብረ፡ ብሩር፡ ደብረ፡ ባሕርይ፡ ወደብረ፡ ሰንፒር፡ ወግረ፡ ቀንዓት፡ ወወግረ፡ ስኂን፡ መንክር፨ ደብረ፡ ወርቅ፡
#             ንብሎ፡ በእንተ፡ ስነ፡ ሃይማኖቱ፡ ርትዕት፨ ወበእንተ፡ ስነ፡ ትዕግሥቱ፡ በውስተ፡ ገድል፡ እንዘ፡ ይጽሕቅ፡ ለፈጽሞ፡ ቃለ፡ ወንጌል፡ እስመ፡
#             ይሰምዖ፡ ለቀርነ፡ መድኃኒትነ፡ ዘውእቱ፡ ብስራተ፡ እስራኤል፡ ሐዲሳን፡ ዘደምፀ፡ </ab>
#             </div>
#     </dts:fragment>
# </TEI>

# %% [markdown]
# ### Getting the whole text
#
# That's nice ! But the text seems fairly small, so why not requesting the whole text ?

# %%
request_uri = urljoin(URI, BLorient718["dts:passage"])

# %%
DSEthiop1_full_text = requests.get(request_uri, headers=h)

# %%
print(request_uri)
# Out:
# https://betamasaheft.eu/api/dts/document?id=https://betamasaheft.eu/BLorient718

# %%
print(DSEthiop1_full_text.text)
# Out:
# <TEI xmlns="http://www.tei-c.org/ns/1.0" xml:id="BLorient718" xml:lang="en" type="mss">
#   <teiHeader xml:base="https://betamasaheft.eu/">
#       <fileDesc>
#          <titleStmt>
#             <title xml:lang="en" xml:id="t1"> 'The 'Gadla Lālibalā'  collection of
#           textual units'</title>
#
#             <editor role="generalEditor" key="AB"/>
#             <editor key="NV"/>
#             <funder>Akademie der Wissenschaften in Hamburg</funder>
#          </titleStmt>
#          <editionStmt>
#             <p> </p>
#          </editionStmt>
#          <publicationStmt>
#             <authority>Hiob-Ludolf-Zentrum für Äthiopistik</authority>
#             <publisher>Die Schriftkultur des christlichen Äthiopiens und Eritreas: Eine multimediale
#           Forschungsumgebung / Beta maṣāḥǝft</publisher>
#             <pubPlace>Hamburg</pubPlace>
#             <availability>
#                <licence target="http://creativecommons.org/licenses/by-sa/4.0/"> This file is licensed
#             under the Creative Commons Attribution-ShareAlike 4.0. </licence>
#             </availability>
#          </publicationStmt>
#          <sourceDesc>
#             <msDesc xml:id="ms">
#                <msIdentifier>
#                   <repository ref="INS00001BL"/>
#                   <collection>Oriental</collection>
#                   <idno>BL Oriental 718</idno>
#                   <altIdentifier>
#                      <idno>Wright cat. CCXCV</idno>
#                   </altIdentifier>
#                   <altIdentifier>
#                      <idno>Wright cat. 295</idno>
#                   </altIdentifier>
#                </msIdentifier>
#                <msContents>
#
#                   <msItem xml:id="ms_i1">
#                      <locus from="1r" to="130vb"/>
#                      <title type="complete" ref="LIT1470GadlaL"/>
#                      <textLang mainLang="gez" otherLangs="am"/>
#
#                      <msItem xml:id="ms_i1.1">
#                         <locus from="1ra" to="5vb"/>
#                         <title type="complete" ref="LIT5080TUoneLal"/>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#1ra"/>በስመ፡ አብ፡ ወወልድ፡ ወመንፈስ፡ ቅዱስ፡ ፩ አምላክ፡ ሥሉስ፡ ዘኢይሰደቅ፡ ዋሕድ፨ ዕሩይ፡
#                   ታሉት፡ ዘኢይነፍድ፤ ዘሀሎ፡ እምቅድመ፡ ክዋኒሁ፡ እንዘ፡ ኢይትበዓድ፨ ወእምህላዊሁ፡ እንዘ፡ ኢየሐፅፅ፡ወኢይፈደፍድ፨ በአናስረ፡
#                   ዓለም፡ ዘኢይተረጐም፡ ወኢይትዔለድ፨ ወዘኢይትፈለጥ፡ ወልድ፡ እምአቡሁ፡ ወመንፈስ፡ እምወልድ፨ </incipit>
#
#                         <explicit xml:lang="gez" type="supplication">
#                            <locus from="5va" to="5vb"/>ሰአሉ፡ ሊተ፡ ከመ፡ የሀበኒ፡ ልሳነ፡ ጥበብ፡ ከመ፡ አእምር፡ ዘእንብብ፨ እስመ፡ አነ፡ ሕፁፀ፡
#                   ልብ፡ እስከ፡ ይእዜ፡ ኢገሠሥኩ፡ ማእዘንተ፡ ነገረ፡ ዚአሁ፡ ለዘእትናገር፡ በእንቲአሁ፡ እስመ፡ ነዋህ፡ ነገሩ፡ ወልጐት፡ ክሥተተ፡
#                   ምሥጢሩ፨ ወባሕቱ፡ እነግረክሙ፡ በሐሳበ፡ ክህልኩ፡ እንዘ፡ እትአመን፡ በኃይለ፡ ጸሎትክሙ፨ ወበጸሎቱ፡ ለዝንቱ፡ ብእሲ፡ ኮከበ፡
#                   ክብር፡ ጽባሐዊ፡ ዘየኃይድ፡ ብርሃኑ፡ እምብርሃነ፡ ካልአን፡ ከዋክብት፨ እንዘ፡ አብ፡ ይረድእ፡ ለወጢን፡ በለብዎ፡ ወእንዘ፡ ወልድ፡
#                   ያጸንዕ፡ በአስተሰናእዎ፨ ወመንፈስ፡ ቅዱስ፡ እንዘ፡ ይከውን፡ ፈጸሜ፡ ኃይለ፡ ቃል፡ በአስተታልዎ፨ በሰላመ፡ ዚአሁ፡ አሜን፨ ጸሎቱ፡
#                   ወበረከቱ፡ ብፁዕ፡ የሃሉ፡ ምስለ፡ ፍቅርቱ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወልዳ፡ መስፍን፡ ኃይለ፡ ኢየሱስ፡ ለዓለመ፡
#                   ዓለም፡ አሜን፨ </explicit>
#
#                         <explicit xml:lang="gez" type="supplication">
#                            <locus target="#5vb"/>ጸሎቱ፡ ወበረከቱ፡ ወሀብተ፡ ረድኤቱ፡ ለዝንቱ፡ ብፁዕ፡ የሃሉ፡ ምስለ፡ ፍቅርቱ፡ ንግሥትነ፡
#                   ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወልዳ፡ መስፍን፡ ኃይለ፡ ኢየሱስ፡ ለዓለመ፡ ዓለም፡ አሜን፨ </explicit>
#
#                         <note> Text contained on f.1r, line 1 up to f.5vb, line 21 is to be found in
#                   Perruchon's edition on page 1, line 1 up to page 7, line 18 (‘Introduction’.). In
#                   this description by counting lines I disregard any extra notes or punctuation in
#                   the manuscript and titles in Perruchon's edition. The beginning is marked as
#                   monthly reading for the 12th of Sane. The first folio recto is layouted with red
#                   inks. It ends with supplication on f.5vb and marked with a cross. </note>
#                      </msItem>
#
#                      <msItem xml:id="ms_i1.2">
#                         <locus from="6ra" to="9vb"/>
#                         <title type="complete" ref="LIT5081SoterLal"/>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#6ra"/>አቀድም፡ አእኵቶቶ፡ ለእግዚአብሔር፡ በእንተ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ዝውእቱ፡ ወልዱ፡
#                   ወቃሉ፡ ለአብ፡ ዘበሕፅነ፡ አቡሁ፡ ሠረፀ፡ ፍሬ፡ ስብሐት፡ ዓቃቤ፡ ሥራይ፡ ዘወረደ፡ እምሰማያት፡ ከመ፡ ይደይ፡ ርጢኖ፡ ዲበ፡ እለ፡
#                   ቈስሉ፡ በንስከተ፡ አርዌ፡ አስዋር፡ ወአልህምተ፨ ኦተቡዕ፡ ወአዕኑስ፡ ፈኒዎ፡ መንፈሰ፡ ኀበ፡ ነቢያቲሁ፡ ዘያጌብሮሙ፡ ከመ፡
#                   ይበልዎ፡ እግዚኦ፡ አጽንን፡ ሰማያቲከ፡ ወረድ፨ አንሥእ፡ ኃይለከ፡ ወነዓ፡ አድኅነነ፨ </incipit>
#
#                         <explicit xml:lang="gez">
#                            <locus from="9va" to="9vb"/> ብፁዕኬ፡ ዘበልዓ፡ እምፍሬሁ፡ ለዝንቱ፡ ብእሲ፡ ጻድቅ፡ ቀሲሞ፡እምአስካለ፡ ፃማሁ፡
#                   በተመስሎተ፡ ምግባራቲሁ፡ እስመ፡ ዘይትሜሰሎ፡ በምግባር፡ ይሄሉ፡ ኀበ፡ ሀሎ፡ ውእቱ፡ ወኀበ፡ ቦአ፡ ይበውአ፡ ወኀበ፡ አሥመከ፡
#                   ያሠምክ፡ ወኀበ፡ ተጽሕፈ፡ ስሙ፡ ይጸሐፍ፡ ስመ፡ ተመሳሊሁ፨ ወዘተሠርገወ፡ ስነ፡ ይሠርገው፡ ተላዌ፡ ፍኖቱ፨ ወዘተቀጸለ፡ አክሊለ፡
#                   ምዝጋና፨ ይትሜሰል፡ ዘይትሜሰሎ፡ በገድል፨ ናሁ፡ ውእቱሰ፡ ነሥአ፡ አክሊለ፡ ምዝጋናሁ፡ ዘኢየኃልፍ፡ ወዘኢይጸመሂ፡ ዘተገብረ፡
#                   በሐሳበ፡ ሕሊናሁ፡ ለዓሣዪ፡ ሕይወት፡ ዘኢተገብረ፡ በሐሳበ፡ ህክሚሆሙ፡ ለጠቢባን፡ መዓሥቃን፡ እለ፡ ያሤንዩ፡ አኒመ፡ በሜላት፨
#                   ወበኅብረ፡ ለይ፡ ወበኅብረ፡ደርከኖ፡ ወበአዝመር፨ </explicit>
#
#                         <note> Soterology has a different articulation in the present manuscript: having the
#                   same incipit on f. 6ra, it will end with a following explicit and incipit of a
#                   portion, which goes further into SaintsLal end ends with the same explicit as
#                   JerusLal.</note>
#
#                         <msItem xml:id="ms_i1.2.1">
#                            <locus from="6ra" to="8va"/>
#                            <incipit xml:lang="gez">
#                               <locus target="#6ra"/>አቀድም፡ አእኵቶቶ፡ ለእግዚአብሔር፡ በእንተ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ዝውእቱ፡ ወልዱ፡
#                     ወቃሉ፡ ለአብ፡ ዘበሕፅነ፡ አቡሁ፡ ሠረፀ፡ ፍሬ፡ ስብሐት፡ ዓቃቤ፡ ሥራይ፡ ዘወረደ፡ እምሰማያት፡ ከመ፡ ይደይ፡ ርጢኖ፡ ዲበ፡ እለ፡
#                     ቈስሉ፡ በንስከተ፡ አርዌ፡ አስዋር፡ ወአልህምተ፨ ኦተቡዕ፡ ወአዕኑስ፡ ፈኒዎ፡ መንፈሰ፡ ኀበ፡ ነቢያቲሁ፡ ዘያጌብሮሙ፡ ከመ፡
#                     ይበልዎ፡ እግዚኦ፡ አጽንን፡ ሰማያቲከ፡ ወረድ፨ አንሥእ፡ ኃይለከ፡ ወነዓ፡ አድኅነነ፨ </incipit>
#                            <explicit xml:lang="gez">
#                               <locus target="#8va"/>ፍሬ፡ ተመርትኒ፡ ካልእ፡ አርአያሁ፡ ወአምሳሊሁ፡ ወጣዕመ፡ መዓዛሁ፡ ወፍሬ፡ መልጰጶንሂ፡ ካልእ፡
#                   አርአያሁ፡ ወአምሳሊሁ፨ ወፍሬ፡ ዕንጐታትሂ፡ ካልዕ፡ አርአያሁ፡ ወአምሳሊሁሙ፨ </explicit>
#
#                            <note>Text contained on f.6ra, line 1 up to f.8va, line 15 is to be found in
#                   Perruchon's edition on page 7, line 19 up to page 10, line 25 (‘Seconde
#                   Introduction’.). It starts on the new page and new line, lines 1,2,5,6 are written
#                   with red inks. The end is marked with three ፨ and dotted line. </note>
#                         </msItem>
#                         <msItem xml:id="ms_i1.2.2">
#                            <locus from="8va" to="17va"/>
#                            <incipit xml:lang="gez">
#                               <locus from="8va" to="8vb"/>ወከማሁኬ፡ ዝንቱኒ፡ ብእሴ፡ አምላክ፡ ላሊበላ፡ እንዘ፡ ንጉሥ፡ ውእቱ፡ ዘተመሰለ፡ ወዓሌ፨
#                   እንዘ፡ እግዚአ፡ ነባርያን፡ ዘተመሰለ፡ ነባሬ፨ እንዘ፡ እግዚአ፡ መኳንንት፡ ተመሰለ፡ ተኰናኔ፨ </incipit>
#                         </msItem>
#                      </msItem>
#
#                      <msItem xml:id="ms_i1.3">
#                         <locus from="9vb" to="12rb"/>
#                         <title type="complete" ref="LIT5082TUthreeLal"/>
#
#                         <incipit xml:lang="gez">
#                            <locus from="9vb" to="10ra"/>ወዓዲ፡ ነሥአ፡ ክብረ፡ እምኀበ፡ እግዚአብሔር፡ ዘየዓቢ፡ እምክብረ፡ ካልአኒሁ፨ እስመ፡
#                   ብዙኅ፡ ፆታ፡ ክብሮሙ፡ ለቅዱሳን፡ በከመ፡ አርአየ፡ ጳውሎስ፡ ወነገረ፡ በምሳሌ፡ እንዘ፡ ይብል፡ ካልእ፡ ክብሩ፡ ለፀሐይ፡ ወካልእ፡
#                   ክብሩ፡ ለወርኅ፡ ወካልእ፡ ክብሮሙ፡ ለከዋክብት፨ ወኮከብ፡ እምኮከብ፡ ይኄይስ፡ ክብሩ፨</incipit>
#
#                         <explicit xml:lang="gez">
#                            <locus target="#12rb"/> ወያወሥኦሙ፡ ዝኩ፡ ሰይፈ፡ ቃል፡ ማኅየዊት፡፡ ወይብሎሙ፡ አማን፡ አማን፡ እብለክሙ፡ ኵሎ፡
#                   ዘገበርክሙ፡ ለ፩ እምእሉ፡ ንዑሳን፡ አኃውየ፡ እለ፡ የአምኑ፡ ብየ፡ ሊተ፡ ገበርክሙ፨ ወየሐውሩ፡ እሉሂ፡ ተስሒቦሙ፡ በስሱ፡
#                   እሕባለ፡ ቃለ፡ ወንጌል፡ ውስተ፡ መንግሥተ፡ ሰማያት፨ ወይበውኡ፡ ኀበ፡ ሀለወ፡ እግዚአብሔር፡ ምስለ፡ በግዑ፡ ወምስለ፡ መንፈሱ፨ </explicit>
#
#                         <note>SaintsLal is not articulated in the present manuscript. </note>
#                      </msItem>
#
#                      <msItem xml:id="ms_i1.4">
#                         <locus from="12rb" to="17va"/>
#                         <title type="complete" ref="LIT5083TUfourLal"/>
#
#                         <incipit xml:lang="gez">
#                            <locus from="12rb" to="12va"/>ወዝንቱ፡ ገብረ፡ መስቀል፡ ፩፡ ውእቱ፡ እምኔሆሙ፡ እምእለ፡ ቦኡ፡ ውስተ፡ ኢየሩሳሌም፡
#                   ሰማያዊት፡ አግዓዚት፡ ብርሃን፡ ዘኢየኃልፍ፡ እንተ፡ ኢይበውአ፡ ውስቴታ፡ ቈላፍ፡ ዘኢተገዝረ፡ ቍልፈተ፡ ልቡ፡ በመጥባሕተ፡
#                   ሃይማኖት፡ ዘንቱሰ፡ ብፁዕ፡ ወቅዱስ፡ ዘተገዝረ፡ ቍልፈተ፡ ነፍስቱ፡ በመጥባሕት፡ ሥጋዊት፨ </incipit>
#
#                         <explicit xml:lang="gez">
#                            <locus from="17ra" to="17vb"/>ያድኅነነኬ፡ እመሥገቱ፡ ለዝንቱ፡ ጽጉበ፡ ደም፡ አርዌ፡ ዘየኃሥሥ፡ እስከ፡ ይእዜ፡ ነፍሳተ፡
#                   ከመ፡ የኃጥ፡ እንዘ፡ ይጥሕር፡ ከመ፡ አንበሳ፡ ወኢያርመመ፡ እምአዳም፡ እስከ፡ ዮም፨ ፋሕለ፡ ጥሕረቱ፡ እንዘ፡ ይፈቅድ፡ ከመ፡
#                   ይድቢ፡ አለ፡ ተሰምዩ፡ ናዝራዊያነ፨ እስመ፡ ሰምዓነ፡ እንዘ፡ ናውግዞ፡ መይጠነ፡ ገጸነ፡ መንገለ፡ ምሥራቅ፡ በዕለተ፡ ለበስናሁ፡
#                   ለመርዓዊ፡ ሰማያዊ፡ ብእሲ፡ ሐዲስ፡ ዘውእቱ፡ ክርስቶስ። ወኃደግናሁ፡ ለብሉይ፡ ብእሲ፡ ዘውእቱ፡ ዲያብሎስ፡ እንዘ፡ ንብሎ፡ ርጉም፡
#                   አንተ፡ ወርጉም፡ ሕሊናከ፡ ወርጉም፡ ግብርከአ ወበእንተዝኬ፡ ይትመዓዕ፡ ላዕሌነ፨</explicit>
#
#
#                         <msItem xml:id="ms_i1.4.1">
#                            <locus from="8va" to="17va"/>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus from="17rb" to="17va"/>ወለነኒ፡ የሀበነ፡ እግዚእነ፡ ኢየሱስ፡ ክርስቶስ፡ ሰይፈ፡ ረድኤት፡ በከመ፡
#                   ወሀቦ፡ ለላሊበላ፡ ሰይፈ፡ መዊዕ፡ ከመ፡ ይውቂ፡ ክሣዶ፡ ለዝንቱ፡ አርዌ፡ ርጉም፡ ወይረስየነ፡ ለነኒ፡ ከመ፡ ናውቂ፡ ክሣዶ፡
#                   በከመ፡ አውቀዮ፡ ውእቱ፡ አሜን፨ </explicit>
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The end is defined by "Amen" and the beginning of the following text written with
#                   red inks. As it was noted, an explicit of JerusLal corresponds to the articulated
#                   explicit. </note>
#                         </msItem>
#                      </msItem>
#
#                      <msItem xml:id="ms_i1.5">
#                         <locus from="17va" to="21va"/>
#                         <title type="complete" ref="LIT5084TUfiveLal"/>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#17va"/> ወዝንቱሰ፡ ብእሲ፡ ክቡር፡ ኮከብ፡ ፅዱል፡ ዘያንሶሱ፡ መልዕልተ፡ ዓየር፡ በጢሎ፡ እምሕሊና፡
#                   ዘበምድር፨ አልቦ፡ ዘገብረ፡ ምግባራተ፡ ዘያምዕዖ፡ ለመንፈሰ፡ ለእግዚአብሔር። ወአልቦ፡ አመ፡ ሰሳለ፡ መንፈስ፡ ቅዱስ፡ እምኔሁ፨
#                   እምአመ፡ ተወልደ፡ እምከርሠ፡ ጥምቀት፨ እስመ፡ አተግኅሠ፡ እምቃለ፡ መጻሕፍት፡ ዘውእቱ፡ እስትንፋሰ፡ መለኮት፨ </incipit>
#
#                         <explicit xml:lang="gez">
#                            <locus target="#21va"/> እስከ፡ አመ፡ ይሠሃለነ፨ </explicit>
#
#                         <note>In the present manuscript GospelLal is divided into two portions with a
#                   supplication. Having the same articulated incipit as GospelLal, it has another
#                   internal explicit and internal incipit, which will end with the same articulated
#                   explicit, as of GospelLal. </note>
#
#                         <explicit xml:lang="gez">
#                            <locus target="#18vb"/>በከመ፡ ይቤ፡ እግዚእነ፡ አልቦ፡ ዘይእኅዝ፡ ፅርፈ፡ ወየሐርስ፡ ድኅሪተ፨ ወይከውን፡ ድልወ፡
#                   ለመንግሥተ፡ ሰማያት፨ ርትዕት፡ ይእቲ፡ መንግሥተ፡ ሰማያት፨ ወዘንተ፡ ሰሚዖ፡ ኮነ፡ ሐረሳዊ፡ ዘመንፈስ፨ እስመ፡ ሰሚዖ፡ ሰብእ፡
#                   ቃለ፡ ሕይወት፡ የሐውር፡ በፍኖተ፡ ሕይወት፨ </explicit>
#
#                         <explicit xml:lang="gez" type="supplication">
#                            <locus target="#18vb"/> ወበዝንቱ፡ ቃለ፡ ሕይወት፡ ዕቀባ፡ ለንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወዕቀቦሙ፡ ለውሉዳ፡ ኃይለ፡
#                   ኢየሱስ፡ ኃይለ፡ ሚካኤል፡ ወልደ፡ ማርያም፡ ወለአዋልዲሃ፡ ወለተ፡ ማርያም፡ ኂሩተ፡ ሥላሴ፡ ለዓለመ፡ ዓለም፡ አ፤ </explicit>
#
#                         <note>First two lines are written with red inks. The text ends with a supplication
#                   note.</note>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#19ra"/>ወቅዱስኒ፡ ወብፁዕ፡ ላሊበላ፡ አኮ፡ ሰሚዖ፡ ቃለ፡ መንፈስ፡ ዘየኀድግ፡ ዘእንበለ፡ ይግበር፡
#                   እስመ፡ ይፈርህ፡ ቃለ፡ ሐዋርያ፡ ዘይቤ፡ እመቦ፡ ዘያጸምዖ፡ ለቃል፡ ወኢይገብሮ፨ </incipit>
#
#                         <explicit xml:lang="gez">
#                            <locus from="19vb" to="20ra"/>እስመ፡ ይቤ፡ ጥበቡ፡ እንከ፡ ወአጥብቡ፡ ልበክሙ፨ እስመ፡ ጸላኢክሙ፡ ጋኔን፡ ይጥሕር፡
#                   ከመ፡ አንበሳ፡ ወየኃሥሥ፡ ዘይውኅጥ፨ ወቆመ፡ ዲበ፡ ኰኵሐ፡ ሃይማኖት፡ ዘኢያንቀለቅል፡ መሠረቱ፡ በኃይለ፡ ነፋሳት፨ እለ፡ እሙንቱ፡
#                   ዓላውያን፡ እለ፡ አውከኩ፡ እምጽድቅ፨ ወተዓተቱ፡ እምርትዕ፡ ወእምሃይማኖት፡ መንክር። በከመ፡ ይቤ፡ አጽንዑ፡ ቀዊመ፡
#                   በሃይማኖትክሙ፨ </explicit>
#
#                         <note>The beginning is marked as monthly reading for the 12th of Ḥāmle. The text
#                   starts on the new page and new line, first two lines are written with red inks.
#                   The end is defined by the left space.</note>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#20ra"/>ወኮነ፡ ልቡ፡ ጽሌ፡ ዘሕግ፡ ዘይሜህር፡ ርትዓ፡ ወምጽዋተ፡ ወምሒረ፡ ነዳያን፡ ወሰርየ፡
#                   ለአባስያን፨ በከመ፡ ይቤ፡ እግዚእነ፡ በወንጌል። ለእመ፡ አበሰ፡ ለከ፡ እኁከ፡ ኅድግ፡ ሎቱ፡ ስብዓ፡ በበስብዕ፨ </incipit>
#                      </msItem>
#
#                      <msItem xml:id="ms_i1.6">
#                         <locus from="21va" to="33va"/>
#                         <title type="complete" ref="LIT5086TUsixLal"/>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#21va"/>ወበዝ፡ ካዕበ፡ ላሊበላ፡ ብፁዕ፡ ንጉሠ፡ ኢትዮጵያ፡ ወምክሐ፡ ኵሉ፡ አድያሚሃ፡ ተመሰሎሙ፡
#                   ለትጉሃነ፡ ሰማይ፨ </incipit>
#
#                         <explicit xml:lang="gez" type="supplication">
#                            <locus from="33ra" to="33va"/> ወለነኒ፡ አሥራተ፡ ምሕረት፡ ይንሥአነ፡ ምክሀ፡ ኵልነ፡ ብፁዕ፡ ላሊበላ፡ ከመ፡ ንባእ፡
#                   ምስሌሁ፡ ኀበ፡ ቦአ፡ ላሊሁ፨ ወከመ፡ ንርፍቅ፡ ኀበ፡ ረፈቀ፡ ውእቱ፡ ከመ፡ ንሳተፎ፡ በፍሥሐሁ፨ ወከመ፡ ንደለው፡ በተድላሁ፨
#                   ወከመ፡ ናንሶሱ፡ ውስተ፡ ቤተ፡ መርዓ፡ ሐዳስ፨ ዘኢይበውእ፡ ውስቴታ፡ ዘኢለብሰ፡ ልብሰ፡ ከብካብ፡ መርዓ፡ ወዘኢተሠርገወ፡
#                   በብርሃነ፡ ሥላሴ፡ ወአመ፡ ይሠራዕ፡ ማዕደ፡ ሕይወት፡ ይበለነ፡ ብፁዕ፡ ላሊበላ፡ በይእቲ፡ ሰዓት፡ ነየ፡ አነ፡ ወደቂቅየ፡
#                   ዘወሀበኒ፡ እግዚአብሔር፨ ወያቁመነ፡ ምስሌሁ፡ ቅድመ፡ ገጸ፡ በግዑ፡ ኃቢኦ፡ በጽላሎተ፡ ክነፊሁ፨ ወከዲኖ፡ በመንጦላዕተ፡ ጸላሎቱ፨
#                   ከመ፡ ኢይቅረቡ፡ ኀቤነ፡ መላእክተ፡ እሳት፡ እኁዛነ፡ አስይፍት፡ እለ፡ የዓፅዱ፡ ክርዳደ፡ አርዮሙ፡ እማእከለ፡ ስርናይ፨
#                   ወየዓስርዎሙ፡ በበከላስስቲሆሙ፡ ለአንድዶቶሙ፡ ወለእለ፡ ይፈልጥዎሙ፡ ለኃጥአን፡ እማእከሎሙ፡ ለጻድቃን፨ ወለእለ፡ ይሌልይዎሙ፡
#                   ለጸዋጋን፡ እማእከሎሙ፡ ለየዋሃን፨ ወእሉ፡ መላእክተ፡ መዓት፡ ከመ፡ ኢይቅረቡ፡ ኀቤነ፡ ወከመ፡ ኢይፍልጡነ፡ እምኔሁ፡ ይመግበነ፡
#                   ሐቂፎ፡ በየማነ፡ እዴሁ፨ወያድኅና፡ እመከራ፡ ሥጋ፡ ወነፍስ፨ ለአመተ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወይዕቀባ፡ ለወለታ፡ ኂሩተ፡
#                   ሥላሴ፡ ለዓለመ፡ ዓለም፡ አሜን፨</explicit>
#
#                         <note> Incipit and explicit of WuddaseLal in the manuscript corresponds to the
#                   articulated incipit and explicit, with more articulated portion in between and
#                   which I articulate with internal incipits and explicits.</note>
#                         <msItem xml:id="ms_i1.6.1">
#                            <locus from="21va" to="23vb"/>
#                            <incipit xml:lang="gez">
#                               <locus target="#21va"/>ወበዝ፡ ካዕበ፡ ላሊበላ፡ ብፁዕ፡ ንጉሠ፡ ኢትዮጵያ፡ ወምክሐ፡ ኵሉ፡ አድያሚሃ፡ ተመሰሎሙ፡
#                     ለትጉሃነ፡ ሰማይ፨ </incipit>
#                            <explicit xml:lang="gez">
#                               <locus target="#23vb"/>ሐፀነቶ፡ መርዓተ፡ ንጉሥ፡ ሰማያዊ፡ እስመ፡ አእመረት፡ ከመ፡ ይከውና፡ ወልዳ፡ ዘምክህ፡
#                   ዘይትሜካህ፡ በፍናዊሃ፡ ወበኃሢሠ፡ ሕገጊሃ፨ በከመ፡ ትቤ፡ ሐና፡ እመ፡ ሳሙኤል፡ ወዘሰ፡ ይትሜካህ፨ በአእምሮ፡ ወበለብዎ፡
#                   እግዚአብሔር፨ በገቢረ፡ ፍትሕ፡ ወጽድቅ፡ በማእከለ፡ ምድር፨ </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The end is defined by the left space </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.6.2">
#                            <locus from="23vab" to="31rb"/>
#                            <incipit xml:lang="gez">
#                               <locus from="23vb" to="24ra"/>ወላሊበላኒ፡ አፍቀረ፡ አጥባቲሃ፡ ለዘሐፀነቶ፡ እስመ፡ ይጥዕሞ፡ አጥባቲሃ፡ እምወይን፡
#                   ወአፈዋቲሃኒ፡ ይምዕዝ፡ እምኵሉ፡ ዕፍረታት፡ በከመ፡ ይቤ፡ ሰሎሞን፡ በውስተ፡ መኃልየ፡ መኃልይ፡ አዳም፡ አጥባትኪ፡ እምወን፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#31rb"/>ፍትወቱ፡ ለሥጋ፡ ወፍትወቱ፡ ለዓይን፡ ወስራሑ፡ ለመንበርት፡ ኢኮነ፡ ዝንቱ፡ እምኀበ፡
#                   እግዚአብሔር፨ አላ፡ እምዓለም፡ ወዓለምኒ፡ የኃልፍ፡ ወፍትወቱኒ፨ ወዘሰ፡ ይገብር፡ ፈቃዶ፡ ለእግዚአብር፡ ይነብር፡ ለዓለም፨ </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The text marked with three kinds of ፨</note>
#                         </msItem>
#                         <msItem xml:id="ms_i1.6.3">
#                            <locus from="31rb" to="32va"/>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#31rb"/>ወበእንተ፡ ዝንቱ፡ ብፁዕ፡ ወቅዱስ፡ ላሊበላ፡ ኢጥዕመ፡ ግሙራ፡ እምፍግዕቶሙ፡ ለኃጥአን፡
#                   ወኢእምአልባሰ፡ ቀጠንት፡ ወኢእማዕድ፡ ጥዕማት፨ እንዘ፡ ይሴፎ፡ በሊዓ፡ እማዕደ፡ ሕይወት፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus from="32rb" to="32va"/>በዝንቱኬ፡ ቃላት፡ ወበፍቅረ፡ መንፈስ፡ ቅዱስ፡ ተወርዚዎ፡ ብፁዕ፡ ላሊበላ፡ ዝኅዙኃ፡
#                   ገድል፡ ተወካፌ፡ ምንዳቤ፡ ሥጋ፡ ከመ፡ ይኩን፡ ሥሉጠ፡ ላዕለ፡ ዕፀ፡ ሕይወት፨ በከመ፡ ይቤ፡ ቴዎጎሎስ፡ ወልደ፡ ነጐድጓድ፨
#                   ብፁዓን፡ እለ፡ ያነጽሑ፡ አልባሲሆሙ፨ ከመ፡ ይኩን፡ ሥልጣኖሙ፡ ላዕለ፡ ዕፀ፡ ሕይወት፨ አመ፡ ይሰደዱ፡ ወይወፅኡ፡ አፍአ፡ ሐምስቱ፡
#                   አክላብ፡ እሉ፡ እሙንቱ፡ መሠርያን፡ ወዘማውያን፡ ወቀታልያን፡ ወእለ፡ ያጣዕው፡ ወኵሎሙ፡ እለ፡ ያፈቅሩ፡ ግብረ፡ ሐሰት፨ ወእሉ፡
#                   አመ፡ ይወፅኡ፡ እምከብካበ፡ መርዓ፡ መንገለ፡ አፍአ፨ </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The end is defined by the beginning of the following text written with red inks on
#                   the new line. </note>
#                         </msItem>
#                         <msItem xml:id="ms_i1.6.4">
#                            <locus from="32va" to="33ra"/>
#                            <incipit xml:lang="gez">
#                               <locus target="#32va"/>ወውእቱሰ፡ ላሊበላ፡ ይበውእ፡ ተጸዊዖ፡ በቃለ፡ መርዓዊ፡ ሰማያዊ፡ ዘይብል፡ ንዑ፡ ኀቤየ፡
#                   ቡሩካኑ፡ ለአቡየ፡ ትረሱ፡ መንግሥተ፡ ሰማያት፡ ዘአስተዳለወ፡ ለክሙ፡ እምቅድመ፡ ይትፈጠር፡ ዓለም፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#33ra"/>ወለጻድቃኒሁ፡ ቡሩካን፨ እለ፡ ፆሩ፡ ክበዳ፡ ወላህባ፡ ለዕለት፨ </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   It ends with a supplication note. The end is marked with three ፨ and dotted
#                   line.</note>
#                         </msItem>
#                      </msItem>
#
#                      <msItem xml:id="ms_i1.7">
#                         <locus from="33vb" to="115rb"/>
#                         <title type="complete" ref="LIT4922HagVit"/>
#
#                         <incipit xml:lang="gez">
#                            <locus target="#33vb"/>ንትመየጥኬ፡ ኀበ፡ ጥንተ፡ ገድሉ፡ ለዝንቱ፡ ዕፍረቱ፡ ምዑዝ፡ ከመ፡ ኢይምሰሎ፡ ዝንጋዔ፡
#                   ለልበ፡ አብድ፡ ለዘኢያፈቅር፡ ውዳሴሆሙ፡ ለጻድቃን፡</incipit>
#
#                         <explicit xml:lang="gez">
#                            <locus target="#115rb"/> ወከመዝ፡ ነበረ፡ በኵሉ፡ መዋዕለ፡ ሕይወቱ፡ እምአመ፡ ነግሠ፡ እስከ፡ አመ፡ ፈለሰ። </explicit>
#
#                         <note>Incipit of VitLal corresponds to the articulated incipit, while explicit of
#                   VitLal is not articulated in this manuscript. VitLal has been divided into
#                   portions, which I present in a descriptive way, presenting articulated incipit and
#                   explicit. I have introduced subtitles that will hopefully help to have a better
#                   idea what is articulated.</note>
#
#                         <msItem xml:id="ms_i1.7.1">
#                            <locus from="33vb" to="35ra"/>
#                            <incipit xml:lang="gez">
#                               <locus target="#33vb"/>ንትመየጥኬ፡ ኀበ፡ ጥንተ፡ ገድሉ፡ ለዝንቱ፡ ዕፍረቱ፡ ምዑዝ፡ ከመ፡ ኢይምሰሎ፡ ዝንጋዔ፡
#                     ለልበ፡ አብድ፡ ለዘኢያፈቅር፡ ውዳሴሆሙ፡ ለጻድቃን፡</incipit>
#                            <explicit xml:lang="gez">
#                               <locus from="34vb" to="34vb"/>ወሶቤሃ፡ ይትፌሣሕ፡ ሰይጣን፡ ምስለ፡ አጋንንቲሁ፡ እስመ፡ በሀብለ፡ ሀኬት፡ አሲሮ፡
#                   አውፅኦሙ፡ ወይኤምኆሙ፡ ሐቂፎ፡ ክሣዶ፡ ከመ፡ ዘይኤምኅ፡ አብ፡ ወልዶ፡ ፍቁሮ፨ ወይተልዎሙ፡ ኀበ፡ ሖሩ፡ እንዘ፡ ይሜግብዎሙ፡
#                   አጋንንቲሁ፡ ይምነ፡ ወጽግመ፡ ከዋላ፡ ወፍጽመ፡ </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus from="34vb" to="35ra"/> ያድኅነነ፡ እግዚአብሔር፡ እመክፈልቶሙ፡ ለእሉ፨ ወያጽሕቅ፡ ልበነ፡ ለሰሚዓ፡ ቃላቲሁ፡
#                   ወለገቢረ፡ ትእዛዛቲሁ፨ ወይረስየነ፡ ድልዋነ፡ ከመ፡ ንኅድር፡ ውስተ፡ ቤቱ፨ ወከመ፡ ንጻመድ፡ ውስተ፡ ቤተ፡ መቅደሱ፡ በኵሉ፡
#                   መዋዕለ፡ ሕይወትነ፨ ወያርእየነ፡ በዘኖሠምሮ፡ ሎቱ፡ በኃይለ፡ ጸሎቱ፡ ለዝንቱ፡ ፀሐየ፡ ጽድቅ፡ ዘስሙ፡ ላሊበላ፡ ወይዕቀባ፡
#                   ለአመተ፡ እግዚአብሔር፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ለዓለመ፡ ዓለም፡ አሜን፨ </explicit>
#
#                            <note>The beginning is marked as monthly reading for the 12th of Naḥāse. The text
#                   starts in the new column and new line, lines 1, 2, 5, 6 are written with red inks.
#                   It ends with a supplication note. The end is marked with dotted line. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.2">
#                            <locus from="35ra" to="35vb"/>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#35ra"/>ስምዑኬ፡ ኦፍቁራንየ፡ እለ፡ ተኃሥሡ፡ በረከተ፡ ጸጋሁ፡ ለጻድቅ፡ ወእለ፡ ትፃምው፡ ለፍቅረ፡
#                   ላሊበላ፡ ከመ፡ ትርወዩ፡ እምነቅዓ፡ ገድሉ፡ ጥዑም፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#35va"/>እንዘ፡ ታከብርዎ፡ ከመ፡ መላእክት፨ ወከመ፡ ነቢያት፡ ወሐዋርያት፨ ወከመ፡ ጻድቃን፡ ወሰማዕት፡
#                   ወከመ፡ ደናግል፡ ወመነኮሳት፨ እስመ፡ ውእቱኒ፡ ኢሐፀ፡ እምኔሆሙ፨ </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus from="35va" to="35vb"/>ጸሎቱ፡ ወስእለቱ፡ ወሀብተ፡ ረድኤቱ፡ ወበረከተ፡ ተስፋሁ፡ የሃሉ፡ ምስለ፡ አመተ፡
#                   እግዚአብሔር፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ወምስለ፡ ኵልክሙ፡ ዝየ፡ እለ፡ ሀለውክሙ፡ ዝየ፡
#                   ወእለ፡ መጻእክሙ፡ እምርኁቅ፡ ወእምቅሩብ፨ እንዘ፡ ትትአመኑ፡ በጽላሎተ፡ ክነፊሁ፡ ወውእቱኒ፡ ኢይርኃቅ፡ እምኔክሙ፨ ለዓለመ፡
#                   ዓለም፡ አሜን፨ </explicit>
#
#                            <note>The text contained on f.35ra, line 3 up to f.35vb, line 7 is to be found in
#                   Perruchon's edition on page 11, line 1 up to line 22 (‘L'auteur commence a
#                   raconter la vie de Lalibala’.). The text starts on the new line and first two
#                   lines are written with red inks. It ends with a supplication note. The end is
#                   marked with dotted line.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.3">
#                            <locus from="35vb" to="37rb"/>
#                            <title>How Lālibalā was born in Roḥā.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#35vb"/>ወሀለወት፡ አሐቲ፡ ሀገር፡ እምአህጉራተ፡ ኢትዮጵያ፡ እንተ፡ ትሰመይ፡ ሮሐ፡ ሀገረ፡ ሙላዱ፡
#                   ለብፁዕ፡ ላሊበላ፡ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#37rb"/>አላ፡ መላእክት፡ እሙንቱ፡ እለ፡ ተመሰሉ፡ አንህብተ፡ እንዘ፡ ያኤምሩ፡ ንግሦ፨ ወጸቃውዓተ፡
#                   ምግባር፡ ዘይትቀዳሕ፡ እምኔሁ፨ እስመ፡ ሀለዎ፡ ለብፁዕ፡ ላሊበላ፡ ከመ፡ ይልበስ፡ ወይፈጽም፡ ዘንተ፡ ኵሎ፡ ትንቢታተ፡ ዘበምድር፡
#                   እንተ፡ ይእቲ፡ ምግባረተ፡ ጽድቅ፨ </explicit>
#
#                            <note>The text contained on f.35vb, line 8 up to f.37rb, line 19 is to be found in
#                   Perruchon's edition on page 12, line 1 up to page 13 line 21 (‘Naissance de
#                   Lalibala’.). The text starts on the new line and first two lines are written with
#                   red inks. The end is marked with three ፨. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.4">
#                            <locus from="37rb" to="39rb"/>
#                            <title>How Lālibalā grew up in a beautiful man.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus from="37rb" to="37va"/> ወእምዝ፡ ልሕቀ፡ እንዘ፡ የሐፅኖ፡ መንፈስ፡ ቅዱስ፡ ወያጸንዖ፡ በኃይል፡ ወበጥበብ፡
#                   ወበምክር፡ ወበግርማ፡ መንክር፨ ወኵለንታሁኒ፡ አዳም፡ ውእቱ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus from="39ra" to="39rb"/> ወይቤሉ፡ ሀለዎ፡ ይኩን፡ ንጉሠ፡ አመ፡ ልሕቀ፡ ዝንቱ፡ ውእቱ፡ ቀዳሜ፡ መንክራት፡ ዘኮነ፡
#                   በላዕለ፡ ብፁዕ፡ ላሊበላ፡ ዘተቀብዓ፡ ኃይለ፡ ውስተ፡ ቈናዝዓ፡ ድማሁ፡ ከመ፡ ሶምሶን፡ ቃዴ፡ እስራኤል፡ እስመ፡ ናዝራዊሁ፡
#                   ለእግዚአብሔር፡ ቅዱስ፡ ውእቱ፨ </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus target="#39rb"/> ጸሎቱ፡ ወስእለቱ፨ ወሀብተ፡ ረድኤቱ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡
#                   ወለታ፡ ኂሩተ፡ ሥላሴ፡ ወይባርከመ፡ ለኵልነ፡ ዝየ፡ እለ፡ ሀለውነ፡ ውሉደ፡ ቤተ፡ ክርስቲያን፡ ለዓለመ፡ ዓለም፡ አሜ፨ </explicit>
#
#                            <note>The text contained on f.37rb, line 20 up to f.38vb, line 11 is to be found in
#                   Perruchon's edition on page 13, line 22 up to page 14, line 24 (‘Portrait de
#                   Lalibala’.). The text starts on the new line and first two lines are written with
#                   red inks. It ends with a supplication note. The end is marked with three ፨ and
#                   with dotted line.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.5">
#                            <locus from="40ra" to="45va"/>
#                            <title>Lālibalā voluntarily embraces the death for the love of the others.</title>
#
#
#                            <incipit xml:lang="gez">
#                               <locus target="#40ra"/> ወእምዝ፡ እነግረክሙ፡ ካልአኒ፡ ነከራ፡ ዘተገብረ፡ በላዕለ፡ ብፁዕ፡ ላሊበላ፡ አመ፡
#                   ውርዛዌሁ፨ ወዝንቱሰ፡ ዘእከሥት፡ ለክሙ፡ ይእዜ፡ በቍዔት፡ ውእቱ፡ ለነፍሳቲክሙ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#45va"/>ወሪዶ፡ እምሰማያት፡ እንዘ፡ አልቦ፡ ዘአገበሮ፡ ለቢሶ፡ ትስብእተ፨ ወመዊቶ፡ ጸገወ፡ ሕይወተ፡
#                   ለምውታን፡ እስመ፡ በፈቃዱ፡ ጥዕመ፡ ሞተ፡ በእንተ፡ እሊአሁ፡ ወበእንተ፡ ፍቁራኒሁ፡ ምእመናን፨ </explicit>
#
#                            <note>The text contained on f.41ra, line 19 up to f.44va, 7 line is to be found in
#                   Perruchon's edition on page 15, line 1 up to page 18 line 23 (‘Le frère de
#                   Lalibala cherche a le faire mourir’.).The beginning is marked as monthly reading
#                   for the 12th of Maskaram. The text starts on the new page and new line, lines 1,
#                   2, 5, 6 are written with red inks. The end is defined by the left space. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.6">
#                            <locus from="45va" to="65ra"/>
#                            <title>Lālibalā became like Jesus Christ. Ascension to the heavens.</title>
#
#
#                            <incipit xml:lang="gez">
#                               <locus from="45va" to="45vb"/>ወላሊበላኒ፡ አማን፡ ተመሰሎ፡ ለመድኃኒ፡ ኵሉ፡ ዓለም፡ እስመ፡ በፈቃዱ፡ ሰትየ፡ ጽዋዓ፡
#                   ሞት፡ በእንተ፡ ፍቅረ፡ ካልኡ፡ እስመ፡ ሰምዓ፡ ቃለ፡ እንዘ፡ ይብል፡ እስመ፡ ተፋቅሮሰ፡ ፍጹም፡ ሕግ፡ ውእቱ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#65ra"/>ኀበ፡ ሀለወ፡ እግዚኦሙ፡ ዘተሰምየ፡ እኁሆሙ፡ በከመ፡ ይቤ፡ ለሊሁ፡ ዘተሳተፈ፡ ምስሌሆሙ፡
#                   ሥጋ፡ ወደመ፡ ወዓፅመ፡ ወጸጒረ፡ ወአሥራወ፨ ወበእንተ፡ ዝንቱ፡ እብለክሙ፡ ኦኃውየ፨ እስመ፡ ነሣእኩ፡ ዘዚአክሙ፡ ከመ፡ አሀብክሙ፡
#                   ዘዚአየ፨ ወኀበ፡ ሀሎኩ፡ አነ፡ ህየ፡ ይሄሉ፡ ዘይትለአክኒ፨ </explicit>
#
#                            <note>The text contained on f.45va, line 14 up to f.46ra, line 14 is to be found in
#                   Perruchon's edition on page 18, line 24 up to page 19, line 13. The text contained
#                   on f.47ra, line 13 up to f.48vb, line 3 is to be found in Perruchon's edition on
#                   page 19, line 14 up to page 21, line 11 ('Lalibala est ravi dans les cieux'.). The
#                   text contained on f.53ra, line 1 up to f.53rb, line 3 line is to be found in
#                   Perruchon's edition page 21, line 12 up to line 20. The text contained on f.56ra,
#                   line 3 up to f.56ra, line 16 is to be found in Perruchon's edition on page 21,
#                   line 21 up to page 22, line 1. The text starts on the new line and first two lines
#                   are written with red inks. Apparently, the upper margin indication for monthly
#                   reading on the 12th of Ṭǝqǝmt is applicable to the text that follows. The end is
#                   defined by the left space.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.7">
#                            <locus from="65rb" to="65vb"/>
#                            <title>Lālibalā is in the heavens.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#65rb"/>ኢሰማዕከኑ፡ ኦብእሲ፡ እንዘ፡ ይነግር፡ ዕበየ፡ ልዕልናክሙ፡ ጳውሎስ፡ ዘከመ፡ ትትሌዓሉ፡
#                   እምኔነ፡ ወይብል፡ እስመ፡ አኮ፡ እመላእክተ፡ ዘነሥኦ፡ ለዘነሥኦ፨ አላ፡ እምዘርአ፡ አብርሃም፡ አልዓለ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#65vb"/>ወእፈቅድ፡ ከመ፡ ይርአዩ፡ ስብሐትየ፡ ዘወሀብከኒ፨ ዘሀሎ፡ ምስሌከ፡ እምቅድመ፡ ይትፈጠር፡
#                   ዓለም፨ እስመ፡ አነሂ፡ አፍቀርክዎሙ፡ በከመ፡ አንተ፡ አፍቀርከኒ፨ </explicit>
#
#                            <note>The beginning is marked as monthly reading for the 12th of Ḫǝdār. The end is
#                   marked with three ፨. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.8">
#                            <locus from="65vb" to="68rb"/>
#                            <title>Lālibalā is in the heavens.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus from="65vb" to="66ra"/>ዝንቱኬ፡ ቃል፡ ዘየዓርገክሙ፡ መልዕልተ፡ ኪሩቤል፡ ወሱራፌል፡ ኀበ፡ ሀለወ፡ ለባሴ፡
#                   ሥጋክሙ፡ ወዓቃሜ፡ ኪዳን፡ ምስሌክሙ፡ ዘተካየድክሙ፡ ለእለ፡ ትገብሩ፡ ፈቃዶ፡ ከመ፡ ተሀልው፡ ኀበ፡ ሀለወ፨ ወከመ፡ ትንበሩ፡ ኀበ፡
#                   ነበረ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#68rb"/>ወምዕማዲሁኒ፡ ወሠራዊቲሁኒ፡ ዘዕፅ፡ ወመክደናኒ፡ ዘሠቅ፡ እንተ፡ ላዕሉ፨ ወአንተሰ፡ አኮ፡
#                   ዘተኃሥሥ፡ ዕፀ፡ ለአዕማድ፡ ወለምዕማዱ፡ ወለሠርዌሁ፨ </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The end is defined by the left space. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.9">
#                            <locus from="68rb" to="68va"/>
#                            <title>How God showed Lālibalā ten monolithic churches.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#68rb"/>ወዘንተ፡ ብሂሎ፡ አርአዮ፡ አብያተ፡ ዓቢያተ፡ ዘእምአሐቲ፡ ዕብን፡ ወኊልቆንሰ፡ ለእማንቱ፡
#                   አብያተ፡ ዘአርአዮ፡ ፲ እማንቱ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#68va"/>ወቦ፡ እምኔሆን፡ ዘኅብረ፡ ሐመደ፡ ክቦ፡ ኅበሪሆን። ወቦ፡ እምኔሆን፡ ዘዓቢይ፡ ኑኃ፡
#                   ግደሚሆን። ለአሐቲ፡ እምአሐቲ፡ የዓቢ፡ ዓዲ፡ ኑኃ፡ ሥሮን፨</explicit>
#
#                            <note>The text contained on f.68rb, line 8 up to f.68va, line 20 is to be found in
#                   Perruchon's edition page 22, line 2 up to line 13 ('Dieu montre à Lalibala les dix
#                   églises monolithes du ciel',). The text starts on the new line and first two lines
#                   are written with red inks. The end is marked with three ፨. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.10">
#                            <locus from="68vb" to="69va"/>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#68vb"/>ወዘንተ፡ ኵሎ፡ እምድኅረ፡ አርአዮ፡ ለላሊበላ፡ ዝኩ፡ እግዚአ፡ ኃይል፡ ዘይነብር፡ ውስተ፡
#                   ሰማይ፡ ስፉሕ፡ ዘኅብረ፡ በረድ። ዘሀሎ፡ መልዕልተ፡ ርእሶሙ፡ ለ፬ቱ፡ እንስሳ፡ እለ፡ እሙንቱ፡ ኪሩባውያን፨ </incipit>
#                            <explicit xml:lang="gez">
#                               <locus target="#69va"/>ዘተናገርክዎ፡ ገጸ፡ በገጽ፡ ከመ፡ ዘይትናገር፡ ብእሲ፡ ምስለ፡ ቢጹ። እስከ፡ ተሰብሐ፡ ኅብረ፡
#                   ገጹ፡ እምነጽሮ፡ ምዕዛርየ፨ </explicit>
#                            <note>The beginning is marked as monthly reading for the 12th of Tāḫsās. The text
#                   starts in a new column new line, first two lines are written with red inks. The
#                   end is defined by the left space. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.11">
#                            <locus from="69vb" to="70va"/>
#
#                            <incipit xml:lang="gez">
#                               <locus from="69vb" to="70ra"/>ወዘንተ፡ ሰሚዖ፡ ብፁዕ፡ ላሊበላ፡ ሰገደ፡ ቅድመ፡ ገጹ፡ ለአኃዜ፡ ኵሉ፨ ወአኃዘ፡
#                   ይንብብ፡ ወይቤ፡ እግዚኦ፡ አነኑ፡ እክል፡ ከመ፡ እግበር፡ ዘንተ፡ ኦጽራሐ፡ መንግሥትከ፡ ዘአርአይከኒ፡ ዓሠርተ፡ አብያተ፡
#                   እምአሐቲ፡ ኰኵሕ። </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus from="70rb" to="70va"/>ወባሕቱ፡ በምክንያተ፡ ተልእኮ፡ በእንቲአሆን፡ ትሰመይ፡ አንተ፡ ገባሪሆን፡ ወአርአዮ፡
#                   ካዕበ፡ ሐፃውንተ፡ በዘቦቶን፡ ይትገበር፡ አርአያሆን፡ ለእማንቱ፡ አብያተ፡ ክርስቲያናት፡ ዘርእየ፡ በውስተ፡ ሰማይ፡ ሳብዕ። </explicit>
#
#                            <note>The text starts on the new line and first line is written with red inks. The
#                   end is defined by the left space.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.12">
#                            <locus from="70va" to="71vb"/>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#70va"/>ወብፁዕ፡ ላሊበላ፡ ሰሚዖ፡ ኵሎ፡ ዘነበቦ፡ እግዚእ፡ ኃያላን፡ ወርእዮ፡ ኵሎ፡ ዘአርአዮ፡ ይቤ፡
#                   ፈቃድከ፡ ለይኩን፡ እግዚኦ፡ ወአኮ፡ ፈቃደ፡ ዚአየ፡ ወባሕቱ፡ ለይርድአኒ፡ ኃይልከ፡ እስመ፡ ፅቡስ፡ አነ። </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#71vb"/> ወከመዝ፡ እትአኰት፡ ወእሴባሕ፡ እምእለ፡ ይኔጽሩ፡ ማኅፈዳተ፡ መቅደስየ፡ ዘሀለዋ፡
#                   ያስተርእያ፡ ዲበ፡ ምድር፡ እምአሐቲ፡ ኰኵሕ። ወአነሂ፡ ናሁ፡ አቀውም፡ ምስሌከ፡ ኪዳነ፡ ዮም፡ በዛቲ፡ ዕለት፨ </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The end is defined by the beginning of the following text written with red inks on
#                   the new line.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.13">
#                            <locus from="71vb" to="74ra"/>
#
#                            <incipit xml:lang="gez">
#                               <locus from="71vb" to="72ra"/> ኵሉ፡ ዘይበጽሕ፡ ውስተ፡ ማኅፈዳት፡ ዘሀለወከ፡ ትሕንጾን፡ ወይትጋነይ፡ በውስቴቶን።
#                   እንዘ፡ ይትአመን፡ በኃይለ፡ ጸሎትከ፡ ወይዜክረከ፡ ወይብለከ፡ መሐረኒ፡ እግዚኦ፡ ወተሠሃለኒ። </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#74ra"/>ወአነ፡ እወዲ፡ ፍርሃተ፡ ውስተ፡ ልበ፡ ኵሎሙ፡ እለ፡ የዓልውከ። ወዑቅ፡ አንተሂ፡ ከመ፡
#                   ታዕትት፡ እምሕዝበ፡ መንግሥትከ፡ ኵሎ፡ ዓመፃ፡ ወግፍዓ። </explicit>
#
#                            <note>The text starts on the new line and first two lines, i.e. lines 16, 17 of the
#                   column, as well as lines 20, 21 are written with red inks. The end is defined by
#                   the left space.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.14">
#                            <locus from="74ra" to="75ra"/>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#74ra"/>ወዘንተ፡ ኵሎ፡ ኪዳነ፡ ሰሚዖ፡ ብፁዕ፡ ላሊበላ፡ ሰገደ፡ ወዲቆ፡ በገጹ፡ በቅድመ፡ እግዚአ፡
#                   ኃያላን፡ ወይቤ፡ እግዚአ፡ እግዚእየ፡ ምንትኑ፡ አነ፡ ከመ፡ እኩን፡ ንጉሠ፡ ዲበ፡ ሕዝብከ፡ ዘአልብየ፡ አእምሮ። </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#75ra"/>ወዘንተ፡ ብሂሎ፡ ለዝኩ፡ መልአክ፡ ለዘአዕረጎ፡ እምድር፡ ይቤሎ፡ እንዘ፡ ይብል፡ ናሁ፡
#                   ረሰይኩከ፡ ወሤምኩከ፡ ከመ፡ ትኩን፡ ዓቃቢሁ፡ በኵሉ፡ መዋዕሊሁ። </explicit>
#
#                            <note>The text starts on the new line and first two lines are written with red inks.
#                   The end is defined by the left space.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.15">
#                            <locus from="75ra" to="75vb"/>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#75ra"/>ወይቤሎ፡ ካዕበ፡ ለብፁዕ፡ ወለቅዱስ፡ ላሊበላ፡ ወአንተሂ፡ ኢትተክዝ፡ በይነ፡ መንግሥት፡
#                   እስመ፡ አነ፡ በእንተ፡ ክብር፡ ኃላፊ፡ ዘእሠይመከ። </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus from="75va" to="75vb"/>አላ፡ ነበረ፡ ውስተ፡ ዓቢይ፡ ፍሥሐ፡ ውስተ፡ ዓፀደ፡ ትጉሃን፡ ወውስተ፡ አብያተ፡ ብርሃን፡
#                   ከመ፡ ኤርምያስ፡ ነቢይ፡ ዘርእየ፡ ምስጢራተ፡ ትንቢት፡ በእንተ፡ ርደቱ፡ ለእግዚእነ፡ እምሰማይ፡ ወበእንተ፡ ተመስሎቱ፡ ሰብአ፡ </explicit>
#
#                            <note>The text contained on f.75ra, line 9 up to f.75vb, line 5 is to be found in
#                   Perruchon's edition on page 22, line 14 up to page 23, line 15 ('Lalibala reçoit
#                   l'ordre de construire des églises semblables; son retour sur la terre'., continues
#                   in the following unit). The text
#                   starts on the new line and first two lines are
#                   written with red inks. The end is defined by the beginning of the following
#                   text
#                   written with red inks.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.16">
#                            <locus from="75vb" to="77ra"/>
#                            <title>Having seen the mysteries of the heaven and being appointed to the thrown, on
#                   the third day Lālibalā comes back to the earth. </title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#75vb"/>ወብፁዕ፡ ላሊበላ፡ በሣልስት፡ ዕለት፡ ተመይጠ፡ ዲበ፡ ምድር፡ ርእዮ፡ ወነጺሮ፡ ምሥጢራተ፡
#                   ሰማይ፡ ወተቀቢዎ፡ ቅብዓ፡ መንግሥት፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#77ra"/>ወባሕቱ፡ ኢተሀበሉ፡ ይግንዝዎ፡ እስመ፡ ኢቈረ፡ ሥጋሁ፡ ከመ፡ ሕገ፡ በድን፡ በዝንቱ፡ ሠሉስ፡
#                   መዋዕል፤ እስመ፡ ምውቅ፡ ሥጋሁ፡ በላህበ፡ መንፈስ፡ ቅዱስ፡ ዘኅዱር፡ ውስቴቱ፨ </explicit>
#
#                            <note>The text contained on f.75vb, line 6 up to f.77ra, line 8 is to be found in
#                   Perruchon's edition on page 23, line 15 up to page 24, line 3 ('Lalibala reçoit
#                   l'ordre de construire des églises semblables; son retour sur la terre'., continues
#                   in the following unit). The text starts on the new line and first two lines are
#                   written with red inks. The end is defined by the beginning of the following text
#                   written with red inks. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.17">
#                            <locus from="77ra" to="78rb"/>
#                            <incipit xml:lang="gez">
#                               <locus target="#77ra"/>ወላሊበላሰ፡ ነቅሐ፡ እምስካቡ፡ ከመ፡ ዘጽሕወ፡ እምወይን፨ ወአብርሃ፡ ገጹ፡ ከመ፡ ፀሐይ፡
#                   እምነ፡ ራዕያት፡ ዘርእየ፡ ወእምነ፡ ስብሐቲሁኒ፡ ለእግዚአብሔር፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus from="78ra" to="78rb"/>ወካልኡን፡ ይቤ፡ አፍቅሩ፡ ቢጸክሙ፡ እስመ፡ ተፋቅሮ፡ ይደመሰሶን፡ ለኵሎን፡ ኃጣውእ፨
#                   አማንኬ፡ ተፈጸመ፡ ቃለ፡ ሐዋርያ፡ ዘይቤ፡ በላዕለ፡ ብፁዕ፡ ላሊበላ፡ ፈርየሂ፡ ወተመክዓበ፨ </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus target="#78rb"/>ወለነኒ፡ ይረስየነ፡ ጽሑቃነ፡ ለአፍቅሮ፡ ቢጽነ፨ እግዚእነ፡ ወመድኃኒነ፡ ኢየሱስ፡ ክርስቶስ፡
#                   በጸሎቱ፡ ወበስእለቱ፡ ወበሀብተ፡ ረድኤቱ፨ ወበፃማ፡ ገድለ፡ ዚአሁ፡ ወበሐፈ፡ ድካሙ፡ ዘተወክፈ፡ በሥጋሁ፡ ዝንቱ፡ ብእሲ፡ ብፁዕ፡
#                   ወቅዱስ፡ ላሊበላ፡ ዘተሰምየ፡ገብረ፡ መስቀል፡ ወያድኅና፡ እመከራ፡ ሥጋ፡ ወነፍስ፨ ለንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ለዓለመ፡ ዓለም፡
#                   አሜን፨ </explicit>
#
#                            <note>The text contained on f.77ra, line 8 up to f.78rb, line 21 is to be found in
#                   Perruchon's edition on page 24, line 3 up to page 25, line 21 ('Lalibala reçoit
#                   l'ordre de construire des églises semblables; son retour sur la terre'.). First
#                   two lines are written with red inks. It ends with a supplication note. The end is
#                   marked with three ፨. </note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.18">
#                            <locus from="78va" to="79vb"/>
#                            <title>Lālibalā runs away to the desert.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#78va"/>ወእምድኅረዝ፡ ነበረ፡ ብፁዕ፡ ላሊበላ፡ እንዘ፡ ይትዌከፍ፡ ኵሎ፡ ፅዕለተ፡ ወኵሎ፡ ምናኔ፡
#                   እምኀበ፡ አዝማዲሁ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#79vb"/>ወብፁዕኒ፡ ላሊበላ፡ ነበረ፡ እንዘ፡ ይሜግቦ፡ ኃይለ፡ መንፈስ፡ ቅዱስ፨ ወሲሳዮ፡ ይሴሰይ፡
#                   ንዒዎ፡ አራዊተ፡ በከመ፡ ነገርናክሙ፡ ቅድመ፨ </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus target="#79vb"/>በረከተ፡ ጸሎቱ፡ የሃሉ፡ ምስለ፡ አመተ፡ እግዚአብሔር፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወኃይለ፡
#                   ሚካኤል፡ ወልደ፡ ማርያም፡ ወለአዋልዲሃ፡ ወለተ፡ ማርያም፡ ኂሩተ፡ ሥላሴ፡ ወበረከተ፡ ጸጋሁ፡ የሃሉ፡ ላዕለ፡ ኵልነ፡ እለ፡
#                   ተጋባእነ፡ ውስተ፡ ዛቲ፡ ቅድስት፡ ቤተ፡ ክርስቲያን፨ ለዓለመ፡ ዓለም፡ አሜን፨ </explicit>
#
#                            <note> The text contained on f.78va, line 1 up to f.79vb, line 20 is to be found in
#                   Perruchon's edition on page 25, line 22 up to page 27, line 17 (‘Lalibala se
#                   retire au désert’.) The text starts on the new page and new line, first two lines
#                   are written with red inks. It ends with a supplication note. The end is marked
#                   with three ፨ and a dotted line.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.19">
#                            <locus from="80ra" to="86ra"/>
#                            <title>Lālibalā marries Masqal Kǝbrā. He is blamed for marrying an engaged woman,
#                   but helped by an angel he escapes the punishment.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#80ra"/>ወከመዝ፡ እንዘ፡ ሀለወ፡ ብፁዕ፡ ላሊበላ፡ በውስተ፡ ገዳም፡ አስተርአዮ፡ መልአከ፡
#                   እግዚአብሔር፡ ዘአዕረጎ፡ ውስተ፡ ሰማይ፨ ወዘተአዘዘ፡ ከመ፡ ይዕቀቦ፡ በኵሉ፡ መዋዕሊሁ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#85vb"/>ወመፍቅደ፡ ሩጸቶሙ፡ ለገይሰ፡ ቤተ፡ ክርስቲያን፡ ወለናዝዞ፡ ሙቁሐን። ወስነ፡ ይዋሄሆሙ፡
#                   ዘይትሜሰል፡ ከመ፡ ይዋሄ፡ በግዕ። ወሀብተ፡ ምጽዋቶሙ፡ ዘኅቡእ፡ ወዘክሡት። </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus from="85vb" to="86ra"/>ወኵሉ፡ ጻሕቀ፡ ተጸምዶሙ፡ ዘፆሩ፡ በሥጋሆሙ፡ ላሊበላ፡ ወመስቀል፡ ክብራ፡ የሃሉ፡
#                   ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ወላዕለ፡ ኵሎሙ፡ እለ፡ ይትአመኑ፡ በኃይለ፡ ጸሎቶሙ፡ ለእሉ፡
#                   ክልኤሆሙ፡ አዕናቍ፡ ፅዱላን፡ እለ፡ ያዋክዩ፡ ወያበርሁ፡ በውስተ፡ ጽልመት፡ ይኩነነ፡ መርሃ፡ በኀበ፡ ኵሉ፡ ዘወፈርነ፨ ወበኀበ፡
#                   ኵሉ፡ ዘኣቶነ፨ በፍጽምነ፡ ወበከዋላነ፡ በይምንነ፡ ወበጽግምነ፨ እስከ፡ ለዓለመ፡ ዓለም፡ አሜን፨ </explicit>
#
#                            <note>The text contained on f.80ra, line 1 up to f.86ra, line 17 is to be found in
#                   Perruchon's edition on page 27, line 18 up to page 35, line 16 (‘Mariage de
#                   Lalibala; son frère le fait venir pour l'en punir’.). The beginning is marked as
#                   monthly reading for the 12th of Ṭǝrr. The text starts on the new page and new
#                   line, lines 1, 2, 5, 6 are written with red inks. It ends with a supplication
#                   note. The end is marked with a dotted line.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.20">
#                            <locus from="86ra" to="87rb"/>
#                            <title>Lālibalā runs away to the desert with Masqal Kǝbrā.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus from="86ra" to="86rb"/>ወእምዝ፡ ሐለየ፡ ላሊበላ፡ ኵሎ፡ ምንዳቤያቲሁ፡ ዘረከቦ፡ እምኀበ፡ ኵሎሙ፡ አዝማዲሁ፡
#                   ወእምኀበ፡ ኵሎሙ፡ ሕዝብ፡ ዘተዓይነ፡ ኵርጓኔ፡ ዘንጉሥ፨ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#87rb"/>አመ፡ ሖረ፡ በትእዛዘ፡ ዚአከ፡ ወበትእዛዘ፡ መምህሩ፡ ከመ፡ ኢይርአይ፡ ሙስናሃ፡ ለኢየሩሳሌም፡
#                   በምክንያተ፡ ድውያን፡ እስመ፡ አዘዘ፡ ኤርሚያስ፡ ነቢይ፡ ከመ፡ ያምጽእ፡ በለሰ፡ ለፈውሶ፡ ድውያን። ወበህየ፡ ከደንኮ፡
#                   በመንጦላዕተ፡ ሣህልከ። እንዘ፡ ትሴስዮ፡ ንዋመ፡ ሠናየ፡ ፷ ወ ፮ተ፡ ዓመተ። </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus target="#87rb"/>ወለነኒ፡ በዘፈቀድከ፡ ትክል፡ አጽንዖተነ። ወለከ፡ ስብሐት፡ ለዓለም፡ ዓለም፡ አሜን፨ </explicit>
#
#                            <note>The text contained on f.86ra, line 18 up to f.86va, line 10 is to be found in
#                   Perruchon's edition on page 35, line 17 up to page 36, line 6 (‘Lalibala retourne
#                   au désert avec sa femme’.). The text starts on the new line and first line, i.e.
#                   line 18, as well as line 20 are written with red inks. Apparently, the upper
#                   margin indication for monthly reading on the 12th of Yakkātit is applicable to the
#                   text that follows. It ends with a supplication note. The end is defined by the left
#                   space.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.21">
#                            <locus from="87rb" to="87vb"/>
#                            <title>After their prayers for food, Lālibalā and Masqal Kǝbrā find partridges which
#                   they eat.</title>
#
#                            <incipit xml:lang="gez">
#                               <locus from="87rb" to="87va"/>ወእምዝ፡ ሶበ፡ ፈጸሙ፡ ጸሎቶሙ፡ አንሶሰወት፡ መስቀል፡ ክብረ፡ ውስተ፡ ውሣጤ፡ በዓት፡
#                   ወረከበት፡ በህየ፡ ጴርድክሴ፡ ዓቢየ፡ ወዜነወቶ፡ ለምታ። </incipit>
#                            <explicit xml:lang="gez">
#                               <locus target="#87va"/>ወወድቀ፡ ማእከለ፡ ቴዓይኒሆሙ። ወዓውደ፡ ደባትሪሆሙ፡ በልዑ፡ ወጸግቡ፡ ጥቀ። ወኢያሕጣእኮሙ፡
#                   እምዘ፡ ፈቀዱ። </explicit>
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus from="87va" to="87vb"/>ወለነኒ፡ ኢኅጣእከነ፡ ለአግብርቲከ፡ እለ፡ ስዱዳን፡ እምሰብእ፡ በእንተ፡ ኃጢአትነ። ወውእተ፡
#                   ዖፈ፡ ተሴስዮሙ፡ ኃደሩ፡ እንዘ፡ የአኵትዎ፡ ለእግዚአብሔር። ጸሎቶሙ፡ ወበረከቶሙ፡ የሃሉ፡ ምስለ፡ ፍቅርቶሙ፡ ወለተ፡ ኢየሱስ፡
#                   ወምስለ፡ ወለታ፡ ኂሩተ፡ ሥላሴ፡ ለዓለመ፡ አሜን፨ </explicit>
#                            <note>The text contained on f.87rb, line 16 up to f.87va, line 8 is to be found in
#                   Perruchon's edition on page 36, line 7 up to line 11. The text starts on the new
#                   page and new line, three line, namely lines 17, 19 and 21 are written with red
#                   inks. It ends with a supplication note. The end is marked with a dotted
#                   line.</note>
#                         </msItem>
#
#                         <msItem xml:id="ms_i1.7.22">
#                            <locus from="87vb" to="90ra"/>
#                            <title>Lālibalā and Masqal Kǝbrā live in a cave, like Prophet Isaiah and other
#                   prophets. They run further to the east from the persecution. Archangel Gābrǝ’el
#                   announces to the family that Lālibalā will make a pilgrimage to Jerusalem. </title>
#
#                            <incipit xml:lang="gez">
#                               <locus target="#87vb"/>ወእምዝ፡ ነበሩ፡ ክልኤሆሙ፡ እምይእቲ፡ ዕለት፡ ውስተ፡ ይእቲ፡ በዓት፡ ኀበ፡ በጽሑ፡ በይእቲ፡
#                   ዕለት፡ እንዘ፡ ይሴሰዩ፡ ዘአቅረበ፡ ሎሙ፡ መንፈስ፡ ቅዱስ፡ እምአቃቂራተ፡ ገዳም፡ እንዘ፡ ይትሜሰልዎ፡ ለመክብበ፡ ነቢያት፡
#                   ኢሳይያስ፡ ወለካልአኒሁኒ፡ ነቢያት፡ ዘነበሩ፡ </incipit>
#
#                            <explicit xml:lang="gez">
#                               <locus target="#90ra"/>ላሊበላሰ፡ ወመስቅል፡ ክብራ፡ ነበሩ፡ ህየ፡ በተጸምዶ፡ ዓቢይ፡ በጾም፡ ወበጸሎት፡ በቀዊም፡
#                   ወበሰጊድ፡ መጠነ፡ ነበሩ፡ ውስተ፡ ይእቲ፡ ብሔር፡ ኅቡረ። </explicit>
#
#                            <explicit xml:lang="gez" type="supplication">
#                               <locus target="#90ra"/>ጸሎቶሙ፡ ወበረከቶሙ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ ወለተ፡ ኢየሱስ፡ ወምስለ፡ ወለታ፡ ኂሩተ፡
#                   ሥላሴ፡ ለዓለመ፡ ዓለም፡ አሜን፨ </explicit>
#
#                            <note>The text contained on f.87vb, line 8 up to line 16 is to be found in
#                   Perruchon's edition on page 36, line 12 up to line 15. The text contained on
#                   f.88ra, line 4 up to f.88rb, line 1 is to be found in Perruchon's edition page 36,
#                   line 15 up to line 22. The text contained on f.88vb, line 1 up to f.89ra, line 7
#                   is to be found in Perruchon's edition on page 36, line 23 up to page 37, line 8.
#                   The text contained on f.89rb, line 7 up to f.89va, line 12 is to be found in
#                   Perruchon's edition on page 37, line 9 up to line 19 ('L’ange Gabriel annonce à
# ...
#             ሕንቀት። ወጸርሐት፡ በ<hi rend="rubric">ው</hi>ስተ፡ <cb n="b"/> ልበ፡ እንዘ፡ ትብል፡ አበስኩ፡ ለከ፡ ኦእግዚእየ፡<hi rend="rubric">ገብረ፡ መስቀል፡ </hi> መሲሑ፡ ለእግዚአብሔር። ወኢይደግም፡ እምይእዜ፡ ጸውዖተከ። ወኢይዘክር፡ ስመከ፡ በእከይ፡
#             ዘእንበለ፡ በሠናይ። ወዘንተ፡ ሶበ፡ ትቤ፡ ወፅአ፡ ውእቱ፡ ምታረ፡ ሥጋ፡ ምስለ፡ ደመ፡ ጕርዔሃ፡ ወወድቀ፡ ውስተ፡ ምድር። ጸሎቱ፡ ወስእለቱ፡
#               ለ<hi rend="rubric">ገብረ፡ መስቀል፡ </hi> የሃሉ፡ ምስለ፡ ንግሥትነ፡ <hi rend="rubric">ወለተ፡ ኢየሱስ፡
#             </hi>ወሐብለ፡ ረድኤቱ፡ ይሕንቆ፡ ለዕድውነ፡ አሜን። <hi rend="rubric">ወካዕበ፡ አሐተ፡ ዕለተ፡ ኣኃዘ፡ ይጽርፍ፡ ሎቱ፡ አሐዱ፡
#               ብእሲ፡</hi> ለ<hi rend="rubric">ላሊበላ፡</hi> እንዘ፡ የሐምዮ። ወብእሲቱሰ፡ ለውእቱ፡ ብእሲ፡ ተቤሎ፡ ኢትጽርፍ፡ ላዕለ፡
#             ገብረ፡ እግዚአብሔር፡ ወመሲሐ፡ እግዚአብሔር፡ ወእቱ፡ <!--ው? DR 2017-08-31-->
#           </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="123">
#                <ab>
#                   <pb n="123r"/>
#                   <cb n="a"/> ዓዲ። ወተምዓ፡ ለብእሲቱ፡ ወተንሥአ፡ እምኀበ፡ ይነብር፡ ወዓርገ፡ ውስተ፡ ምስካቡ፡ ወኖመ። ወሶበ፡ ነቅሐ፡ እምንዋሙ፡
#             ረከበ፡ ክልኤተ፡ አዕይንቲሁ፡ ዕውራነ፡ ወዜነዋ፡ ለብእሲቱ፡ ከመ፡ ዖሩ፡ አዕይንቲሁ። ወብእሲቱሰ፡ ትቤሎ፡ ኢይቤለከኑ፡ ኢትጽርፍ፡ ላዕለ፡
#             ገብረ፡ እግዚአብሔር፡ አርአየኬ፡ እግዚአብሔር፡ ኃይሎ፡ ላዕሌከ፡ እስመ፡ ጸረፍከ፡ ላዕለ፡ ገብሩ፡ በዑረተ፡ ልብከ። ወእግዚአብሔር፡ አዖሮን፡
#             ለአዕይንቲከ። ከመ፡ ይኩን፡ ዕውረ፡ ውሥጥከኒ፡ ወአፍአከኒ፡ ወይእዜኒ፡ ኢትኅዘን፡ በእንተ፡ ዑረተ፡ አዕይንቲከሰ። አላ፡ ኅዘን፡ በእንተ፡
#             ነፍስከ፡ እስመ፡ ትትኳነን፡ በእሳተ፡ ገሃነም፡ ለእመ፡ ኢነሳሕከ። በከመ፡ ይቤ፡ እግዚእነ፡ <cb n="b"/> በወንጌል፡ ኵሉ፡ ዘነበበ፡
#             ጽርፈተ፡ ላዕለ፡ ወልደ፡ እጓለ፡ እመሕያው፡ ይትኃደግ፡ ሎቱ፡ ወዘሰ፡ ጸረፈ፡ ዲበ፡ መንፈስ፡ ቅዱስ፡ ኢይትኃደግ፡ ሎቱ፡ ኢበዝ፡ ዓለም፡
#             ወኢበዘይመጽእ። ዘጸረፈሰ፡ ዲበ፡ እጓለ፡ እመሕያው፡ ዘይቤ፡ ላዕለ፡ እለ፡ ኢተጠምቁ። ወዘሰ፡ ጸረፈ፡ ላዕለ፡ መንፈስ፡ ቅዱስ፡ ዲበ፡ እለ፡
#             ነሥኡ፡ መንፈሰ፡ ቅዱሰ፡ እምከርሠ፡ ጥምቀት፡ ወይእዜኒ፡ ኢይምሰልከ፡ ዲበ፡ ሰብእ፡ ዘጸረፍከ። አላ፡ ዲበ፡ መንፈስ፡ ቅዱስ። ወከመዝ፡
#             ገሠጸቶ፡ ይእቲ፡ ብእሲት፡ ለብእሲሃ፡ እስመ፡ መንፈስ፡ ቅዱስ፡ አስተናገራ። ወይእዜኒ፡ ኦፍቁራንየ፡ ኢይፃእ፡ ጽርፈት፡ እምአፉነ፡ ላዕለ፡
#             እኁነ፡ ክርስቲያናዊ፡ እስመ፡ ተወልደ፡ <pb n="123v"/>
#                   <cb n="a"/> እመንፈስ፡ ቅዱስ። ወበእንተዝ፡ ንሰመይ፡ ጸራፍያነ፡ ላዕለ፡ መንፈስ፡ ቅዱስ፡ ሶበ፡ ጸረፍነ፡ ላዕለ፡ ክርስቶሳዊ።
#             ያድኅነነኬ፡ ቅግዚአብሔር፡ እስመ፡ እምዘ፡ ከመዝ፡ ልማድ፡ እስመ፡ ጳውሎስኒ፡ ይሜህረነ፡ ከመ፡ ኢንርግም፡ እስከ፡ ለሰይጣን፡ አኮ፡ ኃዚኖ፡
#             ለሰይጣን፡ ዘይሜህር፡ ከመዝ፡ አላ፡ ከመ፡ ኢንልክር፡ ጥቀ፡ ለመርገም፡ በልሳንነ፡ ከመ፡ ኢንድኃጽ፡ ለዕለ፡ እኁነ። ንትማኅፀንኬ፡ በኃይለ፡
#             ጸሎቱ፡ ለ<hi rend="rubric">ገብረ፡ መስቀል፡ </hi> ከመ፡ ያዑሮ፡ ለሰይጣን፡ ዘያስሕተነ፡ ወዘይሜህረነ፡ ከመ፡ ንጽርፍ፡ በከመ፡
#             አዖሮ፡ ለውእቱ፡ ብእሲ፡ ዘጸረፈ፡ ላዕሌሁ፡ ጸሎቱ፡ ወስእለቱ፡ ወበረከቱ፡ የሃሉ፡ ምስለ፡ ንግሥትነ፡ <hi rend="rubric">ወለተ፡
#               ኢየሱስ፡ </hi>
#                   <cb n="b"/> ወምስለ፡ ወልዳ፡ <hi rend="rubric">ኃይለ፡ ኢየሱስ፡ </hi>ወይባርከነ፡ ለኵልነ፡ አሜን፤ <hi rend="rubric">ስምዑኬ፡ ኦፍቁራንየ፡ እንግርክሙ፡ ዘከመ፡ ኮነ፡ ግብረ፡ </hi>ፀአቶን፡ ለእላንቱ፡ አብያተ፡ ክርስቲያናት፡
#             እምልበ፡ ምድር። በእደ፡ <hi rend="rubric">ላሊበላ፡ </hi>ልዑለ፡ ዝክር፡ ወዘከመ፡ እፎ፡ ግብረ፡ ሕንጻሆን፡ ኮነ፡ እንበለ፡
#             ዕፅ፡ ወመሬት፡ ወዘእንበለ፡ አኅባለ፡ ጠፈር፡ ወመዋጽሕተ። ሰማዕክሙኑ፡ ዘከመዝ፡ ግብረ፡ ዜና፡ ወሚመ፡ ርኢክሙኑ፡ በአዕይንቲክሙ፡ ዘከመዝ፡
#             መንክረ፡ ወዘከመዝ፡ መድምመ፡ መድፍን፡ ኅቡእ፡ ዘተከሥተ፡ በእደ፡ <hi rend="rubric">ላሊበላ፡ </hi>እምልብኒ፡ ተመሥጠረ፡
#             ወእምሕሊናኒ፡ ተሠወረ፡ ዝኩ፡ ገባሬ፡ ኵሉ፡ ወፈጣሬ፡ ኵሉ፡ </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="124">
#                <ab>
#                   <pb n="124r"/>
#                   <cb n="a"/> ዘአምጽአ፡ ኵሎ፡ ዓለመ፡ በጽዋዔ፡ ቃሉ፡ አመ፡ በጽሐ፡ ጊዜሁ፡ ለሕንጻ፡ እሎን፡ አብያተ፡ ክርስቲያናት። ወአመ፡ ወርዘወ፡
#             ሐናጺሆን፡ በሥጋኒ፡ ወበመንፈስኒ። ፈቀደ፡ እግዚአብሔር፡ ከመ፡ ይክሥት፡ መድፍኖ፡ ኅቡአ፡ ዘነበረ፡ እምቀዳሚ፡ ተከቢቶ። አመ፡ ሣረረ፡
#             ምድረ፡ ወሐለየ፡ ከመ፡ ያርኢ፡ ምሥጢሮ፡ ለሕዝብ፡ ለእለ፡ ይደልዎሙ፡ ከሢቶ፡ እምልበ፡ ምድር፡ ወጥበብ፡ መንክር፡ ወበምሥጢር፡ ኅቡእ።
#             በከመ፡ አውፅአ፡ ቀዳሚ፡ እምከርሠ፡ ምድር፡ ኵሎ፡ አዝርእተ፡ ምድር፡ በበዘመዱ፡ ወበበአርአያሁ። ወዕፀወኒ፡ ከማሁ፡ በበአርአያሁ፡
#             ወበበአምሳሊሁ። ወአንስሳኒ፡ ብዙኃ፡ በበአርአያሆሙ፡ ወበበአምሳሊሆሙ። <cb n="b"/> ወከማሁ፡ ፈቀደ፡ ለእሎንሂ፡ አብያተ፡ ክርስቲያናት፡
#             ያወፅኦን፡ እምድር፡ አኮ፡ ዘአሐዱ፡ ኅብሮን። ወኢሂ፡ ዘአሐዱ፡ ግብረቶን፡ ወኢተኃብር፡ አሐቲ፡ ምስለ፡ ካልእታ፡ በኵሉ፡ ኅብራ፡ ወበኵሉ፡
#             ግብራ። ወሶበ፡ በጽሐ፡ ጊዜሁ፡ ከመ፡ ይትከሠታ፡ ኵሎን፡ አብያተ፡ ክርስቲያናት፡ ዓሠርቱ፡ ዘእምአሐቲ፡ ዕብን። ይቤሎ፡ እግዚአብሔር፡ ለ<hi rend="rubric">ላሊበላ፡ </hi>በጽሐ፡ ጊዜሁ፡ ከመ፡ ይትከሠታ፡ አብያተ፡ ክርስቲያናት፡ በእደ፡ ዚአከ፡ ዘአርአይኩከ፡ ቀዳሚ።
#             ወአንተኒ፡ ጽናዕ፡ ወተኃየል፡ ከመ፡ ትፈጽም፡ መልእክተከ። እስመ፡ ብዙኃን፡ ነፍሳት፡ ይድኅኑ፡ በውስቴቶን። አስተፋጥን፡ ሐኒጾቶን። ወናሁ፡
#             አዘዝክዎሙ፡ ለመላእክትየ፡ ከመ፡ ይርድኡከ። <pb n="124v"/>
#                   <cb n="a"/>
#                   <hi rend="rubric">ወላሊበላ፡</hi> አግበረ፡ ሐፃውንተ፡ ብዙኃ፡ ዘዘ፡ ዚአሁ፡ ግብረቶን። ቦለጸሪብኒ፡ ወቦ፡ ሐፂን፡ ለመፍጽሕኒ፡
#             ወቦ፡ ሐፂን፡ ለወቂር። ዘንተ፡ ኵሎ፡ ሐፃውንተ፡ ገብረ። ወካልኣነኒ፡ ብዙኃተ፡ ሐፃውንተ፡ ገብረ፡ በዘይትፌጸም፡ ሕንጻ፡ መቅደስ፡
#             ዘእምአሐቲ፡ ኰኵሕ፡ ወእምአሜሃሰ፡ ኢሐለየ፡ <hi rend="rubric">ላሊበላ፡</hi> ሕሊና፡ ዘበምድር፡ ኢለመፍቅደ፡ ሥጋሁ፡
#             ወለመፍቅደ፡ ብእሲቱ። አላ፡ ይሔሊ፡ ኵሎ፡ አሚረ፡ በእንተ፡ እሎን፡ አብያተ፡ ክርስቲናት፡ ከመ፡ ይፈጽም፡ በከመ፡ ርእየ፡ በውስተ፡ ሰማይ፡
#             እንዘ፡ ያኄይሎ፡ መንፈስ፡ ቅዱስ፡ በኵሉ፡ ውስተ፡ ኵሉ። ወአግቢሮ፡ ሐፃውንተ፡ በዘይገብር፡ ሕንጻ፡ መቅደስ፡ አዘዞሙ፡ ለኵሎሙ፡ <cb n="b"/> ሕዝብ፡ ከመ፡ ይትጋብኡ፡ ኀቤሁ። ወይቤሎሙ፡ ሶበ፡ ተጋብኡ፡ ንግሩ፡ ዓስበክሙ፡ ዘትነሥኡ፡ ኵልክሙ እለ፡ ትትራድኡኒ፡ ውስተ፡
#             ሕንጻ፡ አብያተ፡ ክርስቲያናት፡ እስመ፡ አዘዘኒ፡ እግዚአብሔር፡ ከመ፡ እግበር። አንትሙኒ፡ ንግሩ፡ በበቃልክሙ፡ ዘከመ፡ ትነሥኡ፡ ዓስበክሙ።
#             ዘሂ፡ ይትራዳእ፡ ውስተ፡ ግብረ፡ ጸሪብ። ወዘሂ፡ ይፃሙ፡ በአውፅኦ፡ መሬት። ወኵልክሙ፡ ንግሩ፡ በበቃልክሙ፡ ወዘከመ፡ ትቤሉኒ፡ እሁበክሙ፡
#             ከመ፡ ኢትበሉኒ፡ አገበረነ፡ እንበለ፡ ፈቃድነ፡ ከመ፡ ኢይኩን፡ ፃማክሙ፡ በከ፡ ሶበ፡ ታንጐረጕሩ። ወነገሩ፡ ኵሎሙ፡ በከመ፡ ሕሊና፡ ልቦሙ።
#             ውእቱኒ፡ ወሀቦሙ፡ በከመ፡ ይቤልዎ፡ ወኢያንተገ፡ ውሂቦቶሙ፡ </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="125">
#                <ab>
#                   <pb n="125r"/>
#                   <cb n="a"/> እምአመ፡ ወጠነ፡ ሐኒጸ፡ አብያተ፡ ክርስቲያናት፡ እስከ፡ ፈጸመ፡ ለለዕለቱ፡ ይሁቦሙ፡ ዓስቦሙ። ለዘይወቅርሂ፡
#             ወለዘይጸርብሂ፡ ወለዘያወፅእሂ፡ መሬተ፡ እምጽራበ፡ ቤተ፡ ክርስቲያን፤ ወእምውስተ፡ ሕዝብሰ፡ ብዙኃን፡ እለ፡ ተረክቡ፡ ምሉዓነ፡ ጥበብ። እለ፡
#             ወደየ፡ ላዕሌሆሙ፡ እግዚአብሔር፡ መንፈሰ፡ አእምሮ፡ ከመ፡ ቤሲላኤል፡ ወኢልያብ። ወተደለወ፡ <hi rend="rubric">ገብረ፡ መስቀል፡
#             </hi>ከመ፡ ይግበር፡ በከመ፡ አርአዮ፡ እግዚአብሔር፡ ወአኃዘ፡ ይውጥን። ወመላእክትኒ፡ አኃዙ፡ ያንሶስው፡ ምስሌሁ፡ እንዘ፡ ይሜጥኑ፡ ሎቱ፡
#             ምድረ፡ በበአምጣኖን፡ ለኵሉ፡ በበፆታሁ፡ ለንዑስኒ፡ ወለዓቢይኒ። ወውእተኒ፡ ምድረ፡ <cb n="b"/> ኀበ፡ ገብረ፡ አብያተ፡ ክርስቲያናት፡
#             ተሣየጡ፡ በወርቁ፡ እምኀቤሆሙ፡ ለእለ፡ ይኴንንዋ፡ ለይእቲ፡ ምድር፡ እንዘ፡ ያፈደፍድ፡ ኂሩተ። ወለእመሰ፡ ፈቀደ፡ ከመ፡ ይንሣእ፡ መኑ፡
#             እምከልኦ፡ ለንጉሥ። ወገብረ፡ ቀዳሚተ፡ ቤተ፡ ክርስቲያነ፡ በከመ፡ አርአዮ፡ እግዚአብሔር፡ በመንክር፡ ግብር፡ ወበመድምም፡ ኪን፡
#             ዘኢይትከሀሎ፡ ለእጓለ፡ እመሕያው፡ ከመ፡ ይግበር፡ ዘእንበለ፡ ጥበበ፡ እግዚአብሔር። ወአሠነየ፡ አፍአሂኒ፡ ወውሥጣኒ፡ ወአሠርገዋ፡ በመሳክው፡
#             ሠናያን፡ ወስቅሱቃን፡ እሙንቱ፡ ወሰቅሰቆሙኒ፡ ኢኮነ፡ ዘዕፅ፡ ወአዕማዲሆሙኒ፡ ብልዙናት፡ እማንቱ። ወገብረ፡ እንተ፡ ቅድሜሃኒ፡ ክልኤተ፡
#             አብያተ፡ <pb n="125v"/>
#                   <cb n="a"/> ክርስቲያናት። ወሙፃኦንሰ፡ አሐዱ፡ አንቀጽ፡ ወይፈልጦን፡ አንቀጽ፡ ውሣጣይ። ወእንተ፡ ድኅሬሃኒ፡ ገብረ፡ አሐተ፡ ቤተ፡
#             ክርስቲያን፡ ዓባየ። ወአሠነያ፡ በብዙኅ፡ ሠርጕ። ወአኮ፡ በወርቅ፡ ወበብሩር፡ አላ፡ ሠርጓኒ፡ ዘዕብን። ወኍልቈ፡ አዕማዲሃሰ፡ ፸ ወ ፪ቱ፡
#             በኍልቈ፡ ፸ ወ ፪ቱ፡ አርድእት፡ እንተ፡ በየማናኒ፡ ገብረ፡ አሐተ፡ ቤተ፡ ክርስቲያነ። ወእንተ፡ በጸጋማኒ፡ ገብረ፡ አሐተ፡ ቤተ፡
#             ክርስቲያነ። ወሰመያ፡ ለቀዳሚት፡ <hi rend="rubric">ቤተ፡ ማርያም፡</hi> ወለእንተ፡ ቅድሜሃኒ፡ ክልኤተ፡ አብያተ፡ ክርስቲያናት፡
#             ለአሐቲ፡ ሰመያ፡ ደብረ፡ ሲና፡ ወለካልእታኒ፡ ሰመያ፡ ጎልጎታ፡ ወለእንተ፡ የማናኒ፡ ሰመያ፡ ቤተ፡ መስቀል። ወለእንተ፡ ፀጋማኒ፡ <cb n="b"/> ሰመያ፡ ቤተ፡ ደናግል። ወከመዝ፡ አስተአኃዘ፡ ፭ተ፡ ቤተ፡ ክርስቲያናተ፡ ሠናያነ፡ ዘእምአሐቲ፡ ኰኵሕ። ወክልኤተኒ፡ አብያተ፡
#             ክርስቲያናተ፡ ሠናያተ፡ ዘእምአሐቲ፡ ኰኲሕ። ወክልኤተኒ፡ አብያተ፡ ክርስቲያናት፡ ገብረ፡ ሠናያተ፡ ወግብረቶንሰ፡ ብዑድ፡ ውእቱ፡ ወቅሩባን፡
#             እማንቱ። ወባሕቱ፡ ይፈልጦን፡ ቅጽር፡ ዘሀሎ፡ ማእከሎን። ወለእልክቱሂ፡ ክልኤሆን፡ ሰመያ፡ ለአሐቲ፡ ቤተ፡ ገብርኤል።ወለካልእታኒ፡ ሰመያ፡
#             ቤተ፡ አባ፡ መጣዕ። ወከመዝ፡ አስተአኃዘ፡ እሎንተ፡ ክልኤተ፡ አብያተ፡ ክርስቲያናት። ወደመሮን፡ በቅጽር፡ ወፈለጦን፡ ካዕበ፡ በቅጽር፡
#             ወገብረ፡ ካዕበ፡ ክልኤተ፡ አብያተ፡ ክርስቲያናተ፡ መአድማነ፡ </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="126">
#                <ab>
#                   <pb n="126r"/>
#                   <cb n="a"/> ሕንፃ፡ ላሊበላ፡ miniature <pb n="126v"/>
#                   <cb n="a"/> ወግብረቶንሰ፡ ኢይኃብር፡ ለክልኤሆን። ወለእሎንሂ፡ ሰመያ፡ ለአሐቲ፡ ቤተ፡ መርቆሬዎስ። ወለካልእታኒ፡ ሰመያ፡ ቤተ፡
#             አማኑኤል። ወከመዝ፡ አስተአኃዞን፡ ለክልኤሆን፡ አብያተ፡ ክርስቲያናት፡ ወገብረ፡ አሐቲኒ፡ ቤተ፡ ክርስቲያነ፡ እንተ፡ ባሕቲታ፡ ወግብረታኒ፡
#             ብዑደ፡ ውእቱ፡ በትእምርተ፡ መስቀል፡ ገብራ፡ በከመ፡ አመሩ፡ ሎቱ፡ መላእክት። ወበከመ፡ አርአይዎ፡ እንዘ፡ ይሜጥኑ፡ ሎቱ፡ ምድረ። ወሰመያ፡
#             ላቲኒ፡ ቤተ፡ ጊዮርጊስ። ወከመዝ፡ ፈጸሞን፡ ለዓሠርቱ፡ አብያተ፡ ክርስቲያናት። ወግብረቶንሰ፡ ዘዘዚአሆን፡ ወአርአያሆንሂ፡ ዘዘዚአሆን።
#             ወአልቦ፡ ዘገብረ፡ <hi rend="rubric">ገብረ፡ መስቀል፡ </hi>ወኢምንተኒ፡ ዘእንበለ፡ ዘአርአዮ፡ <cb n="b"/> እግዚአብሔር።
#             አላ፡ ገብረ፡ በከመ። ርእየ፡ በውስተ፡ ሳብዕ፡ ሰማይ፡ ወኢወሰከ፡ ኢዲበ፡ ኑኆን፡ ወኢዲበ፡ ቆሞን፡ ወኢዲበ፡ ሰሮን፡ አላ፡ በከመ፡ ርእየ፡
#             በከመ፡ ይቤሎ፡ እግዚአብሔር፡ ኢትወስክ፡ ኢዲበ፡ ቆሞን፡ ወኢዲበ፡ ሰሮን። ወሶበ፡ አኃዘ፡ ይውጥን፡ ሕንጻሆን፡ አኃዙ፡ መላእክትኒ፡
#             ይትራድእዎ፡ በውስተ፡ ኵሉ፡ ግብር። ወኮኑ፡ አሐደ፡ መርዔተ፡ መላእክት፡ ወሰብእ፡ በውእቱ፡ መዋዕል። እስመ፡ ተደመሩ፡ መላእክት፡ ኀበ፡
#             ኵሎሙ፡ መስተገብራነ፡ ቤተ፡ ክርስቲያን፡ ኀበ፡ ጸረብትኒ፡ ወኀበ፡ ወቀርትኒ። ወኀበ፡ ፀወርተ፡ መሬትኒ፡ መዓልተሰ፡ ይትጌበሩ፡ መላእክት፡
#             ምስለ፡ ሰብእ፡ ውስተ፡ ሕንጻ፡ አብያተ፡ ክርስቲያን። ወሌሊተሰ፡ ይትገበሩ፡ መላእክት፤ </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="127">
#                <ab>
#                   <pb n="127r"/>
#                   <cb n="a"/> መዓልተ፡ ሶበ፡ ይገብሩ፡ አሐተ፡ ዕመተ። ወበሳኒታ፡ ይትረከብ፡ ከዊኖ፡ አርባዕተ፡ ዕመተ። እስመ፡ መላእክት፡ ይገብሩ፡
#             በኵሉ፡ ለያልይ። ወእለ፡ ርእዩ፡ ይቤሉ፡ ምንትኑዝ፡ መንክር። ንሕነሰ፡ ኃደግነ፡ አሐሰ፡ ዕመተ፡ ታማልም። ወይእዜሰ፡ ኮነ፡ አርባዕተ፡
#             ዕመተ። እስመ፡ ኢይአምሩ፡ እሙንቱ፡ ሰብእ፡ ከመ፡ መላእክት፡ ይገብሩ፡ እስመ፡ ኢይሬእይዎሙ። ወ<hi rend="rubric">ላሊበላ</hi>ሰ፡ የአምርዎ፡ ዘንተ፡ እስመ፡ የአምሩ፡ መላእክት፡ ኂሩቶ። ወበእንተዝ፡ ኢይሤወርዎ፡ እስመ፡ ኮንዎ፡ ኣብያጸ፡ እሳታውያን፡
#             ወበእንተዝ፡ ኢይትኃብእዎ፡ ወከመዝ፡ ፈጸመ፡ ሐኒጸቶን፡ ለእላንቱ፡ አብያተ፡ ክርስቲያናት፡ ዓሠርቱ። ወግብረቶንሰ፡ <cb n="b"/>
#             እምአሐዱ፡ ዕብን። ርእዩኬ፡ ኦፍቁራንየ፡ ዘከመዝ፡ ብእሴ፡ ዘበእዴሁ፡ ተከሥታ፡ እሎን፡ አብያተ፡ ክርስቲያናት፡ ዘኢተገብረ፡ ዘከማሆን፡
#             በኀበ፡ ካልአን፡ በሐውርት። በአይ፡ ልሳን፡ ንክል፡ ነጊረ፡ ግብረቶን፡ ለእሎን፡ አብያተ፡ ክርስቲያናት። ወግብረተ፡ ቅጽሮንሂ፡ ኢንክል፡
#             ነጊረ፡ ኅድጉሰ፡ እንተ፡ ውሥጦን። ዘርእየኒ፡ ኢይጸግብ፡ በነጽሮ። ወበአንክሮኒ፡ ኢይክል፡ ልብ፡ ፈጽሞ። እስመ፡ መንክር፡ ተገብረ፡ በእደ፡
#               <hi rend="rubric">ላሊበላ፡ </hi>ዘኢይትከሀሎ፡ ለሥጋዊ፡ ከመ፡ ይኈልቍ፡ መንክራቲሁ። እመቦ፡ ዘይኌልቆሙ፡ ለከዋክብተ፡
#             ሰማይ። ይኋልቆሙ፡ ለመንክራትኒ፡ ዘተገብራ፡ በእደ፡ <hi rend="rubric">ላሊበላ፡</hi>
#                   <pb n="127v"/>
#                   <cb n="a"/> ቤተ፡ ማርያምን፡ እም{}ዳአነፀ፡ miniature </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="128">
#                <ab>
#                   <pb n="128r"/>
#                   <cb n="a"/> ወለእመሰቦ፡ ዘይፈቅድ፡ ከመ፡ ይርአይ፡ ገብረ፡ ሕንጻሆን፡ ለአብያተ፡ ክርስቲያናት፡ ዘተገብራ፡ በእደ፡ <hi rend="rubric">ላሊበላ፡ </hi>ይምጻእ፡ ወይርአይ፡ በአዕይንቲሁ፡ እስመ፡ አኮ፡ ዘይበልያ፡ ሕንጻ፡ ማኅፈዱ፡ ለ<hi rend="rubric">ላሊበላ፡ </hi>ከመ፡ ደብተራ፡ ሙሴ። ወኢሂ፡ ከመ፡ ምኵራበ፡ ሰሎሞን፡ ዘይነስትዎን፡ ዓላውያን። ማኅፈደ፡
#             ደብተራሁሰ፡ ለ<hi rend="rubric">ገብረ፡ መስቀል፡</hi> ኢያንቀለቅላ፡ ወኢይማስና፡ እስከ፡ ታስተርኢ፡ ኢየሩሳሌም፡ ሰማያዊት፡
#             ዲበ፡ ምድር፡ እንተ፡ ድሉት፡ ለኅሩያን፡ እለ፡ ይደልዎሙ፡ ከመ፡ ይኅድሩ፡ ውስቴታ። <hi rend="rubric">ጴጥሮስ፡</hi> ወ<hi rend="rubric">ጳውሎስ፡</hi> ምስለ፡ <hi rend="rubric">ኢየሱስ፡</hi> ሊቆሙ፡ ፈጸሙ፡ ሐኒጾተ፡ መርጡላ፡
#             ለድንግል፡ በሠለስቱ፡ አዕባን፡ እንዘ፡ ይለመልማ፡ <cb n="b"/> ከመ፡ ሰምዕ፡ በትእዛዘ፡ እግዚአብሔር። ወ<hi rend="rubric">ላሊበላ፡ </hi>ኒ፡ ፈጸመ፡ ዓሠርተ፡ አብያተ፡ ክርስቲያናት፡ በአሐዱ፡ ዕብን። እንዘ፡ ትረድኦ፡ ጸጋ፡ እግዚአብሔር፡ ምስለ፡
#             ኃይላቲሁ። <hi rend="rubric">ጴጥሮስ፡</hi> ወ<hi rend="rubric">ጳውሎስ፡</hi> ሐነጹ፡ ነፍሳተ፡ ብዙኃ፡ በአሐዱ፡
#             ሐይማኖት። ወ<hi rend="rubric">ላሊበላ፡ </hi>ኒ፡ ሐነጸ፡ ብዙኃ፡ አብያተ፡ ክርስቲያናት፡ በአሐዱ፡ ዕብን። <hi rend="rubric">ጴጥሮስ፡</hi> ወ<hi rend="rubric">ጳውሎስ፡</hi> ሣረሩ፡ አብያተ፡ ክርስቲያናት፡ ዲበ፡ አሐዱ፡
#             ኰኵሕ። ወግብረቶንሰ፡ በፅቡር፡ ወበአኅባለ፡ ጠፈር፡ ወበመዋጽሕት፡ ዘዕፅ፡ ወአዕማዲሆንኒ፡ ዘዕፅ። ወ<hi rend="rubric">ላሊበላ፡
#             </hi>ኒ፡ ሣረረ፡ ብዙኃተ፡ አብያተ፡ ክርስቲያናት፡ ዘእምአሐዱ፡ ዕብን፡ ዘአልቦ፡ ጽቡረ፡ ለመአኅዝቲሆን፡ <pb n="128v"/>
#                   <cb n="a"/> ዘአልቦ፡ ጠፈር፡ ለመአቀዶን፡ ወዘአልቦ፡ መሥዕርተ፡ ለመክደኖን። ወኵሎሰ፡ ግብረቲሆን፡ ኢንክል፡ ንንግር፡ በበገጹ።
#             እስመ፡ ብዙኅ፡ ፆታ፡ ግብረቶን። ናሁ፡ ተስዕነኒ፡ ሊተሰ፡ ላዕላዓ፡ ልሳን፡ ከመ፡ እጽሐፍ፡ ለክሙ፡ ኵሎ፡ ኂሩታቲሁ፡ ለዝንቱ፡ ብእሲ፡
#             ክቡር፡ <hi rend="rubric">ላሊበላ፡ </hi>ዘከብረ፡ እምኵሎሙ፡ መሬታውያን፡ በጥበብኒ፡ ወበስነ፡ ጽድቅኒ፡ ተብህለ፡ ከመ፡
#             ሰሎሞን፡ ጠቢብ፡ እምኵሉ፡ እጓለ፡ እመሕያው፡ ወእምኵሎሙ፡ ጠቢባነ፡ ግብጽ። ወውእቱኒ፡ ገብረ፡ ምኵራበ፡ በኢየሩሳሌም፡ በአዕባን፡ ዓበይት፡
#             ዘዘሳምን፡ ወዘዘ፡ ሳብዕ፡ ኑኆን። እንዘ፡ ይረድኦ፡ ኪራም፡ ንጉሠ፡ ጢሮስ፡ በዕፀወ፡ ቄድሮና፡ <cb n="b"/> ወበዕፀወ፡ ጳውቄና፡
#             ወበዕፀወ፡ ቄጳርስ። ወፈጸመ፡ ክልኤቱ፡ አብያተ። ቤተ፡ እግዚአብሔርኒ፡ ወቤተ፡ ርእሱኒ፡ በ፳፡ ዓመት። ወ<hi rend="rubric">ላሊበላ፡ </hi>ሰ፡ ገብረ፡ ዓሠርተ፡ አብያተ፡ ክርስቲያናት፡ በአሐዱ፡ ዕብን፡ እንዘ፡ ይረድኦ፡ ወልደ፡ እግዚአብሔር። እምእለ፡
#             ክልኤቱ፡ ጠቢባን፡ ተገብራ፡ ክልኤቱ፡ ምኵራባት። ምኵራቡሰ፡ ለአሐዱ፡ ጠቢብ፡ በዕብን፡ ወበዕፀው፡ ወበአሕባል፡ ወበፅቡር። ወካልኡኒ፡ ጠቢብ፡
#             ገብረ፡ ማኅፈዳቲሁ፡ ዘእምአሐቲ፡ ዕብን። እንዘ፡ ኢይፈቅድ፡ ወኢምንተኒ፡ ለመፍቅዶን። ወኢዕፀ፡ ለመሳክዊሆን፡ ወኢአኅባለ፡ ለመአቂዶን፡
#             ወኢፅቡረ፡ ለመአኅዝቲሆን። እስመ፡ በአሐቲ፡ ዕብን፡ ፈጸመ፡ ኵሎ፡ </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="129">
#                <ab>
#                   <pb n="129r"/>
#                   <cb n="a"/> ፲፯ ግብረታቲሆን። ግብረ፡ ቅጽሮንሂ፡ ዘእምአሐዱ፡ ዕብን። ወግብረተ፡ ውሣጥያቲሆንሂ፡ ዘእምአሐዱ፡ ዕብን። ወእምፃማ፡
#             ውሣጥያቲሆንሰ፡ የዓቢ፡ ፃማ፡ ቅጽራቲሆን። ኵሉኬ፡ ሰብእ፡ እንዘ፡ ኢትዮጵያዊ፡ ውእቱ፡ ዘኢበጽሐ፡ ውስተ፡ ሀገረ፡ ሮሐ፡ ቅድስት፡ እንዘ፡
#             ይሰምዕ፡ ዜናሆን፡ ለእላንቱ፡ አብያተ፡ ክርስቲያናት፡ እለ፡ ተገብራ፡ ዘእምአሐቲ፡ ዕብን፡ ይትሜሰል፡ ከመ፡ ብእሲ፡ ዘኢያፈቅር፡ ከመ፡
#             ይርአይ፡ ገጾ፡ ለእግዚእነ፡ ወመድኃኒነ፡ <hi rend="rubric">ኢየሱስ፡ ክርስቶስ፡</hi> ወብፁዕሰ፡ ወቅዱስ፡<hi rend="rubric">ላሊበላ፡ </hi> ሶበ፡ ፈጸመ፡ ሕንጻሆን፡ ለእማንቱ፡ አብያተ፡ <cb n="b"/> ክርስቲያናት፡ ዘከመ፡ አርአዮ፡
#             እግዚአብሔር። ኢፈቀደ፡ ከመ፡ ይጐንዲ፡ ላዕሌሁ፡ ሢመተ፡ መንግሥት፡ ወኢፈቀደ፡ ከመ፡ ትዕዱ፡ ላዕለ፡ ወልዱኒ። አላ፡ ይቤ፡ ይሚጣ፡ ለዚቲ፡
#             ሢመተ፡ መንግሥት፡ ወያግብአ፡ ኀበ፡ እስራኤል። እስመ፡ ሎሙ፡ ይቤሎሙ፡ በእንቲአክሙ፡ ፈጠርክዎሙ፡ ለኵሎሙ፡ አሕዛብ፡ ወካዕበ፡ መሐለ፡ ሎሙ፡
#             እንዘ፡ ይብል፡ ኢይሜንኖሙ፡ ለሕዝበ፡ ያዕቆብ። ወኢያስተሐቅሮሙ፡ ለሕዝበ፡ እስራኤል። እስመ፡ ኪያሆሙ፡ ኃረይኩ፡ እምኵሎሙ፡ አሕዛብ። በከመ፡
#             ይቤ፡ ነቢይ፡ መሐለ፡ እግዚአብሔር፡ ለዳዊት፡ በጽድቅ፡ <pb n="129v"/>
#                   <cb n="a"/> ወኢይኔስሕ። እስመ፡ ይቤሎ፡ አነብር፡ ዲበ፡ መንበርከ፡ ወይእዜኒ፡ ለያግብኣ፡ እግዚአብሔር፡ ለዛቲ፡ መንግሥት፡ ኀበ፡
#             እስራኤል፡ ወኢይትኃጣእ፡ እምነ፡ ቤተ፡ እስራኤል፡ ዘይነብር፡ ዲበ፡ መንበረ፡ መንግሥት። ኢያጐንዲ፡ እግዚአ፡ ኃያላን፡ ዛቲ፡ ሢመተ፡
#             መንሥት፡ ኢያጐንዲ፡ እግዚኣ፡ ኃያላን፡ ዛቲ፡ ሢመተ፡ መንግሥት፡ ኢዲቤየ፡ ወኢዲ፡ አዝማድየ። ወናሁ፡ አንሰ፡ ፈጸምኩ፡ መልእክትየ፡
#             ዘበእንቲአሃ፡ ሤመኒ፡ ሢመተ፡ መንግሥት። እንዘ፡ ለሊሁ፡ እግዚአብሔር፡ ይገብር፡ በእደ፡ መላእክቲሁ። ከመዝ፡ ይቤ፡ <hi rend="rubric">ገብረ፡ መስቀል፡ </hi>ንጉሥ፡ እስመ፡ ኢያፈቅር፡ ሢመተ፡ ዘበምድር፡ <cb n="b"/> ፈጺሞ፡ መልእክቶ፡
#             ወመጽዊቶ፡ ኵሎ፡ ጥሪቶ። እስከ፡ ኢይተርፍ፡ አሣዕነ፡ ዲበ፡ እገሪሁ። ወአሠርጊዎ፡ አብያተ፡ ክርስቲያናቲሁ፡ ዘገብረ፡ በውስተ፡ ኵሉ፡
#             በሐውርት። ወእሎንተኒ፡ ዓሠርተ፡ ማኅፈዳተ፡ ዘገብረ፡ ዘእምአሐቲ፡ ዕብን። አሠርገወ፡ በሠርጕ፡ ዘይደሉ፡ ለቤተ፡ ክርስቲያን፡ በመስቀልኒ፡
#             ወበአልባስኒ፡ ወቦ፡ ዘአሠርጊዎን፡ በሥዕልኒ። ወፈድፋደሰ፡ ገብረ፡ መድምመ፡ በመካነ፡ ጎልጎታ። በድነ፡ መካሀ፡ ዘለበግዑ፡ ዘኢየዓፂ፡ በድኑ።
#             ወካልአነሂ፡ ሥዕለተ፡ ብዙኃ፡ ገብረ፡ እስመ፡ በእንቲአሆን፡ ይተግህ፡ መዓልተ፡ ወሌሊተ። ወኢይሔሊ፡ ካልአ፡ መፍቅደ፡ ሥጋ፡ ኢመብልዓ፡
#             ለሲሲቱ። </ab>
#             </div>
#             <div type="textpart" subtype="folio" n="130">
#                <ab>
#                   <pb n="130r"/>
#                   <cb n="a"/> ወኢልብሰ፡ ለዓራዙ። ወኢተከዘ፡ በእንተ፡ ብእሲቱኒ፡ ወበእንተ፡ ውሉዱኒ፡ ዘእንበለ፡ በእንዚአሆን፡ ለአብያተ፡
#             ክርስቲያናት። ወሶበ፡ ፈጸሞን፡ ጸለየ፡ በውስቴቶን፡ እንዘ፡ ይብል፡ ኵሉ፡ ዘጌሠ፡ ውስተ፡ እላንቱ፡ አጽራሐ፡ ቅድሳቲከ፡ ዘገበርከ፡ በእደ፡
#             ዚአየ፡ ሀበኒ፡ አሥራተ፡ ኦእግዚእየ፨ ወይቤሎ፡ እግዚአብሔር፡ ይኩንከ፡ በከመ፡ ትቤ። ለእመ፡ ጌሠ፡ ውስተ፡ ቤተ፡ ክርስቲያንከ፡ በንጹሕ፡
#             ኦኅሩይየ፡ ከማሁ፡ በከመ፡ ሰአልከ። አንተሰ፡ ፈጸምከ፡ መልእክተከ፡ ወዓቀብከ፡ ሃይማኖተከ። እምይእዜሰ፡ ጽኑሕ፡ ለከ፡ አክሊለ፡ ጽድቅ፡
#             ወርኅው፡ ለከ፡ ኆኅተ፡ መንግሥተ፡ ሰማያት፡ ከመ፡ ትባእ፡ በፍሥሐ። ወዘንተ፡ እምድኅረ፡ <cb n="b"/> ይቤሎ፡ መድኃኒነ። ሐመ፡ ብፁዕ፡
#               <hi rend="rubric">ላሊበላ፡ </hi> ንስቲተ፡ ወአዕረፈ፡ አመ፡ ፳ ወ ፪፡ ለወርኃ፡ ሐዚራን። ወተመጠው፡ ነፍሶ፡ ንጽሕት፡
#             መላእክተ፡ ብርሃን። ወፆሮ፡ <hi rend="rubric">ገብርኤል፡ </hi>ዲበ፡ አክናፊሁ። ወካልአን፡ መላእክት፡ እንዘ፡ ይዜምሩ፡
#             በቅድሜሁ፡ ወበጽኅሬሁ። አዕረግዎ፡ ውስተ፡ ሰማይ። ወአተወ፡ <hi rend="rubric">ገብረ፡ መስቀል፡</hi> ውስተ፡ ምዕራፊሁ፡
#             ዘለዓለም። ወኃደረ፡ ምስለ፡ <hi rend="rubric">ጴጥሮስ፡ </hi>ወ<hi rend="rubric">ጳውሎስ፡</hi> እስመ፡ ከመዝ፡
#             ኪዳን፡ ተውህቦ፡ እምኀበ፡ መድኅን፡ ናሁኬ፡ ለካእኩ፡ ለክሙ፡ ኦፍቁራንየ፡ ንስቲተ፡ ዜና፡ እምትሩፋቲሁ፡ ለ<hi rend="rubric">ገብረ፡ መስቀል፡ </hi>ከመ፡ ይትፈሣሕ፡ ልብክሙ፡ ወይኩነነ፡ ለኵልነ፡ እለ፡ ተጋባእነ፡ ዝየ፡ ኃይለ፡ ጸሎቱ፡ ጊራ፡ <pb n="130v"/>
#                   <cb n="a"/> ምክህ፡ ለርእስነ። ወጸዳለ፡ ሱራሔ፡ ለገጽነ። ወኵሕለ፡ መድኃኒት፡ ለአዕይንቲነ። ወአዕኑገ፡ ሣህል፡ ለእዛኒነ። ወመዓዛ፡
#             ሠናየ፡ ለአዕናፈነ። ወማኅተመ፡ ጽድቅ፡ ለከናፍሪነ። ወሞጣሕተ፡ ፍሥሐ፡ ለዘባንነ። ወእልታሐ፡ መዊእ፡ ለእንግድዓነ፤ ወአውቃፈ፡ ምሕረት፡
#             ለእደዊነ። ወሕልቀተ፡ ፍቅር፡ ለአፃብኢነ። ወአሣዕነ፡ አድኅኖ፡ ለእገሪነ። ወስቴ፡ ሕይወት፡ ለጽምዕነ። ወኅብስተ፡ መና፡ ለርኃብነ። ወኀበ፡
#             ቦአ፡ ቤተ፡ መርዐ፡ መርዓ፡ ምስሌሁ፡ ያብአነ። በጽላሎተ፡ ክነፊሁ፡ እንዘ፡ ይከድነነ። ወኀበ፡ ረፈቀ፡ ያርፍቀነ። ለዓለመ፡ ዓለም፡ አሜን፨
#             ................................................................
#             ................................................................
#             .................................................................. <cb n="b"/> ለዘጸሐፎ፡
#             ወለዘአጽሐፎ፨ ለዘአንበቦ፡ ወለዘተርጐሞ፡ ወለዘሰምዓ፡ ቃላቲሁ፡ ኅቡረ፡ ይምሐሮሙ፡ እግዚአብሔር፡ በመንግሥተ፡ ሰማያት። በጸሎታ፡ ለ<hi rend="rubric">ማርያም፡</hi> ወዲተ፡ አምላክ። ወበትንብልናሆሙ፡ ለ<hi rend="rubric">ሚካኤል፡</hi> ወ<hi rend="rubric">ገብርኤል፡</hi> ወበጸሎተ፡ ነቢያት፡ ወሐዋርያት፡ ወበጸሎተ፡ ጻድቃን፡ ወሰማዕት። ወበጸሎተ፡ <hi rend="rubric">ላሊበላ፡ </hi> ወ<hi rend="rubric">መስቀል፡ ክብራ፡ </hi>እግዚአብሔር፡ ይምሐራ፡ ለንግሥትነ፡
#               <hi rend="rubric">ወለተ፡ ኢየሱስ፡ /</hi>ወለውሉዳ፡ <hi rend="rubric">ኃይለ፡ ኢየሱስ፡</hi> ኃይለ፡ <hi rend="rubric">ሚካኤል፡</hi> ወልደ፡ <hi rend="rubric">ማርያም፡</hi> ወላአዋልዲሃ፡ <hi rend="rubric">{ወለተ፡ ማርያም፡} ኂሩተ፡ ሥላሴ፡</hi> ለዓለመ፡ ዓለም፡ አሜን።
#             ..............................................................
#             .............................................................
#             ............................................................. </ab>
#             </div>
#          </div>
#       </body>
#   </text>
# </TEI>
